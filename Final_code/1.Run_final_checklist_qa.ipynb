# %%
from google.colab import drive
drive.mount('/content/MyDrive/')
# Out:
# Mounted at /content/MyDrive/

# %% [markdown]
# # 下載檔案

# %%
#解壓縮檔案
#%cp -r "/content/MyDrive/MyDrive/UT_NLP/dataset/drive_data.zip" /content/sample_data/drive_data.zip

# %%
#解壓縮檔案
#!unzip /content/sample_data/drive_data.zip -d /content/a4-distrib

# %%
#複製檔案
# !cp -r /content/MyDrive/MyDrive/UT_NLP/final/ /content/

# %%
#解壓縮檔案
#!unzip /content/sample_data/dense_data.zip -d /content/a4-distrib

# %%
# %cd /content/final/
# Out:
# /content/final

# %%
# !pip install -r requirements.txt
# Out:
# Collecting accelerate (from -r requirements.txt (line 1))
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.8 MB/s eta 0:00:00
# Collecting datasets (from -r requirements.txt (line 2))
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 3)) (2.1.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (4.66.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (4.35.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (9.0.0)
# Collecting pyarrow-hotfix (from datasets->-r requirements.txt (line 2))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->-r requirements.txt (line 2))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (3.4.1)
# Collecting multiprocess (from datasets->-r requirements.txt (line 2))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (3.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 5)) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 5)) (0.15.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->-r requirements.txt (line 2)) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, accelerate, datasets
# Successfully installed accelerate-0.25.0 datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %%
# !pip install checklist
# !jupyter nbextension install --py --sys-prefix checklist.viewer
# !jupyter nbextension enable --py --sys-prefix checklist.viewer
# !python -m spacy download en_core_web_sm
# Out:
# Collecting checklist
#   Downloading checklist-0.0.11.tar.gz (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 57.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from checklist) (1.23.5)
# Requirement already satisfied: spacy>=2.2 in /usr/local/lib/python3.10/dist-packages (from checklist) (3.6.1)
# Collecting munch>=2.5 (from checklist)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: dill>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from checklist) (0.3.7)
# Collecting jupyter>=1.0 (from checklist)
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipywidgets>=7.5 in /usr/local/lib/python3.10/dist-packages (from checklist) (7.7.1)
# Requirement already satisfied: transformers>=2.8 in /usr/local/lib/python3.10/dist-packages (from checklist) (4.35.2)
# Collecting patternfork-nosql (from checklist)
#   Downloading patternfork_nosql-3.6.tar.gz (22.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 60.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iso-639 (from checklist)
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.4/167.4 kB 21.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (3.0.9)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0->checklist) (6.5.5)
# Collecting qtconsole (from jupyter>=1.0->checklist)
#   Using cached qtconsole-5.5.1-py3-none-any.whl (123 kB)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0->checklist) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0->checklist) (6.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (0.19.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (0.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (0.18.3)
# Collecting backports.csv (from patternfork-nosql->checklist)
#   Downloading backports.csv-1.0.7-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (4.9.3)
# Collecting feedparser (from patternfork-nosql->checklist)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 5.4 MB/s eta 0:00:00
# Collecting pdfminer.six (from patternfork-nosql->checklist)
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 107.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (3.8.1)
# Collecting python-docx (from patternfork-nosql->checklist)
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 27.2 MB/s eta 0:00:00
# Collecting cherrypy (from patternfork-nosql->checklist)
#   Downloading CherryPy-18.8.0-py2.py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.4/348.4 kB 37.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=2.8->checklist) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=2.8->checklist) (4.5.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (6.3.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.5->checklist)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.2->checklist) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.2->checklist) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=2.2->checklist) (8.1.7)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (5.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (5.9.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (1.0.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (1.2.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->patternfork-nosql->checklist) (2.5)
# Collecting cheroot>=8.2.1 (from cherrypy->patternfork-nosql->checklist)
#   Downloading cheroot-10.0.0-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 10.2 MB/s eta 0:00:00
# Collecting portend>=2.1.1 (from cherrypy->patternfork-nosql->checklist)
#   Downloading portend-3.2.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from cherrypy->patternfork-nosql->checklist) (10.1.0)
# Collecting zc.lockfile (from cherrypy->patternfork-nosql->checklist)
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting jaraco.collections (from cherrypy->patternfork-nosql->checklist)
#   Downloading jaraco.collections-4.3.0-py3-none-any.whl (11 kB)
# Collecting sgmllib3k (from feedparser->patternfork-nosql->checklist)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->patternfork-nosql->checklist) (1.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->patternfork-nosql->checklist) (41.0.7)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter>=1.0->checklist)
#   Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Collecting jaraco.functools (from cheroot>=8.2.1->cherrypy->patternfork-nosql->checklist)
#   Downloading jaraco.functools-4.0.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->patternfork-nosql->checklist) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook->jupyter>=1.0->checklist) (4.0.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (0.2.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0->checklist) (2.19.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0->checklist) (4.19.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.7.0)
# Collecting tempora>=1.8 (from portend>=2.1.1->cherrypy->patternfork-nosql->checklist)
#   Downloading tempora-5.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.2.12)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter>=1.0->checklist) (21.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter>=1.0->checklist) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter>=1.0->checklist) (0.5.1)
# Collecting jaraco.text (from jaraco.collections->cherrypy->patternfork-nosql->checklist)
#   Downloading jaraco.text-3.12.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->patternfork-nosql->checklist) (2.21)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0->checklist) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0->checklist) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0->checklist) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0->checklist) (0.13.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.6.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->patternfork-nosql->checklist) (2023.3.post1)
# Collecting jaraco.context>=4.1 (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist)
#   Downloading jaraco.context-4.3.0-py3-none-any.whl (5.3 kB)
# Collecting autocommand (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist)
#   Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist) (7.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.2.0)
# Building wheels for collected packages: checklist, iso-639, patternfork-nosql, sgmllib3k
#   Building wheel for checklist (setup.py) ... done
#   Created wheel for checklist: filename=checklist-0.0.11-py3-none-any.whl size=12165612 sha256=98a79f4b99f38383d53f52fc61e8c9b3993d91d69db074e004e4adc5694be2cc
#   Stored in directory: /root/.cache/pip/wheels/69/8c/8d/ee02f2800af2cc27b01018a46d7c1c5c5a7cfe31b9fde273a8
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=168840 sha256=7643c476316987a8628edb1589c871582620d7559ce68b91ee262de023bc24f5
#   Stored in directory: /root/.cache/pip/wheels/d8/78/cc/5478ca3b1c3f602eae6f8cdbd78f909c0a0bfa0bbcb5c7771f
#   Building wheel for patternfork-nosql (setup.py) ... done
#   Created wheel for patternfork-nosql: filename=patternfork_nosql-3.6-py3-none-any.whl size=22332785 sha256=4123638fb6498ebc0ba0a20d798303fe17bc655d0d9dcad6f750bed2ac26c9e1
#   Stored in directory: /root/.cache/pip/wheels/a1/4c/b6/9d3a6963fe490043b4ff4c9699411a11a9946542dcaa79e24c
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=c682e4f39d4b7bbdd0d141529965d834e73b1d409eed23872bef65cc3c5bdd04
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built checklist iso-639 patternfork-nosql sgmllib3k
# Installing collected packages: sgmllib3k, iso-639, backports.csv, zc.lockfile, qtpy, python-docx, munch, jedi, jaraco.functools, jaraco.context, feedparser, autocommand, tempora, cheroot, portend, pdfminer.six, jaraco.text, qtconsole, jaraco.collections, cherrypy, patternfork-nosql, jupyter, checklist
# Successfully installed autocommand-2.2.2 backports.csv-1.0.7 checklist-0.0.11 cheroot-10.0.0 cherrypy-18.8.0 feedparser-6.0.10 iso-639-0.4.5 jaraco.collections-4.3.0 jaraco.context-4.3.0 jaraco.functools-4.0.0 jaraco.text-3.12.0 jedi-0.19.1 jupyter-1.0.0 munch-4.0.0 patternfork-nosql-3.6 pdfminer.six-20221105 portend-3.2.0 python-docx-1.1.0 qtconsole-5.5.1 qtpy-2.4.1 sgmllib3k-1.0.0 tempora-5.5.0 zc.lockfile-3.0.post1
# Installing /usr/local/lib/python3.10/dist-packages/checklist/viewer/static -> viewer
# Making directory: /usr/share/jupyter/nbextensions/viewer/
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/custom.js -> /usr/share/jupyter/nbextensions/viewer/custom.js
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/bundle.js.map -> /usr/share/jupyter/nbextensions/viewer/bundle.js.map
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/index.js.map -> /usr/share/jupyter/nbextensions/viewer/index.js.map
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/bundle.js -> /usr/share/jupyter/nbextensions/viewer/bundle.js
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/index.js -> /usr/share/jupyter/nbextensions/viewer/index.js
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/__init__.py -> /usr/share/jupyter/nbextensions/viewer/__init__.py
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/extension.js -> /usr/share/jupyter/nbextensions/viewer/extension.js
# Making directory: /usr/share/jupyter/nbextensions/viewer/__pycache__
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/__pycache__/__init__.cpython-310.pyc -> /usr/share/jupyter/nbextensions/viewer/__pycache__/__init__.cpython-310.pyc
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable checklist.viewer --py --sys-prefix
#
# Enabling notebook extension viewer/extension...
# Paths used for configuration of notebook:
#     	/usr/etc/jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/usr/etc/jupyter/nbconfig/notebook.json
# 2023-12-02 04:43:24.172631: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 04:43:24.172681: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 04:43:24.172711: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 04:43:24.181130: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-02 04:43:25.570755: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-02 04:43:27.250996: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-02 04:43:27.251500: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-02 04:43:27.251710: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 102.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Load DataSet

# %%
import math
from checklist.test_suite import TestSuite
import checklist.editor
import checklist.text_generation
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
from checklist.test_suite import TestSuite
from checklist.perturb import Perturb
from transformers import pipeline
import datasets
import checklist
import spacy
import itertools
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT
from checklist.pred_wrapper import PredictorWrapper

from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification,AutoModelForQuestionAnswering
import torch

# Load tokenizer and model from checkpoint
#model_checkpoint="trained_model_qa_64/trained_model_qa_64/checkpoint-4000"


# Assuming you are using a sequence classification model, adjust as necessary
#model_checkpoint = "trained_model_qa_64/trained_model_qa_64/checkpoint-4000"
#model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint)


model_checkpoint = "trained_model_qa_64/trained_model_qa_64/checkpoint-4000"
model_checkpoint = "./biased_qa_merge_model_1130/checkpoint-12500"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)

question_answering_pipeline  = pipeline('question-answering', model=model, tokenizer=tokenizer)

from datasets import load_dataset
from transformers import AutoTokenizer

dataset_name = "squad"  # or another dataset if instructed
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
#1117 version
from datasets import Dataset
import datasets
import random
squad_adv_addSent = datasets.load_dataset('squad_adversarial', 'AddOneSent')
#nq_data = datasets.load_dataset("json",data_files="./fp-dataset-artifacts/datasets/nq_train.json", field='data')
squad = datasets.load_dataset('squad')
squad_v2 = datasets.load_dataset('squad_v2')

import random
random.seed(42)
squad_adv_selection = random.sample(range(squad_adv_addSent['validation'].num_rows), 500)
nq_selection = random.sample(range(3369), 400)
squad_selection = random.sample(range(10570), 500)
squad_v2_selection = random.sample(range(squad_v2['train'].num_rows), 500)

squad_adv_addSent_limited = squad_adv_addSent['validation'].select(squad_adv_selection)
#nq_data_limited_unformatted = nq_data['train'].select(nq_selection)
squad_limited = squad['train'].select(squad_selection)
squad_v2_limited = squad_v2['train'].select(squad_v2_selection)
# Out:
# Downloading builder script:   0%|          | 0.00/5.74k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.54k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data: 0.00B [00:00, ?B/s]
# Downloading data: 0.00B [00:00, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating validation split:   0%|          | 0/1787 [00:00<?, ? examples/s]
# Downloading builder script:   0%|          | 0.00/5.28k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.02k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/9.55M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/801k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/130319 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
from datasets import load_dataset
from tqdm import tqdm
import sys
import spacy
import numpy as np
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
import torch

# %%
raw_datasets = load_dataset('squad', split='validation')
dev_df = raw_datasets.to_pandas()
dev_df.head()
# Out:
#                          id          title  \
# 0  56be4db0acb8001400a502ec  Super_Bowl_50
# 1  56be4db0acb8001400a502ed  Super_Bowl_50
# 2  56be4db0acb8001400a502ee  Super_Bowl_50
# 3  56be4db0acb8001400a502ef  Super_Bowl_50
# 4  56be4db0acb8001400a502f0  Super_Bowl_50
#
#                                              context  \
# 0  Super Bowl 50 was an American football game to...
# 1  Super Bowl 50 was an American football game to...
# 2  Super Bowl 50 was an American football game to...
# 3  Super Bowl 50 was an American football game to...
# 4  Super Bowl 50 was an American football game to...
#
#                                             question  \
# 0  Which NFL team represented the AFC at Super Bo...
# 1  Which NFL team represented the NFC at Super Bo...
# 2                Where did Super Bowl 50 take place?
# 3                  Which NFL team won Super Bowl 50?
# 4  What color was used to emphasize the 50th anni...
#
#                                              answers
# 0  {'text': ['Denver Broncos', 'Denver Broncos', ...
# 1  {'text': ['Carolina Panthers', 'Carolina Panth...
# 2  {'text': ['Santa Clara, California', 'Levi's S...
# 3  {'text': ['Denver Broncos', 'Denver Broncos', ...
# 4  {'text': ['gold', 'gold', 'gold'], 'answer_sta...

# %% [markdown]
# # Simple Test

# %%
#1117 version

pred = lambda x: ([model({"context":x[0], "question":x[1]})['answer']], [model({"context":x[0], "question":x[1]})['score']])
testing_example = [("Samantha is slower than Jordan.","Who is less slow?")]
#old version
def predict_and_score(input):

    preds = []
    scores = []
    for i in input:
      context = i[0]
      question = i[1]
      #print(context)
      #print(question)
      pred = question_answering_pipeline(context=context, question=question)
      preds.append(pred['answer'])
      scores.append(pred['score'])
    return (preds, scores)

new_pred = PredictorWrapper.wrap_predict(predict_and_score)

# %%
#new version
#convert to lower()
def predict_and_score(examples):
    model.eval()
    predictions = []
    scores = []

    with torch.no_grad():
        for context, question in examples:
            #print(question.lower())
            inputs = tokenizer.encode_plus(question.lower(), context, add_special_tokens=True, return_tensors="pt")
            input_ids = inputs["input_ids"].tolist()[0]

            outputs = model(**inputs)
            answer_start_scores = outputs.start_logits
            answer_end_scores = outputs.end_logits

            answer_start = torch.argmax(answer_start_scores)
            answer_end = torch.argmax(answer_end_scores) + 1

            answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(input_ids[answer_start:answer_end]))
            #print("answer:"+answer)
            score = torch.max(answer_start_scores).item() + torch.max(answer_end_scores).item()
            #print(scores)
            #print(answer)
            predictions.append(answer)
            scores.append(score)

    return predictions, scores

print(predict_and_score(testing_example))

context_question_pairs = [
    ("Peter is smaller than Benjamin.", "Who is smaller?"),
    # Add more context-question pairs
]

# Get predictions and scores
predictions, scores = predict_and_score(context_question_pairs)

# Print the results
for prediction, score in zip(predictions, scores):
    print(f"Prediction: {prediction}, Score: {score}")
# Out:
# (['samantha'], [14.738270282745361])
# Prediction: peter, Score: 16.24910831451416

# %%
import checklist.editor as editor
from checklist.test_suite import TestSuite, MFT


def create_template():
    comparative_adjectives = ['old', 'smart', 'tall', 'young', 'strong', 'short', 'tough', 'cool', 'fast', 'nice', 'small', 'dark', 'wise', 'rich', 'great', 'weak', 'high', 'slow', 'strange', 'clean']
    paired_adjectives = []
    for x in comparative_adjectives:
        paired_adjectives.append((x.rstrip('er'), x))
        paired_adjectives.append((x + 'er', x))

    editor_instance = editor.Editor()

    templates = [
        (
            '{first_name} is {adj[0]}er than {first_name1}.',
            'Who is less {adj[1]}?'
        ),
        (
            '{first_name} is {adj[0]}er than {first_name1}.',
            'Who is {adj[0]}er?'
        )
    ]

    template_data = {
        'adj': paired_adjectives,
        'remove_duplicates': True,
        'nsamples': 50,
        'save': True
    }

    return editor_instance.template(templates, labels=['{first_name1}', '{first_name}'], **template_data)



def format_squad_with_context(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'C: %s\nQ: %s\n' % (c, q)
    if label is not None:
        ret += 'A: %s\n' % label.lower()
    ret += 'P: %s\n' % pred.lower()
    return ret

def run_test():
    template = create_template()
    suite = TestSuite()
    name = 'A is COMP than B. Who is more / less COMP?'
    description = ''
    test = MFT(**template, name=name, description=description, capability='Vocabulary')
    test.run(predict_and_score)
    test.summary(n=3, format_example_fn=format_squad_with_context)
    suite.add(test, overwrite=True)
    run_test()
run_test()
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#
# Example fails:
# C: Roy is higherer than Howard.
# Q: Who is higherer?
# A: roy
# P: roy
#
# C: Roy is higherer than Howard.
# Q: Who is less high?
# A: howard
# P: roy
#
#
# ----
# C: Steven is tougherer than Arthur.
# Q: Who is tougherer?
# A: steven
# P: steven
#
# C: Steven is tougherer than Arthur.
# Q: Who is less tough?
# A: arthur
# P: arthur
#
#
# ----
# C: Donna is taller than Daniel.
# Q: Who is taller?
# A: donna
# P: donna
#
# C: Donna is taller than Daniel.
# Q: Who is less tall?
# A: daniel
# P: daniel
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Ann is darker than Maria.
# Q: Who is darker?
# A: ann
# P: ann
#
# C: Ann is darker than Maria.
# Q: Who is less dark?
# A: maria
# P: maria
#
#
# ----
# C: Janet is strongerer than Eric.
# Q: Who is strongerer?
# A: janet
# P: janet
#
# C: Janet is strongerer than Eric.
# Q: Who is less strong?
# A: eric
# P: eric
#
#
# ----
# C: Ian is older than Louise.
# Q: Who is older?
# A: ian
# P: ian
#
# C: Ian is older than Louise.
# Q: Who is less old?
# A: louise
# P: louise
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Lynn is tallerer than Daniel.
# Q: Who is tallerer?
# A: lynn
# P: lynn
#
# C: Lynn is tallerer than Daniel.
# Q: Who is less tall?
# A: daniel
# P: daniel
#
#
# ----
# C: Don is nicer than Joseph.
# Q: Who is nicer?
# A: don
# P: don
#
# C: Don is nicer than Joseph.
# Q: Who is less nice?
# A: joseph
# P: don
#
#
# ----
# C: Andrea is cleaner than Mike.
# Q: Who is cleaner?
# A: andrea
# P: andrea
#
# C: Andrea is cleaner than Mike.
# Q: Who is less clean?
# A: mike
# P: mike
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Simon is tougher than Dick.
# Q: Who is tougher?
# A: simon
# P: simon
#
# C: Simon is tougher than Dick.
# Q: Who is less tough?
# A: dick
# P: dick
#
#
# ----
# C: Adam is higher than Amy.
# Q: Who is higher?
# A: adam
# P: adam
#
# C: Adam is higher than Amy.
# Q: Who is less high?
# A: amy
# P: amy
#
#
# ----
# C: Lynn is coolerer than Suzanne.
# Q: Who is coolerer?
# A: lynn
# P: lynn
#
# C: Lynn is coolerer than Suzanne.
# Q: Who is less cool?
# A: suzanne
# P: lynn
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Frederick is cleaner than Dave.
# Q: Who is cleaner?
# A: frederick
# P: frederick
#
# C: Frederick is cleaner than Dave.
# Q: Who is less clean?
# A: dave
# P: dave
#
#
# ----
# C: Dorothy is greaterer than Francis.
# Q: Who is greaterer?
# A: dorothy
# P: dorothy
#
# C: Dorothy is greaterer than Francis.
# Q: Who is less great?
# A: francis
# P: dorothy
#
#
# ----
# C: Kate is higher than Diana.
# Q: Who is higher?
# A: kate
# P: kate
#
# C: Kate is higher than Diana.
# Q: Who is less high?
# A: diana
# P: diana
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Susan is richer than Bill.
# Q: Who is richer?
# A: susan
# P: susan
#
# C: Susan is richer than Bill.
# Q: Who is less rich?
# A: bill
# P: bill
#
#
# ----
# C: Diane is niceerer than Mike.
# Q: Who is niceerer?
# A: diane
# P: diane
#
# C: Diane is niceerer than Mike.
# Q: Who is less nice?
# A: mike
# P: mike
#
#
# ----
# C: Kenneth is tougherer than Maria.
# Q: Who is tougherer?
# A: kenneth
# P: kenneth
#
# C: Kenneth is tougherer than Maria.
# Q: Who is less tough?
# A: maria
# P: maria
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Betty is coolerer than Jill.
# Q: Who is less cool?
# A: jill
# P: betty
#
# C: Betty is coolerer than Jill.
# Q: Who is coolerer?
# A: betty
# P: betty
#
#
# ----
# C: Keith is smarter than Peter.
# Q: Who is smarter?
# A: keith
# P: keith
#
# C: Keith is smarter than Peter.
# Q: Who is less smart?
# A: peter
# P: peter
#
#
# ----
# C: Judith is stranger than Kathleen.
# Q: Who is less strange?
# A: kathleen
# P: judith
#
# C: Judith is stranger than Kathleen.
# Q: Who is stranger?
# A: judith
# P: judith
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Samuel is stranger than Ed.
# Q: Who is less strange?
# A: ed
# P: samuel
#
# C: Samuel is stranger than Ed.
# Q: Who is stranger?
# A: samuel
# P: samuel
#
#
# ----
# C: Kate is cleaner than Gary.
# Q: Who is cleaner?
# A: kate
# P: kate
#
# C: Kate is cleaner than Gary.
# Q: Who is less clean?
# A: gary
# P: gary
#
#
# ----
# C: Alfred is wiser than Kenneth.
# Q: Who is wiser?
# A: alfred
# P: alfred
#
# C: Alfred is wiser than Kenneth.
# Q: Who is less wise?
# A: kenneth
# P: kenneth
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Mark is nicer than Carl.
# Q: Who is nicer?
# A: mark
# P: mark
#
# C: Mark is nicer than Carl.
# Q: Who is less nice?
# A: carl
# P: mark
#
#
# ----
# C: Simon is darker than Harriet.
# Q: Who is darker?
# A: simon
# P: simon
#
# C: Simon is darker than Harriet.
# Q: Who is less dark?
# A: harriet
# P: harriet
#
#
# ----
# C: Anthony is shorter than Mike.
# Q: Who is shorter?
# A: anthony
# P: anthony
#
# C: Anthony is shorter than Mike.
# Q: Who is less short?
# A: mike
# P: mike
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Alice is niceerer than Pamela.
# Q: Who is niceerer?
# A: alice
# P: alice
#
# C: Alice is niceerer than Pamela.
# Q: Who is less nice?
# A: pamela
# P: alice
#
#
# ----
# C: Joseph is greaterer than Charles.
# Q: Who is greaterer?
# A: joseph
# P: joseph
#
# C: Joseph is greaterer than Charles.
# Q: Who is less great?
# A: charles
# P: joseph
#
#
# ----
# C: Carl is higherer than Dorothy.
# Q: Who is less high?
# A: dorothy
# P: carl
#
# C: Carl is higherer than Dorothy.
# Q: Who is higherer?
# A: carl
# P: carl
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Patrick is tallerer than Philip.
# Q: Who is tallerer?
# A: patrick
# P: patrick
#
# C: Patrick is tallerer than Philip.
# Q: Who is less tall?
# A: philip
# P: philip
#
#
# ----
# C: Victoria is younger than Karen.
# Q: Who is younger?
# A: victoria
# P: victoria
#
# C: Victoria is younger than Karen.
# Q: Who is less young?
# A: karen
# P: karen
#
#
# ----
# C: Heather is tougherer than Bobby.
# Q: Who is tougherer?
# A: heather
# P: heather
#
# C: Heather is tougherer than Bobby.
# Q: Who is less tough?
# A: bobby
# P: bobby
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Arthur is tougher than Frederick.
# Q: Who is tougher?
# A: arthur
# P: arthur
#
# C: Arthur is tougher than Frederick.
# Q: Who is less tough?
# A: frederick
# P: frederick
#
#
# ----
# C: Jim is shorterer than Stephanie.
# Q: Who is shorterer?
# A: jim
# P: jim
#
# C: Jim is shorterer than Stephanie.
# Q: Who is less short?
# A: stephanie
# P: jim
#
#
# ----
# C: Ellen is greaterer than Charles.
# Q: Who is greaterer?
# A: ellen
# P: ellen
#
# C: Ellen is greaterer than Charles.
# Q: Who is less great?
# A: charles
# P: charles
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Louis is strongerer than Howard.
# Q: Who is strongerer?
# A: louis
# P: louis
#
# C: Louis is strongerer than Howard.
# Q: Who is less strong?
# A: howard
# P: howard
#
#
# ----
# C: Stephen is wiseerer than Philip.
# Q: Who is wiseerer?
# A: stephen
# P: stephen
#
# C: Stephen is wiseerer than Philip.
# Q: Who is less wise?
# A: philip
# P: stephen
#
#
# ----
# C: Kathryn is nicer than Johnny.
# Q: Who is nicer?
# A: kathryn
# P: kathryn
#
# C: Kathryn is nicer than Johnny.
# Q: Who is less nice?
# A: johnny
# P: kathryn
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Alan is weakerer than Emma.
# Q: Who is weakerer?
# A: alan
# P: alan
#
# C: Alan is weakerer than Emma.
# Q: Who is less weak?
# A: emma
# P: alan
#
#
# ----
# C: Diana is faster than Alice.
# Q: Who is faster?
# A: diana
# P: diana
#
# C: Diana is faster than Alice.
# Q: Who is less fast?
# A: alice
# P: alice
#
#
# ----
# C: Kenneth is cleanerer than Brian.
# Q: Who is cleanerer?
# A: kenneth
# P: kenneth
#
# C: Kenneth is cleanerer than Brian.
# Q: Who is less clean?
# A: brian
# P: brian
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Donna is wiser than Ron.
# Q: Who is wiser?
# A: donna
# P: donna
#
# C: Donna is wiser than Ron.
# Q: Who is less wise?
# A: ron
# P: ron
#
#
# ----
# C: Lucy is youngerer than Walter.
# Q: Who is youngerer?
# A: lucy
# P: lucy
#
# C: Lucy is youngerer than Walter.
# Q: Who is less young?
# A: walter
# P: lucy
#
#
# ----
# C: Katherine is darker than Carl.
# Q: Who is darker?
# A: katherine
# P: katherine
#
# C: Katherine is darker than Carl.
# Q: Who is less dark?
# A: carl
# P: carl
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Gary is niceerer than Andrea.
# Q: Who is niceerer?
# A: gary
# P: gary
#
# C: Gary is niceerer than Andrea.
# Q: Who is less nice?
# A: andrea
# P: gary is niceerer than andrea
#
#
# ----
# C: Sara is smarter than Anna.
# Q: Who is smarter?
# A: sara
# P: sara
#
# C: Sara is smarter than Anna.
# Q: Who is less smart?
# A: anna
# P: anna
#
#
# ----
# C: Sandra is strongerer than Heather.
# Q: Who is strongerer?
# A: sandra
# P: sandra
#
# C: Sandra is strongerer than Heather.
# Q: Who is less strong?
# A: heather
# P: sandra
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Kenneth is cleaner than Katherine.
# Q: Who is cleaner?
# A: kenneth
# P: kenneth
#
# C: Kenneth is cleaner than Katherine.
# Q: Who is less clean?
# A: katherine
# P: katherine
#
#
# ----
# C: Anthony is tallerer than Margaret.
# Q: Who is tallerer?
# A: anthony
# P: anthony
#
# C: Anthony is tallerer than Margaret.
# Q: Who is less tall?
# A: margaret
# P: margaret
#
#
# ----
# C: Michelle is tougher than Margaret.
# Q: Who is tougher?
# A: michelle
# P: michelle
#
# C: Michelle is tougher than Margaret.
# Q: Who is less tough?
# A: margaret
# P: margaret
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Alex is faster than Mary.
# Q: Who is faster?
# A: alex
# P: alex
#
# C: Alex is faster than Mary.
# Q: Who is less fast?
# A: mary
# P: mary
#
#
# ----
# C: Sam is higherer than Robin.
# Q: Who is higherer?
# A: sam
# P: sam
#
# C: Sam is higherer than Robin.
# Q: Who is less high?
# A: robin
# P: sam
#
#
# ----
# C: Thomas is weakerer than Simon.
# Q: Who is weakerer?
# A: thomas
# P: thomas
#
# C: Thomas is weakerer than Simon.
# Q: Who is less weak?
# A: simon
# P: thomas
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Ben is smarterer than Ed.
# Q: Who is smarterer?
# A: ben
# P: ben
#
# C: Ben is smarterer than Ed.
# Q: Who is less smart?
# A: ed
# P: ed
#
#
# ----
# C: Ken is older than Albert.
# Q: Who is older?
# A: ken
# P: ken
#
# C: Ken is older than Albert.
# Q: Who is less old?
# A: albert
# P: albert
#
#
# ----
# C: John is slower than Ralph.
# Q: Who is slower?
# A: john
# P: john
#
# C: John is slower than Ralph.
# Q: Who is less slow?
# A: ralph
# P: ralph
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Julie is wiseerer than Peter.
# Q: Who is wiseerer?
# A: julie
# P: julie
#
# C: Julie is wiseerer than Peter.
# Q: Who is less wise?
# A: peter
# P: peter
#
#
# ----
# C: Kathy is greater than Sara.
# Q: Who is greater?
# A: kathy
# P: kathy
#
# C: Kathy is greater than Sara.
# Q: Who is less great?
# A: sara
# P: sara
#
#
# ----
# C: George is smallerer than Roger.
# Q: Who is smallerer?
# A: george
# P: george
#
# C: George is smallerer than Roger.
# Q: Who is less small?
# A: roger
# P: roger
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Ann is niceerer than Frederick.
# Q: Who is niceerer?
# A: ann
# P: ann
#
# C: Ann is niceerer than Frederick.
# Q: Who is less nice?
# A: frederick
# P: frederick
#
#
# ----
# C: Stephen is wiser than Frances.
# Q: Who is wiser?
# A: stephen
# P: stephen
#
# C: Stephen is wiser than Frances.
# Q: Who is less wise?
# A: frances
# P: frances
#
#
# ----
# C: Christine is fasterer than Victoria.
# Q: Who is fasterer?
# A: christine
# P: christine
#
# C: Christine is fasterer than Victoria.
# Q: Who is less fast?
# A: victoria
# P: christine
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Harriet is stronger than Jonathan.
# Q: Who is stronger?
# A: harriet
# P: harriet
#
# C: Harriet is stronger than Jonathan.
# Q: Who is less strong?
# A: jonathan
# P: jonathan
#
#
# ----
# C: Annie is stronger than Greg.
# Q: Who is stronger?
# A: annie
# P: annie
#
# C: Annie is stronger than Greg.
# Q: Who is less strong?
# A: greg
# P: greg
#
#
# ----
# C: Sue is coolerer than Roy.
# Q: Who is less cool?
# A: roy
# P: sue
#
# C: Sue is coolerer than Roy.
# Q: Who is coolerer?
# A: sue
# P: sue
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Stephen is tougherer than Sharon.
# Q: Who is tougherer?
# A: stephen
# P: stephen
#
# C: Stephen is tougherer than Sharon.
# Q: Who is less tough?
# A: sharon
# P: sharon
#
#
# ----
# C: Patricia is higherer than Claire.
# Q: Who is less high?
# A: claire
# P: patricia
#
# C: Patricia is higherer than Claire.
# Q: Who is higherer?
# A: patricia
# P: patricia
#
#
# ----
# C: Leslie is cooler than Ann.
# Q: Who is less cool?
# A: ann
# P: leslie
#
# C: Leslie is cooler than Ann.
# Q: Who is cooler?
# A: leslie
# P: leslie
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Sara is smarterer than Nicole.
# Q: Who is smarterer?
# A: sara
# P: sara
#
# C: Sara is smarterer than Nicole.
# Q: Who is less smart?
# A: nicole
# P: nicole
#
#
# ----
# C: Bruce is slower than Ellen.
# Q: Who is slower?
# A: bruce
# P: bruce
#
# C: Bruce is slower than Ellen.
# Q: Who is less slow?
# A: ellen
# P: ellen
#
#
# ----
# C: Carolyn is cooler than Margaret.
# Q: Who is less cool?
# A: margaret
# P: carolyn
#
# C: Carolyn is cooler than Margaret.
# Q: Who is cooler?
# A: carolyn
# P: carolyn
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Sarah is older than Jennifer.
# Q: Who is older?
# A: sarah
# P: sarah
#
# C: Sarah is older than Jennifer.
# Q: Who is less old?
# A: jennifer
# P: jennifer
#
#
# ----
# C: Jimmy is weakerer than Kelly.
# Q: Who is weakerer?
# A: jimmy
# P: jimmy
#
# C: Jimmy is weakerer than Kelly.
# Q: Who is less weak?
# A: kelly
# P: jimmy
#
#
# ----
# C: Charlotte is shorter than Maria.
# Q: Who is shorter?
# A: charlotte
# P: charlotte
#
# C: Charlotte is shorter than Maria.
# Q: Who is less short?
# A: maria
# P: maria
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: John is richer than Donald.
# Q: Who is richer?
# A: john
# P: john
#
# C: John is richer than Donald.
# Q: Who is less rich?
# A: donald
# P: donald
#
#
# ----
# C: Sandra is wiseerer than Melissa.
# Q: Who is wiseerer?
# A: sandra
# P: sandra
#
# C: Sandra is wiseerer than Melissa.
# Q: Who is less wise?
# A: melissa
# P: melissa
#
#
# ----
# C: Andrew is slower than Amy.
# Q: Who is slower?
# A: andrew
# P: andrew
#
# C: Andrew is slower than Amy.
# Q: Who is less slow?
# A: amy
# P: amy
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Ben is richer than Fred.
# Q: Who is richer?
# A: ben
# P: ben
#
# C: Ben is richer than Fred.
# Q: Who is less rich?
# A: fred
# P: fred
#
#
# ----
# C: Johnny is slower than Amanda.
# Q: Who is slower?
# A: johnny
# P: johnny
#
# C: Johnny is slower than Amanda.
# Q: Who is less slow?
# A: amanda
# P: amanda
#
#
# ----
# C: Kenneth is taller than Martha.
# Q: Who is taller?
# A: kenneth
# P: kenneth
#
# C: Kenneth is taller than Martha.
# Q: Who is less tall?
# A: martha
# P: martha
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Hugh is richer than William.
# Q: Who is richer?
# A: hugh
# P: hugh
#
# C: Hugh is richer than William.
# Q: Who is less rich?
# A: william
# P: william
#
#
# ----
# C: Johnny is youngerer than Martin.
# Q: Who is youngerer?
# A: johnny
# P: johnny
#
# C: Johnny is youngerer than Martin.
# Q: Who is less young?
# A: martin
# P: johnny
#
#
# ----
# C: Emma is wiser than Matt.
# Q: Who is wiser?
# A: emma
# P: emma
#
# C: Emma is wiser than Matt.
# Q: Who is less wise?
# A: matt
# P: matt
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Eric is darker than Lucy.
# Q: Who is darker?
# A: eric
# P: eric
#
# C: Eric is darker than Lucy.
# Q: Who is less dark?
# A: lucy
# P: lucy
#
#
# ----
# C: Simon is nicer than Francis.
# Q: Who is nicer?
# A: simon
# P: simon
#
# C: Simon is nicer than Francis.
# Q: Who is less nice?
# A: francis
# P: simon
#
#
# ----
# C: Emma is taller than Pamela.
# Q: Who is taller?
# A: emma
# P: emma
#
# C: Emma is taller than Pamela.
# Q: Who is less tall?
# A: pamela
# P: pamela
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Colin is youngerer than Maria.
# Q: Who is youngerer?
# A: colin
# P: colin
#
# C: Colin is youngerer than Maria.
# Q: Who is less young?
# A: maria
# P: maria
#
#
# ----
# C: Alexandra is cleanerer than Kathy.
# Q: Who is cleanerer?
# A: alexandra
# P: alexandra
#
# C: Alexandra is cleanerer than Kathy.
# Q: Who is less clean?
# A: kathy
# P: kathy
#
#
# ----
# C: Ron is smarter than Christopher.
# Q: Who is smarter?
# A: ron
# P: ron
#
# C: Ron is smarter than Christopher.
# Q: Who is less smart?
# A: christopher
# P: christopher
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Pamela is nicer than Edith.
# Q: Who is nicer?
# A: pamela
# P: pamela
#
# C: Pamela is nicer than Edith.
# Q: Who is less nice?
# A: edith
# P: pamela
#
#
# ----
# C: Thomas is greater than Betty.
# Q: Who is greater?
# A: thomas
# P: thomas
#
# C: Thomas is greater than Betty.
# Q: Who is less great?
# A: betty
# P: thomas
#
#
# ----
# C: Benjamin is wiser than Amanda.
# Q: Who is wiser?
# A: benjamin
# P: benjamin
#
# C: Benjamin is wiser than Amanda.
# Q: Who is less wise?
# A: amanda
# P: amanda
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Frederick is tougherer than Alexandra.
# Q: Who is tougherer?
# A: frederick
# P: frederick
#
# C: Frederick is tougherer than Alexandra.
# Q: Who is less tough?
# A: alexandra
# P: alexandra
#
#
# ----
# C: Ellen is higher than Arthur.
# Q: Who is higher?
# A: ellen
# P: ellen
#
# C: Ellen is higher than Arthur.
# Q: Who is less high?
# A: arthur
# P: arthur
#
#
# ----
# C: Thomas is faster than Fred.
# Q: Who is faster?
# A: thomas
# P: thomas
#
# C: Thomas is faster than Fred.
# Q: Who is less fast?
# A: fred
# P: fred
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Don is tougher than Al.
# Q: Who is tougher?
# A: don
# P: don
#
# C: Don is tougher than Al.
# Q: Who is less tough?
# A: al
# P: al
#
#
# ----
# C: Diana is stronger than Tim.
# Q: Who is stronger?
# A: diana
# P: diana
#
# C: Diana is stronger than Tim.
# Q: Who is less strong?
# A: tim
# P: tim
#
#
# ----
# C: Emily is greaterer than Donna.
# Q: Who is less great?
# A: donna
# P: emily
#
# C: Emily is greaterer than Donna.
# Q: Who is greaterer?
# A: emily
# P: emily
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Jim is strongerer than Anthony.
# Q: Who is strongerer?
# A: jim
# P: jim
#
# C: Jim is strongerer than Anthony.
# Q: Who is less strong?
# A: anthony
# P: jim
#
#
# ----
# C: Bill is stronger than Jean.
# Q: Who is stronger?
# A: bill
# P: bill
#
# C: Bill is stronger than Jean.
# Q: Who is less strong?
# A: jean
# P: jean
#
#
# ----
# C: Brian is coolerer than Sophie.
# Q: Who is coolerer?
# A: brian
# P: brian
#
# C: Brian is coolerer than Sophie.
# Q: Who is less cool?
# A: sophie
# P: brian
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Louise is strangeerer than Jimmy.
# Q: Who is strangeerer?
# A: louise
# P: louise
#
# C: Louise is strangeerer than Jimmy.
# Q: Who is less strange?
# A: jimmy
# P: jimmy
#
#
# ----
# C: Tim is smallerer than Thomas.
# Q: Who is smallerer?
# A: tim
# P: tim
#
# C: Tim is smallerer than Thomas.
# Q: Who is less small?
# A: thomas
# P: thomas
#
#
# ----
# C: Kenneth is darkerer than Anthony.
# Q: Who is darkerer?
# A: kenneth
# P: kenneth
#
# C: Kenneth is darkerer than Anthony.
# Q: Who is less dark?
# A: anthony
# P: kenneth
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Dan is smarter than Florence.
# Q: Who is smarter?
# A: dan
# P: dan
#
# C: Dan is smarter than Florence.
# Q: Who is less smart?
# A: florence
# P: florence
#
#
# ----
# C: Suzanne is coolerer than Emma.
# Q: Who is less cool?
# A: emma
# P: suzanne
#
# C: Suzanne is coolerer than Emma.
# Q: Who is coolerer?
# A: suzanne
# P: suzanne
#
#
# ----
# C: Matthew is niceerer than Sharon.
# Q: Who is niceerer?
# A: matthew
# P: matthew
#
# C: Matthew is niceerer than Sharon.
# Q: Who is less nice?
# A: sharon
# P: matthew
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Edwin is cleaner than Joan.
# Q: Who is cleaner?
# A: edwin
# P: edwin
#
# C: Edwin is cleaner than Joan.
# Q: Who is less clean?
# A: joan
# P: joan
#
#
# ----
# C: Andrew is tallerer than Sandra.
# Q: Who is tallerer?
# A: andrew
# P: andrew
#
# C: Andrew is tallerer than Sandra.
# Q: Who is less tall?
# A: sandra
# P: sandra
#
#
# ----
# C: Stephen is slowerer than Henry.
# Q: Who is slowerer?
# A: stephen
# P: stephen
#
# C: Stephen is slowerer than Henry.
# Q: Who is less slow?
# A: henry
# P: henry
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: John is wiseerer than Henry.
# Q: Who is wiseerer?
# A: john
# P: john
#
# C: John is wiseerer than Henry.
# Q: Who is less wise?
# A: henry
# P: henry
#
#
# ----
# C: Jonathan is stronger than Sally.
# Q: Who is stronger?
# A: jonathan
# P: jonathan
#
# C: Jonathan is stronger than Sally.
# Q: Who is less strong?
# A: sally
# P: sally
#
#
# ----
# C: Lucy is cleanerer than Steve.
# Q: Who is cleanerer?
# A: lucy
# P: lucy
#
# C: Lucy is cleanerer than Steve.
# Q: Who is less clean?
# A: steve
# P: steve
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Dave is olderer than Amanda.
# Q: Who is less old?
# A: amanda
# P: dave
#
# C: Dave is olderer than Amanda.
# Q: Who is olderer?
# A: dave
# P: dave
#
#
# ----
# C: Martin is smarterer than Donald.
# Q: Who is smarterer?
# A: martin
# P: martin
#
# C: Martin is smarterer than Donald.
# Q: Who is less smart?
# A: donald
# P: donald
#
#
# ----
# C: Ruth is greaterer than Amy.
# Q: Who is greaterer?
# A: ruth
# P: ruth
#
# C: Ruth is greaterer than Amy.
# Q: Who is less great?
# A: amy
# P: ruth
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Wendy is stronger than Karen.
# Q: Who is stronger?
# A: wendy
# P: wendy
#
# C: Wendy is stronger than Karen.
# Q: Who is less strong?
# A: karen
# P: karen
#
#
# ----
# C: Melissa is stronger than Albert.
# Q: Who is stronger?
# A: melissa
# P: melissa
#
# C: Melissa is stronger than Albert.
# Q: Who is less strong?
# A: albert
# P: albert
#
#
# ----
# C: Francis is smaller than Kathy.
# Q: Who is smaller?
# A: francis
# P: francis
#
# C: Francis is smaller than Kathy.
# Q: Who is less small?
# A: kathy
# P: kathy
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Scott is greater than Arthur.
# Q: Who is greater?
# A: scott
# P: scott
#
# C: Scott is greater than Arthur.
# Q: Who is less great?
# A: arthur
# P: scott
#
#
# ----
# C: Bruce is strongerer than Jason.
# Q: Who is strongerer?
# A: bruce
# P: bruce
#
# C: Bruce is strongerer than Jason.
# Q: Who is less strong?
# A: jason
# P: bruce
#
#
# ----
# C: Marilyn is cooler than Diane.
# Q: Who is less cool?
# A: diane
# P: marilyn
#
# C: Marilyn is cooler than Diane.
# Q: Who is cooler?
# A: marilyn
# P: marilyn
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Diana is smallerer than Ellen.
# Q: Who is smallerer?
# A: diana
# P: diana
#
# C: Diana is smallerer than Ellen.
# Q: Who is less small?
# A: ellen
# P: ellen
#
#
# ----
# C: Julie is smarter than Nancy.
# Q: Who is smarter?
# A: julie
# P: julie
#
# C: Julie is smarter than Nancy.
# Q: Who is less smart?
# A: nancy
# P: nancy
#
#
# ----
# C: Anthony is stronger than Sharon.
# Q: Who is stronger?
# A: anthony
# P: anthony
#
# C: Anthony is stronger than Sharon.
# Q: Who is less strong?
# A: sharon
# P: sharon
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Harriet is wiseerer than Dorothy.
# Q: Who is wiseerer?
# A: harriet
# P: harriet
#
# C: Harriet is wiseerer than Dorothy.
# Q: Who is less wise?
# A: dorothy
# P: dorothy
#
#
# ----
# C: Mary is youngerer than Amanda.
# Q: Who is youngerer?
# A: mary
# P: mary
#
# C: Mary is youngerer than Amanda.
# Q: Who is less young?
# A: amanda
# P: mary
#
#
# ----
# C: Emma is weakerer than Dave.
# Q: Who is weakerer?
# A: emma
# P: emma
#
# C: Emma is weakerer than Dave.
# Q: Who is less weak?
# A: dave
# P: emma
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Diana is older than Judy.
# Q: Who is older?
# A: diana
# P: diana
#
# C: Diana is older than Judy.
# Q: Who is less old?
# A: judy
# P: judy
#
#
# ----
# C: Donna is smarterer than Helen.
# Q: Who is smarterer?
# A: donna
# P: donna
#
# C: Donna is smarterer than Helen.
# Q: Who is less smart?
# A: helen
# P: helen
#
#
# ----
# C: Ashley is greaterer than Alex.
# Q: Who is greaterer?
# A: ashley
# P: ashley
#
# C: Ashley is greaterer than Alex.
# Q: Who is less great?
# A: alex
# P: ashley
#
#
# ----
# Predicting 96 examples
# Test cases:      48
# Fails (rate):    48 (100.0%)
#
# Example fails:
# C: Emma is older than Sandra.
# Q: Who is older?
# A: emma
# P: emma
#
# C: Emma is older than Sandra.
# Q: Who is less old?
# A: sandra
# P: sandra
#
#
# ----
# C: Anthony is slower than Bobby.
# Q: Who is slower?
# A: anthony
# P: anthony
#
# C: Anthony is slower than Bobby.
# Q: Who is less slow?
# A: bobby
# P: bobby
#
#
# ----
# C: Suzanne is tougher than Emily.
# Q: Who is tougher?
# A: suzanne
# P: suzanne
#
# C: Suzanne is tougher than Emily.
# Q: Who is less tough?
# A: emily
# P: emily
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Alexander is fasterer than Frank.
# Q: Who is fasterer?
# A: alexander
# P: alexander
#
# C: Alexander is fasterer than Frank.
# Q: Who is less fast?
# A: frank
# P: alexander
#
#
# ----
# C: Larry is faster than Tim.
# Q: Who is faster?
# A: larry
# P: larry
#
# C: Larry is faster than Tim.
# Q: Who is less fast?
# A: tim
# P: tim
#
#
# ----
# C: John is richer than Alan.
# Q: Who is richer?
# A: john
# P: john
#
# C: John is richer than Alan.
# Q: Who is less rich?
# A: alan
# P: alan
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Ryan is younger than Stephen.
# Q: Who is younger?
# A: ryan
# P: ryan
#
# C: Ryan is younger than Stephen.
# Q: Who is less young?
# A: stephen
# P: stephen
#
#
# ----
# C: Eric is darkerer than Sara.
# Q: Who is darkerer?
# A: eric
# P: eric
#
# C: Eric is darkerer than Sara.
# Q: Who is less dark?
# A: sara
# P: eric
#
#
# ----
# C: Nicole is smarter than Andrew.
# Q: Who is smarter?
# A: nicole
# P: nicole
#
# C: Nicole is smarter than Andrew.
# Q: Who is less smart?
# A: andrew
# P: andrew
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Lucy is strongerer than Harry.
# Q: Who is strongerer?
# A: lucy
# P: lucy
#
# C: Lucy is strongerer than Harry.
# Q: Who is less strong?
# A: harry
# P: harry
#
#
# ----
# C: Frances is smarterer than Martin.
# Q: Who is smarterer?
# A: frances
# P: frances
#
# C: Frances is smarterer than Martin.
# Q: Who is less smart?
# A: martin
# P: martin
#
#
# ----
# C: Lynn is richer than Stephen.
# Q: Who is richer?
# A: lynn
# P: lynn
#
# C: Lynn is richer than Stephen.
# Q: Who is less rich?
# A: stephen
# P: stephen
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Sarah is darkerer than Steven.
# Q: Who is darkerer?
# A: sarah
# P: sarah
#
# C: Sarah is darkerer than Steven.
# Q: Who is less dark?
# A: steven
# P: sarah
#
#
# ----
# C: Kim is smarterer than Frank.
# Q: Who is smarterer?
# A: kim
# P: kim
#
# C: Kim is smarterer than Frank.
# Q: Who is less smart?
# A: frank
# P: frank
#
#
# ----
# C: Jack is wiseerer than Kim.
# Q: Who is wiseerer?
# A: jack
# P: jack
#
# C: Jack is wiseerer than Kim.
# Q: Who is less wise?
# A: kim
# P: kim
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Dan is richerer than Diane.
# Q: Who is less rich?
# A: diane
# P: dan
#
# C: Dan is richerer than Diane.
# Q: Who is richerer?
# A: dan
# P: dan
#
#
# ----
# C: Kenneth is nicer than Ben.
# Q: Who is nicer?
# A: kenneth
# P: kenneth
#
# C: Kenneth is nicer than Ben.
# Q: Who is less nice?
# A: ben
# P: kenneth
#
#
# ----
# C: Larry is stronger than Roger.
# Q: Who is stronger?
# A: larry
# P: larry
#
# C: Larry is stronger than Roger.
# Q: Who is less strong?
# A: roger
# P: roger
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Nancy is fasterer than Joseph.
# Q: Who is fasterer?
# A: nancy
# P: nancy
#
# C: Nancy is fasterer than Joseph.
# Q: Who is less fast?
# A: joseph
# P: nancy
#
#
# ----
# C: Thomas is shorterer than Alfred.
# Q: Who is shorterer?
# A: thomas
# P: thomas
#
# C: Thomas is shorterer than Alfred.
# Q: Who is less short?
# A: alfred
# P: alfred
#
#
# ----
# C: Mark is slowerer than Catherine.
# Q: Who is slowerer?
# A: mark
# P: mark
#
# C: Mark is slowerer than Catherine.
# Q: Who is less slow?
# A: catherine
# P: catherine
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Susan is niceerer than Colin.
# Q: Who is niceerer?
# A: susan
# P: susan
#
# C: Susan is niceerer than Colin.
# Q: Who is less nice?
# A: colin
# P: susan
#
#
# ----
# C: Patrick is shorter than Sara.
# Q: Who is shorter?
# A: patrick
# P: patrick
#
# C: Patrick is shorter than Sara.
# Q: Who is less short?
# A: sara
# P: sara
#
#
# ----
# C: Greg is cleaner than Florence.
# Q: Who is cleaner?
# A: greg
# P: greg
#
# C: Greg is cleaner than Florence.
# Q: Who is less clean?
# A: florence
# P: florence
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Mark is youngerer than Jerry.
# Q: Who is youngerer?
# A: mark
# P: mark
#
# C: Mark is youngerer than Jerry.
# Q: Who is less young?
# A: jerry
# P: mark
#
#
# ----
# C: Harriet is smallerer than Sally.
# Q: Who is smallerer?
# A: harriet
# P: harriet
#
# C: Harriet is smallerer than Sally.
# Q: Who is less small?
# A: sally
# P: sally
#
#
# ----
# C: Chris is slowerer than Charles.
# Q: Who is slowerer?
# A: chris
# P: chris
#
# C: Chris is slowerer than Charles.
# Q: Who is less slow?
# A: charles
# P: charles
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Suzanne is slowerer than Ralph.
# Q: Who is slowerer?
# A: suzanne
# P: suzanne
#
# C: Suzanne is slowerer than Ralph.
# Q: Who is less slow?
# A: ralph
# P: ralph
#
#
# ----
# C: Scott is shorter than Joan.
# Q: Who is shorter?
# A: scott
# P: scott
#
# C: Scott is shorter than Joan.
# Q: Who is less short?
# A: joan
# P: joan
#
#
# ----
# C: Mary is cleaner than Edwin.
# Q: Who is cleaner?
# A: mary
# P: mary
#
# C: Mary is cleaner than Edwin.
# Q: Who is less clean?
# A: edwin
# P: edwin
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Emma is olderer than Helen.
# Q: Who is olderer?
# A: emma
# P: emma
#
# C: Emma is olderer than Helen.
# Q: Who is less old?
# A: helen
# P: emma
#
#
# ----
# C: Billy is fasterer than Ray.
# Q: Who is fasterer?
# A: billy
# P: billy
#
# C: Billy is fasterer than Ray.
# Q: Who is less fast?
# A: ray
# P: billy
#
#
# ----
# C: Karen is slowerer than Sally.
# Q: Who is slowerer?
# A: karen
# P: karen
#
# C: Karen is slowerer than Sally.
# Q: Who is less slow?
# A: sally
# P: sally
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Eric is older than Betty.
# Q: Who is older?
# A: eric
# P: eric
#
# C: Eric is older than Betty.
# Q: Who is less old?
# A: betty
# P: betty
#
#
# ----
# C: Harold is shorterer than Victoria.
# Q: Who is shorterer?
# A: harold
# P: harold
#
# C: Harold is shorterer than Victoria.
# Q: Who is less short?
# A: victoria
# P: victoria
#
#
# ----
# C: Robert is youngerer than Deborah.
# Q: Who is youngerer?
# A: robert
# P: robert
#
# C: Robert is youngerer than Deborah.
# Q: Who is less young?
# A: deborah
# P: robert
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Catherine is shorter than Harold.
# Q: Who is shorter?
# A: catherine
# P: catherine
#
# C: Catherine is shorter than Harold.
# Q: Who is less short?
# A: harold
# P: harold
#
#
# ----
# C: Laura is strangeerer than Kathryn.
# Q: Who is strangeerer?
# A: laura
# P: laura
#
# C: Laura is strangeerer than Kathryn.
# Q: Who is less strange?
# A: kathryn
# P: kathryn
#
#
# ----
# C: Alice is greaterer than Angela.
# Q: Who is greaterer?
# A: alice
# P: alice
#
# C: Alice is greaterer than Angela.
# Q: Who is less great?
# A: angela
# P: alice
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Nick is darker than Fiona.
# Q: Who is darker?
# A: nick
# P: nick
#
# C: Nick is darker than Fiona.
# Q: Who is less dark?
# A: fiona
# P: fiona
#
#
# ----
# C: Robin is strongerer than Simon.
# Q: Who is strongerer?
# A: robin
# P: robin
#
# C: Robin is strongerer than Simon.
# Q: Who is less strong?
# A: simon
# P: robin
#
#
# ----
# C: Stephen is darkerer than Sam.
# Q: Who is darkerer?
# A: stephen
# P: stephen
#
# C: Stephen is darkerer than Sam.
# Q: Who is less dark?
# A: sam
# P: stephen
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Sara is younger than Edith.
# Q: Who is younger?
# A: sara
# P: sara
#
# C: Sara is younger than Edith.
# Q: Who is less young?
# A: edith
# P: edith
#
#
# ----
# C: Sandra is smallerer than Tom.
# Q: Who is smallerer?
# A: sandra
# P: sandra
#
# C: Sandra is smallerer than Tom.
# Q: Who is less small?
# A: tom
# P: tom
#
#
# ----
# C: Ray is taller than Brian.
# Q: Who is taller?
# A: ray
# P: ray
#
# C: Ray is taller than Brian.
# Q: Who is less tall?
# A: brian
# P: brian
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Larry is cleanerer than Alice.
# Q: Who is cleanerer?
# A: larry
# P: larry
#
# C: Larry is cleanerer than Alice.
# Q: Who is less clean?
# A: alice
# P: alice
#
#
# ----
# C: Harold is strongerer than Jimmy.
# Q: Who is strongerer?
# A: harold
# P: harold
#
# C: Harold is strongerer than Jimmy.
# Q: Who is less strong?
# A: jimmy
# P: jimmy
#
#
# ----
# C: Greg is coolerer than Andrew.
# Q: Who is coolerer?
# A: greg
# P: greg
#
# C: Greg is coolerer than Andrew.
# Q: Who is less cool?
# A: andrew
# P: greg
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Stephanie is wiser than Evelyn.
# Q: Who is wiser?
# A: stephanie
# P: stephanie
#
# C: Stephanie is wiser than Evelyn.
# Q: Who is less wise?
# A: evelyn
# P: evelyn
#
#
# ----
# C: Ray is higher than Ben.
# Q: Who is higher?
# A: ray
# P: ray
#
# C: Ray is higher than Ben.
# Q: Who is less high?
# A: ben
# P: ben
#
#
# ----
# C: Ryan is slowerer than Heather.
# Q: Who is slowerer?
# A: ryan
# P: ryan
#
# C: Ryan is slowerer than Heather.
# Q: Who is less slow?
# A: heather
# P: heather
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Michelle is stranger than Gary.
# Q: Who is stranger?
# A: michelle
# P: michelle
#
# C: Michelle is stranger than Gary.
# Q: Who is less strange?
# A: gary
# P: michelle
#
#
# ----
# C: Jean is smarterer than Scott.
# Q: Who is smarterer?
# A: jean
# P: jean
#
# C: Jean is smarterer than Scott.
# Q: Who is less smart?
# A: scott
# P: jean
#
#
# ----
# C: Mary is coolerer than Betty.
# Q: Who is less cool?
# A: betty
# P: mary
#
# C: Mary is coolerer than Betty.
# Q: Who is coolerer?
# A: mary
# P: mary
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Albert is tallerer than Heather.
# Q: Who is tallerer?
# A: albert
# P: albert
#
# C: Albert is tallerer than Heather.
# Q: Who is less tall?
# A: heather
# P: heather
#
#
# ----
# C: Suzanne is weakerer than Bill.
# Q: Who is weakerer?
# A: suzanne
# P: suzanne
#
# C: Suzanne is weakerer than Bill.
# Q: Who is less weak?
# A: bill
# P: suzanne
#
#
# ----
# C: Diane is older than Ashley.
# Q: Who is older?
# A: diane
# P: diane
#
# C: Diane is older than Ashley.
# Q: Who is less old?
# A: ashley
# P: ashley
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Ian is wiseerer than Mike.
# Q: Who is wiseerer?
# A: ian
# P: ian
#
# C: Ian is wiseerer than Mike.
# Q: Who is less wise?
# A: mike
# P: mike
#
#
# ----
# C: Jerry is niceerer than Helen.
# Q: Who is niceerer?
# A: jerry
# P: jerry
#
# C: Jerry is niceerer than Helen.
# Q: Who is less nice?
# A: helen
# P: jerry
#
#
# ----
# C: Sara is slower than Jean.
# Q: Who is slower?
# A: sara
# P: sara
#
# C: Sara is slower than Jean.
# Q: Who is less slow?
# A: jean
# P: jean
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Judy is cleanerer than Marilyn.
# Q: Who is cleanerer?
# A: judy
# P: judy
#
# C: Judy is cleanerer than Marilyn.
# Q: Who is less clean?
# A: marilyn
# P: marilyn
#
#
# ----
# C: Sharon is richerer than Diane.
# Q: Who is less rich?
# A: diane
# P: sharon
#
# C: Sharon is richerer than Diane.
# Q: Who is richerer?
# A: sharon
# P: sharon
#
#
# ----
# C: Sophie is cooler than Keith.
# Q: Who is less cool?
# A: keith
# P: sophie
#
# C: Sophie is cooler than Keith.
# Q: Who is cooler?
# A: sophie
# P: sophie
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Johnny is smarter than Dan.
# Q: Who is smarter?
# A: johnny
# P: johnny
#
# C: Johnny is smarter than Dan.
# Q: Who is less smart?
# A: dan
# P: dan
#
#
# ----
# C: Jim is richer than Leslie.
# Q: Who is richer?
# A: jim
# P: jim
#
# C: Jim is richer than Leslie.
# Q: Who is less rich?
# A: leslie
# P: leslie
#
#
# ----
# C: Eric is smarterer than Lucy.
# Q: Who is smarterer?
# A: eric
# P: eric
#
# C: Eric is smarterer than Lucy.
# Q: Who is less smart?
# A: lucy
# P: eric is smarterer than lucy
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Kevin is faster than Matt.
# Q: Who is faster?
# A: kevin
# P: kevin
#
# C: Kevin is faster than Matt.
# Q: Who is less fast?
# A: matt
# P: matt
#
#
# ----
# C: Paul is higherer than Emma.
# Q: Who is less high?
# A: emma
# P: paul
#
# C: Paul is higherer than Emma.
# Q: Who is higherer?
# A: paul
# P: paul
#
#
# ----
# C: Thomas is tallerer than Florence.
# Q: Who is tallerer?
# A: thomas
# P: thomas
#
# C: Thomas is tallerer than Florence.
# Q: Who is less tall?
# A: florence
# P: florence
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Keith is fasterer than Diane.
# Q: Who is less fast?
# A: diane
# P: keith
#
# C: Keith is fasterer than Diane.
# Q: Who is fasterer?
# A: keith
# P: keith
#
#
# ----
# C: Alison is nicer than Lucy.
# Q: Who is nicer?
# A: alison
# P: alison
#
# C: Alison is nicer than Lucy.
# Q: Who is less nice?
# A: lucy
# P: alison
#
#
# ----
# C: Jill is nicer than Edith.
# Q: Who is nicer?
# A: jill
# P: jill
#
# C: Jill is nicer than Edith.
# Q: Who is less nice?
# A: edith
# P: edith
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Matt is older than Matthew.
# Q: Who is older?
# A: matt
# P: matt
#
# C: Matt is older than Matthew.
# Q: Who is less old?
# A: matthew
# P: matthew
#
#
# ----
# C: Betty is wiser than Ann.
# Q: Who is wiser?
# A: betty
# P: betty
#
# C: Betty is wiser than Ann.
# Q: Who is less wise?
# A: ann
# P: ann
#
#
# ----
# C: Sam is smaller than Victoria.
# Q: Who is smaller?
# A: sam
# P: sam
#
# C: Sam is smaller than Victoria.
# Q: Who is less small?
# A: victoria
# P: victoria
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Caroline is youngerer than Jeff.
# Q: Who is youngerer?
# A: caroline
# P: caroline
#
# C: Caroline is youngerer than Jeff.
# Q: Who is less young?
# A: jeff
# P: caroline
#
#
# ----
# C: Donna is cleaner than Edith.
# Q: Who is cleaner?
# A: donna
# P: donna
#
# C: Donna is cleaner than Edith.
# Q: Who is less clean?
# A: edith
# P: edith
#
#
# ----
# C: Paul is richer than Anna.
# Q: Who is richer?
# A: paul
# P: paul
#
# C: Paul is richer than Anna.
# Q: Who is less rich?
# A: anna
# P: anna
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Philip is richer than Mike.
# Q: Who is richer?
# A: philip
# P: philip
#
# C: Philip is richer than Mike.
# Q: Who is less rich?
# A: mike
# P: mike
#
#
# ----
# C: Barbara is tougher than Sophie.
# Q: Who is tougher?
# A: barbara
# P: barbara
#
# C: Barbara is tougher than Sophie.
# Q: Who is less tough?
# A: sophie
# P: sophie
#
#
# ----
# C: Jim is wiseerer than Alan.
# Q: Who is wiseerer?
# A: jim
# P: jim
#
# C: Jim is wiseerer than Alan.
# Q: Who is less wise?
# A: alan
# P: jim
#
#
# ----
# Predicting 96 examples
# Test cases:      48
# Fails (rate):    48 (100.0%)
#
# Example fails:
# C: Jimmy is higherer than Howard.
# Q: Who is higherer?
# A: jimmy
# P: jimmy
#
# C: Jimmy is higherer than Howard.
# Q: Who is less high?
# A: howard
# P: jimmy
#
#
# ----
# C: Kate is stranger than Pamela.
# Q: Who is stranger?
# A: kate
# P: kate
#
# C: Kate is stranger than Pamela.
# Q: Who is less strange?
# A: pamela
# P: kate
#
#
# ----
# C: Jack is richerer than Greg.
# Q: Who is richerer?
# A: jack
# P: jack
#
# C: Jack is richerer than Greg.
# Q: Who is less rich?
# A: greg
# P: jack
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Anna is wiser than Kim.
# Q: Who is wiser?
# A: anna
# P: anna
#
# C: Anna is wiser than Kim.
# Q: Who is less wise?
# A: kim
# P: kim
#
#
# ----
# C: Michelle is slowerer than Philip.
# Q: Who is slowerer?
# A: michelle
# P: michelle
#
# C: Michelle is slowerer than Philip.
# Q: Who is less slow?
# A: philip
# P: philip
#
#
# ----
# C: Emma is higherer than Sharon.
# Q: Who is higherer?
# A: emma
# P: emma
#
# C: Emma is higherer than Sharon.
# Q: Who is less high?
# A: sharon
# P: emma
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Marilyn is richer than Michelle.
# Q: Who is richer?
# A: marilyn
# P: marilyn
#
# C: Marilyn is richer than Michelle.
# Q: Who is less rich?
# A: michelle
# P: michelle
#
#
# ----
# C: Eric is faster than Stephanie.
# Q: Who is faster?
# A: eric
# P: eric
#
# C: Eric is faster than Stephanie.
# Q: Who is less fast?
# A: stephanie
# P: stephanie
#
#
# ----
# C: Carol is wiser than Ray.
# Q: Who is wiser?
# A: carol
# P: carol
#
# C: Carol is wiser than Ray.
# Q: Who is less wise?
# A: ray
# P: ray
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Kathy is slower than Richard.
# Q: Who is slower?
# A: kathy
# P: kathy
#
# C: Kathy is slower than Richard.
# Q: Who is less slow?
# A: richard
# P: richard
#
#
# ----
# C: Diana is greaterer than Jack.
# Q: Who is greaterer?
# A: diana
# P: diana
#
# C: Diana is greaterer than Jack.
# Q: Who is less great?
# A: jack
# P: diana
#
#
# ----
# C: Ian is smarter than David.
# Q: Who is smarter?
# A: ian
# P: ian
#
# C: Ian is smarter than David.
# Q: Who is less smart?
# A: david
# P: david
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Jim is darkerer than Jason.
# Q: Who is darkerer?
# A: jim
# P: jim
#
# C: Jim is darkerer than Jason.
# Q: Who is less dark?
# A: jason
# P: jim
#
#
# ----
# C: Roger is smarterer than Dick.
# Q: Who is smarterer?
# A: roger
# P: roger
#
# C: Roger is smarterer than Dick.
# Q: Who is less smart?
# A: dick
# P: dick
#
#
# ----
# C: Michael is richer than Mike.
# Q: Who is richer?
# A: michael
# P: michael
#
# C: Michael is richer than Mike.
# Q: Who is less rich?
# A: mike
# P: mike
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Joan is weaker than Annie.
# Q: Who is weaker?
# A: joan
# P: joan
#
# C: Joan is weaker than Annie.
# Q: Who is less weak?
# A: annie
# P: annie
#
#
# ----
# C: Amanda is youngerer than Kevin.
# Q: Who is youngerer?
# A: amanda
# P: amanda
#
# C: Amanda is youngerer than Kevin.
# Q: Who is less young?
# A: kevin
# P: amanda
#
#
# ----
# C: Jennifer is tallerer than Eric.
# Q: Who is tallerer?
# A: jennifer
# P: jennifer
#
# C: Jennifer is tallerer than Eric.
# Q: Who is less tall?
# A: eric
# P: eric
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Diana is higher than Edward.
# Q: Who is higher?
# A: diana
# P: diana
#
# C: Diana is higher than Edward.
# Q: Who is less high?
# A: edward
# P: edward
#
#
# ----
# C: Virginia is greaterer than Lauren.
# Q: Who is greaterer?
# A: virginia
# P: virginia
#
# C: Virginia is greaterer than Lauren.
# Q: Who is less great?
# A: lauren
# P: virginia
#
#
# ----
# C: Mary is fasterer than Kathleen.
# Q: Who is fasterer?
# A: mary
# P: mary
#
# C: Mary is fasterer than Kathleen.
# Q: Who is less fast?
# A: kathleen
# P: mary
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Sophie is greaterer than Dan.
# Q: Who is greaterer?
# A: sophie
# P: sophie
#
# C: Sophie is greaterer than Dan.
# Q: Who is less great?
# A: dan
# P: sophie
#
#
# ----
# C: Charlie is strangeerer than Eric.
# Q: Who is strangeerer?
# A: charlie
# P: charlie
#
# C: Charlie is strangeerer than Eric.
# Q: Who is less strange?
# A: eric
# P: charlie
#
#
# ----
# C: Evelyn is higher than Joan.
# Q: Who is higher?
# A: evelyn
# P: evelyn
#
# C: Evelyn is higher than Joan.
# Q: Who is less high?
# A: joan
# P: joan
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Joseph is shorterer than Jean.
# Q: Who is shorterer?
# A: joseph
# P: joseph
#
# C: Joseph is shorterer than Jean.
# Q: Who is less short?
# A: jean
# P: jean
#
#
# ----
# C: William is weakerer than Edwin.
# Q: Who is weakerer?
# A: william
# P: william
#
# C: William is weakerer than Edwin.
# Q: Who is less weak?
# A: edwin
# P: william
#
#
# ----
# C: Kathleen is faster than Ann.
# Q: Who is faster?
# A: kathleen
# P: kathleen
#
# C: Kathleen is faster than Ann.
# Q: Who is less fast?
# A: ann
# P: ann
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Mike is older than Scott.
# Q: Who is older?
# A: mike
# P: mike
#
# C: Mike is older than Scott.
# Q: Who is less old?
# A: scott
# P: scott
#
#
# ----
# C: Roger is younger than Ray.
# Q: Who is younger?
# A: roger
# P: roger
#
# C: Roger is younger than Ray.
# Q: Who is less young?
# A: ray
# P: ray
#
#
# ----
# C: Deborah is smarterer than Larry.
# Q: Who is smarterer?
# A: deborah
# P: deborah
#
# C: Deborah is smarterer than Larry.
# Q: Who is less smart?
# A: larry
# P: larry
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Simon is smarter than Harriet.
# Q: Who is smarter?
# A: simon
# P: simon
#
# C: Simon is smarter than Harriet.
# Q: Who is less smart?
# A: harriet
# P: harriet
#
#
# ----
# C: Mark is fasterer than Marilyn.
# Q: Who is less fast?
# A: marilyn
# P: mark
#
# C: Mark is fasterer than Marilyn.
# Q: Who is fasterer?
# A: mark
# P: mark
#
#
# ----
# C: Jerry is cleanerer than Edward.
# Q: Who is cleanerer?
# A: jerry
# P: jerry
#
# C: Jerry is cleanerer than Edward.
# Q: Who is less clean?
# A: edward
# P: edward
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Kathryn is richerer than Ron.
# Q: Who is richerer?
# A: kathryn
# P: kathryn
#
# C: Kathryn is richerer than Ron.
# Q: Who is less rich?
# A: ron
# P: kathryn
#
#
# ----
# C: Diana is coolerer than Joseph.
# Q: Who is coolerer?
# A: diana
# P: diana
#
# C: Diana is coolerer than Joseph.
# Q: Who is less cool?
# A: joseph
# P: diana
#
#
# ----
# C: Dorothy is greaterer than Roger.
# Q: Who is greaterer?
# A: dorothy
# P: dorothy
#
# C: Dorothy is greaterer than Roger.
# Q: Who is less great?
# A: roger
# P: dorothy
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Bruce is strangeerer than Matthew.
# Q: Who is strangeerer?
# A: bruce
# P: bruce
#
# C: Bruce is strangeerer than Matthew.
# Q: Who is less strange?
# A: matthew
# P: bruce
#
#
# ----
# C: Elaine is shorter than Ron.
# Q: Who is shorter?
# A: elaine
# P: elaine
#
# C: Elaine is shorter than Ron.
# Q: Who is less short?
# A: ron
# P: ron
#
#
# ----
# C: Joe is nicer than Rose.
# Q: Who is nicer?
# A: joe
# P: joe
#
# C: Joe is nicer than Rose.
# Q: Who is less nice?
# A: rose
# P: rose
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Emily is tougher than Steve.
# Q: Who is tougher?
# A: emily
# P: emily
#
# C: Emily is tougher than Steve.
# Q: Who is less tough?
# A: steve
# P: steve
#
#
# ----
# C: Susan is richer than Marilyn.
# Q: Who is richer?
# A: susan
# P: susan
#
# C: Susan is richer than Marilyn.
# Q: Who is less rich?
# A: marilyn
# P: marilyn
#
#
# ----
# C: Andrea is shorterer than Ray.
# Q: Who is shorterer?
# A: andrea
# P: andrea
#
# C: Andrea is shorterer than Ray.
# Q: Who is less short?
# A: ray
# P: andrea
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Ray is older than Sandra.
# Q: Who is older?
# A: ray
# P: ray
#
# C: Ray is older than Sandra.
# Q: Who is less old?
# A: sandra
# P: sandra
#
#
# ----
# C: Ryan is older than Philip.
# Q: Who is older?
# A: ryan
# P: ryan
#
# C: Ryan is older than Philip.
# Q: Who is less old?
# A: philip
# P: philip
#
#
# ----
# C: Frank is slower than Jean.
# Q: Who is slower?
# A: frank
# P: frank
#
# C: Frank is slower than Jean.
# Q: Who is less slow?
# A: jean
# P: jean
#
#
# ----
# Predicting 100 examples
# Test cases:      50
# Fails (rate):    50 (100.0%)
#
# Example fails:
# C: Donna is nicer than Johnny.
# Q: Who is nicer?
# A: donna
# P: donna
#
# C: Donna is nicer than Johnny.
# Q: Who is less nice?
# A: johnny
# P: donna is nicer than johnny
#
#
# ----
# C: Chris is greater than Marie.
# Q: Who is greater?
# A: chris
# P: chris
#
# C: Chris is greater than Marie.
# Q: Who is less great?
# A: marie
# P: chris
#
#
# ----
# C: Maria is niceerer than Martha.
# Q: Who is niceerer?
# A: maria
# P: maria
#
# C: Maria is niceerer than Martha.
# Q: Who is less nice?
# A: martha
# P: maria
#
#
# ----
# Predicting 98 examples
# Test cases:      49
# Fails (rate):    49 (100.0%)
#
# Example fails:
# C: Harriet is faster than Roy.
# Q: Who is faster?
# A: harriet
# P: harriet
#
# C: Harriet is faster than Roy.
# Q: Who is less fast?
# A: roy
# P: roy
#
#
# ----
# C: Ann is greater than John.
# Q: Who is greater?
# A: ann
# P: ann
#
# C: Ann is greater than John.
# Q: Who is less great?
# A: john
# P: john
#
#
# ----
# C: Rebecca is nicer than Tony.
# Q: Who is nicer?
# A: rebecca
# P: rebecca
#
# C: Rebecca is nicer than Tony.
# Q: Who is less nice?
# A: tony
# P: tony
#
#
# ----
# ...
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
# ---> 53     run_test()
#      54 run_test()
#
# <ipython-input-69-2240bab16d8f> in run_test()
#      48     description = ''
#      49     test = MFT(**template, name=name, description=description, capability='Vocabulary')
# ---> 50     test.run(predict_and_score)
#      51     test.summary(n=3, format_example_fn=format_squad_with_context)
#      52     suite.add(test, overwrite=True)
#
# /usr/local/lib/python3.10/dist-packages/checklist/abstract_test.py in run(self, predict_and_confidence_fn, overwrite, verbose, n, seed)
#     369         if verbose:
#     370             print('Predicting %d examples' % len(examples))
# --> 371         preds, confs = predict_and_confidence_fn(examples)
#     372         self.run_from_preds_confs(preds, confs, overwrite=overwrite)
#     373
#
# <ipython-input-68-4e69793067fe> in predict_and_score(examples)
#      12             input_ids = inputs["input_ids"].tolist()[0]
#      13
# ---> 14             outputs = model(**inputs)
#      15             answer_start_scores = outputs.start_logits
#      16             answer_end_scores = outputs.end_logits
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#     899         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     900
# --> 901         distilbert_output = self.distilbert(
#     902             input_ids=input_ids,
#     903             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     597         embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
#     598
# --> 599         return self.transformer(
#     600             x=embeddings,
#     601             attn_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     367                 )
#     368             else:
# --> 369                 layer_outputs = layer_module(
#     370                     hidden_state,
#     371                     attn_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions)
#     308
#     309             sa_output = sa_output[0]
# --> 310         sa_output = self.sa_layer_norm(sa_output + x)  # (bs, seq_length, dim)
#     311
#     312         # Feed Forward Network
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1680     # See full discussion on the problems with returning `Union` here
#    1681     # https://github.com/microsoft/pyright/issues/4213
# -> 1682     def __getattr__(self, name: str) -> Any:
#    1683         if '_parameters' in self.__dict__:
#    1684             _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %%
# Define the list of genders
genders = ["Male", "Female", "Non-Binary", "Transgender", "Genderqueer", "Other"]

# Define a list of sample questions
questions = [
    "Is the language in the question gender-neutral?",
    "Does the question avoid making assumptions about gender?",
    "Is the question inclusive of all gender identities?"
]

# Create a checklist
checklist = []
for gender in genders:
    for question in questions:
        checklist_item = f"For {gender} individuals: {question}"
        checklist.append(checklist_item)

# Display the checklist
checklist_formatted = "\n".join(checklist)
print(checklist_formatted)
# Out:
# For Male individuals: Is the language in the question gender-neutral?
# For Male individuals: Does the question avoid making assumptions about gender?
# For Male individuals: Is the question inclusive of all gender identities?
# For Female individuals: Is the language in the question gender-neutral?
# For Female individuals: Does the question avoid making assumptions about gender?
# For Female individuals: Is the question inclusive of all gender identities?
# For Non-Binary individuals: Is the language in the question gender-neutral?
# For Non-Binary individuals: Does the question avoid making assumptions about gender?
# For Non-Binary individuals: Is the question inclusive of all gender identities?
# For Transgender individuals: Is the language in the question gender-neutral?
# For Transgender individuals: Does the question avoid making assumptions about gender?
# For Transgender individuals: Is the question inclusive of all gender identities?
# For Genderqueer individuals: Is the language in the question gender-neutral?
# For Genderqueer individuals: Does the question avoid making assumptions about gender?
# For Genderqueer individuals: Is the question inclusive of all gender identities?
# For Other individuals: Is the language in the question gender-neutral?
# For Other individuals: Does the question avoid making assumptions about gender?
# For Other individuals: Is the question inclusive of all gender identities?

# %%
#1117 version
import datasets
from transformers import AutoTokenizer, AutoModelForSequenceClassification, \
    AutoModelForQuestionAnswering, Trainer, TrainingArguments, HfArgumentParser
from transformers import pipeline

baseline_model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
baseline_model_pipeline = pipeline('question-answering', model=baseline_model, tokenizer=tokenizer)

#model = pipeline('question-answering', model="distilbert-base-cased-distilled-squad")
baseline_model_pipeline({
    'context': 'A new strain of flu that has the potential to become a pandemic has been identified by scientists.',
    'question': 'What has been discovered by scientists?'
})
# Out:
# {'score': 0.5087801218032837,
#  'start': 0,
#  'end': 19,
#  'answer': 'A new strain of flu'}

# %% [markdown]
# # Checklist test

# %%
#1117 version
import checklist.editor as editor
from checklist.test_suite import TestSuite, MFT

def predconfs(context_question_pairs):
    """
    output: predictions, confidence
    source: https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/tutorials/5.%20Testing%20transformer%20pipelines.ipynb
    https://github.com/filipegl/checklist_SQuAD_exp/blob/main/1.%20SQuAD-create-test-suite.ipynb
    https://github.com/marcotcr/checklist/blob/4e6e5e33a26f30c20ed602b2050f6c73e123cc23/notebooks/Sentiment.ipynb
    https://github.com/marcotcr/checklist/tree/4e6e5e33a26f30c20ed602b2050f6c73e123cc23
    """
    preds = []
    confs = []
    for c, q in context_question_pairs:
        try:
            p = baseline_model_pipeline(question=q, context=c, truncation=True, )
        except:
            print('Failed', q)
            preds.append(' ')
            confs.append(1)
        preds.append(p['answer'])
        confs.append(p['score'])
    return preds, np.array(confs)

def format_squad_with_context(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'C: %s\nQ: %s\n' % (c, q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret

def format_squad(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'Q: %s\n' % (q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret
editor = Editor()
suite = TestSuite()

# %%
#1117 Vocabulary
suggestions1 = editor.suggest('{first_name} is {mask} than {first_name2}.')[:60]
print(suggestions1)
suggestions1 = [x for x in suggestions1 if x.endswith("er")][:20]
# Out:
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/checklist/text_generation.py:171: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   to_pred = torch.tensor(to_pred, device=self.device).to(torch.int64)
# ['smarter', 'older', 'better', 'younger', 'taller', 'worse', 'stronger', 'different', 'shorter', 'cooler', 'nicer', 'tougher', 'bigger', 'hotter', 'happier', 'smaller', 'wiser', 'more', 'faster', 'richer', 'darker', 'thinner', 'weaker', 'less', 'larger', 'quieter', 'cleaner', 'heavier', 'healthier', 'closer', 'colder', 'slower', 'wealthier', 'quicker', 'longer', 'harder', 'safer', 'lighter', 'warmer', 'brighter', 'cheaper', 'sharper', 'higher', 'louder', 'thicker', 'greater', 'lower', 'easier', 'deeper', 'poorer', 'softer', 'smoother', 'simpler', 'stranger', 'newer', 'other', 'superior', 'clearer', 'stricter', 'tighter']

# %% [markdown]
# # Vocabulary

# %%
#1117 Vocabulary
#1117 version more than
editor = Editor()
suite = TestSuite()
t = editor.template(
    [(
    '{first_name} is {adj} than {first_name1}.',
    'Who is {adj}?'
    )
    ],
    labels = ['{first_name}'],
    adj=suggestions1,
    remove_duplicates=True,
    nsamples=500,
    save=True
    )
name = 'A is richer than B. Who is more rich?'
description = ''
test = MFT(**t, name=name, description=description, capability='Taxonomy')
suite = TestSuite()
suite.add(test)
test.run(predconfs, n=100, overwrite=True)
test.summary(format_example_fn=format_squad_with_context)
# Out:
# Predicting 100 examples
# Test cases:      498
# Test cases run:  100
# Fails (rate):    0 (0.0%)

# %%
#1117 Vocabulary
#1117 version less than
t = editor.template(
    [(
    '{first_name} is {adj} than {first_name1}.',
    'Who is less {adj}?'
    )
    ],
    labels = ['{first_name1}'],
    adj=suggestions1,
    remove_duplicates=True,
    nsamples=500,
    save=True
    )
name = 'A is COMP than B. Who is less COMP?'
description = ''
test = MFT(**t, name=name, description=description, capability='Taxonomy')
suite.add(test)
test.run(predconfs, n=100)
test.summary(format_example_fn=format_squad_with_context, n=3)
# Out:
# Predicting 100 examples
# Test cases:      495
# Test cases run:  100
# Fails (rate):    9 (9.0%)
#
# Example fails:
# C: Anna is happier than Anthony.
# Q: Who is less happier?
# A: Anthony
# P: Anna
#
# ----
# C: Julie is happier than Frank.
# Q: Who is less happier?
# A: Frank
# P: Julie
#
# ----
# C: Jean is weaker than Sharon.
# Q: Who is less weaker?
# A: Sharon
# P: Jean
#
# ----

# %%
#1117 Intensifiers
#1117 version
def crossproduct(t):
    # takes the output of editor.template and does the cross product of contexts and qas
    ret = []
    ret_labels = []
    for x in t.data:
        cs = x['contexts']
        qas = x['qas']
        d = list(itertools.product(cs, qas))
        ret.append([(x[0], x[1][0]) for x in d])
        ret_labels.append([x[1][1] for x in d])
    t.data = ret
    t.labels = ret_labels
    return t
state = editor.suggest('John is very {mask} about the project.')[:20]
print(', '.join(editor.suggest('John is {mask} {state} about the project.', state=state)[:30]))
very = ['very', 'extremely', 'really', 'quite', 'incredibly', 'particularly', 'highly', 'super']
somewhat = ['a little', 'somewhat', 'slightly', 'mildly']

t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {very} {s} about the project. {first_name1} is {s} about the project.',
            '{first_name1} is {s} about the project. {first_name} is {very} {s} about the project.',
            '{first_name} is {s} about the project. {first_name1} is {somewhat} {s} about the project.',
            '{first_name1} is {somewhat} {s} about the project. {first_name} is {s} about the project.',
            '{first_name} is {very} {s} about the project. {first_name1} is {somewhat} {s} about the project.',
            '{first_name1} is {somewhat} {s} about the project. {first_name} is {very} {s} about the project.',
        ],
        'qas': [
            (
                'Who is most {s} about the project?',
                '{first_name}'
            ),
            (
                'Who is least {s} about the project?',
                '{first_name1}'
            ),

        ]

    },
    s = state,
    very=very,
    somewhat=somewhat,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?'
desc = ''
test = MFT(**t, name=name, description=desc, capability='Vocabulary')
suite.add(test)
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
# Out:
# very, pretty, extremely, also, still, quite, more, really, not, clearly, fairly, incredibly, particularly, now, understandably, rather, cautiously, surprisingly, certainly, feeling, so, especially, definitely, generally, most, highly, super, reportedly, being, obviously
# Predicting 1200 examples
# Test cases:      498
# Test cases run:  100
# Fails (rate):    1 (1.0%)
#
# Example fails:
# C: Katherine is pessimistic about the project. Marilyn is super pessimistic about the project.
# Q: Who is most pessimistic about the project?
# A: Marilyn
# P: Katherine
#
#
# ----

# %%
comp_pairs = [('better', 'worse'), ('older', 'younger'), ('smarter', 'dumber'), ('taller', 'shorter'), ('bigger', 'smaller'), ('stronger', 'weaker'), ('faster', 'slower'), ('darker', 'lighter'), ('richer', 'poorer'), ('happier', 'sadder'), ('louder', 'quieter'), ('warmer', 'colder')]
comp_pairs = list(set(comp_pairs))#list(set(comp_pairs + [(x[1], x[0]) for x in comp_pairs]))
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {comp[0]} than {first_name1}.',
            '{first_name1} is {comp[1]} than {first_name}.',
        ],
        'qas': [
            (
                'Who is {comp[1]}?',
                '{first_name1}',
            ),
            (
                'Who is {comp[0]}?',
                '{first_name}',
            )

        ]
        ,
    },
    comp=comp_pairs,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'A is COMP than B. Who is antonym(COMP)? B'
test = MFT(**t, name=name, description='', capability='Taxonomy')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      497
# Test cases run:  100
# Fails (rate):    12 (12.0%)
#
# Example fails:
# C: Alan is weaker than Melissa.
# Q: Who is stronger?
# A: Melissa
# P: Alan
#
#
# ----
# C: Martha is weaker than Nancy.
# Q: Who is stronger?
# A: Nancy
# P: Martha
#
#
# ----
# C: Diane is weaker than Louis.
# Q: Who is stronger?
# A: Louis
# P: Diane
#
#
# ----

# %% [markdown]
# # Taxonomy

# %%
#1117 Taxonomy
#1117 version
import munch
order = ['size', 'shape', 'age', 'color']
props = []
properties = {
    'color' : ['red', 'blue','yellow', 'green', 'pink', 'white', 'black', 'orange', 'grey', 'purple', 'brown'],
    'size' : ['big', 'small', 'tiny', 'enormous'],
    'age' : ['old', 'new'],
    'shape' : ['round', 'oval', 'square', 'triangular'],
    'material' : ['iron', 'wooden', 'ceramic', 'glass', 'stone']
}
for i in range(len(order)):
    for j in range(i + 1, len(order)):
        p1, p2 = order[i], order[j]
        for v1, v2 in itertools.product(properties[p1], properties[p2]):
            props.append(munch.Munch({
                'p1': p1,
                'p2': p2,
                'v1': v1,
                'v2': v2,
            }))
print(', '.join(editor.suggest('There is {a:p.v1} {p.v2} {mask} in the room.', p=props, verbose=False)[:30]))
objects = ['box', 'clock', 'table', 'object', 'toy', 'painting', 'sculpture', 'thing', 'figure']

t = crossproduct(editor.template(
    {
        'contexts': [
            'There is {a:p.v1} {p.v2} {obj} in the room.',
            'There is {a:obj} in the room. The {obj} is {p.v1} and {p.v2}.',
        ],
        'qas': [
            (
                'What {p.p1} is the {obj}?',
                '{p.v1}'
            ),
            (
                'What {p.p2} is the {obj}?',
                '{p.v2}'
            ),

        ]
    },
    obj=objects,
    p=props,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'size, shape, age, color'
desc = ''
test = MFT(**t, name=name, description=desc, capability='Taxonomy')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# sofa, couch, wall, carpet, chair, table, light, lamp, door, clock, mirror, desk, bed, TV, bar, television, window, box, tree, painting, curtain, fan, fridge, screen, wallpaper, piano, rug, shelf, camera, candle
# Predicting 400 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    0 (0.0%)

# %%
#1117 professions
#1117 version
professions = editor.suggest('{first_name} works as {a:mask}.')[:30]
professions += editor.suggest('{first_name} {last_name} works as {a:mask}.')[:30]
professions = list(set(professions))
if 'translator' in professions:
    professions.remove('translator')
print(professions)

def clean(string):
    return string.lstrip('[a,the,an,in,at] ').rstrip('.')
def expect_squad(x, pred, conf, label=None, meta=None):
    return clean(pred) == clean(label)
expect_squad = Expect.single(expect_squad)
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {a:nat} {prof}.',
            '{first_name} is {a:prof}. {first_name} is {nat}.',
            '{first_name} is {nat}. {first_name} is {a:prof}.',
            '{first_name} is {nat} and {a:prof}.',
            '{first_name} is {a:prof} and {nat}.',
        ],
        'qas': [
            (
                'What is {first_name}\'s job?',
                '{prof}'
            ),
            (
                'What is {first_name}\'s nationality?',
                '{nat}'
            ),

        ]

    },
    nat = editor.lexicons['nationality'][:10],
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    save=True,
    ))
name = 'Profession vs nationality'
test = MFT(**t, name=name, expect=expect_squad, description='',  capability='Taxonomy')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# ['investigator', 'entrepreneur', 'analyst', 'waitress', 'editor', 'model', 'agent', 'reporter', 'organizer', 'activist', 'interpreter', 'historian', 'investor', 'accountant', 'engineer', 'actress', 'executive', 'producer', 'intern', 'escort', 'attorney', 'architect', 'author', 'educator', 'assistant', 'journalist', 'DJ', 'administrator', 'economist', 'artist', 'actor', 'nurse', 'secretary', 'photographer']
# Predicting 1000 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    0 (0.0%)

# %%
synonyms = [ ('spiritual', 'religious'), ('angry', 'furious'), ('organized', 'organised'),
            ('vocal', 'outspoken'), ('grateful', 'thankful'), ('intelligent', 'smart'),
            ('humble', 'modest'), ('courageous', 'brave'), ('happy', 'joyful'), ('scared', 'frightened'),
           ]

t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is very {s1[0]}. {first_name2} is very {s2[0]}.',
            '{first_name2} is very {s2[0]}. {first_name} is very {s1[0]}.',
        ],
        'qas': [
            (
                'Who is {s1[1]}?',
                '{first_name}'
            ),
            (
                'Who is {s2[1]}?',
                '{first_name2}'
            ),

        ]

    },
    s=synonyms,
    remove_duplicates=True,
    nsamples=250,
    save=True
   ))
t += crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is very {s1[1]}. {first_name2} is very {s2[1]}.',
            '{first_name2} is very {s2[1]}. {first_name} is very {s1[1]}.',
        ],
        'qas': [
            (
                'Who is {s1[0]}?',
                '{first_name}'
            ),
            (
                'Who is {s2[0]}?',
                '{first_name2}'
            ),

        ]

    },
    s=synonyms,
    remove_duplicates=True,
    nsamples=250,
    save=True
    ))
name = 'Synonyms'
test = MFT(**t, name=name, description='', capability='Taxonomy', expect=expect_squad)
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      460
# Test cases run:  100
# Fails (rate):    0 (0.0%)

# %%
animals = ['dog', 'cat', 'bull', 'cow', 'fish', 'serpent', 'snake', 'lizard', 'hamster', 'rabbit', 'guinea pig', 'iguana', 'duck']
vehicles = ['car', 'truck', 'train', 'motorcycle', 'bike', 'firetruck', 'tractor', 'van', 'SUV', 'minivan']
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} has {a:animal} and {a:vehicle}.',
            '{first_name} has {a:vehicle} and {a:animal}.',
        ],
        'qas': [
            (
                'What animal does {first_name} have?',
                '{animal}'
            ),
            (
                'What vehicle does {first_name} have?',
                '{vehicle}'
            ),

        ]

    },
    animal=animals,
    vehicle=vehicles,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Animal vs Vehicle'
test = MFT(**t, name=name, description='', capability='Taxonomy', expect=expect_squad)
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test, overwrite=True)
# Out:
# Predicting 400 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    0 (0.0%)

# %%
antonym_adjs = [('progressive', 'conservative'),('religious', 'secular'),('positive', 'negative'),('defensive', 'offensive'),('rude',  'polite'),('optimistic', 'pessimistic'),('stupid', 'smart'),('negative', 'positive'),('unhappy', 'happy'),('active', 'passive'),('impatient', 'patient'),('powerless', 'powerful'),('visible', 'invisible'),('fat', 'thin'),('bad', 'good'),('cautious', 'brave'), ('hopeful', 'hopeless'),('insecure', 'secure'),('humble', 'proud'),('passive', 'active'),('dependent', 'independent'),('pessimistic', 'optimistic'),('irresponsible', 'responsible'),('courageous', 'fearful')]
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is more {a[0]} than {first_name1}.',
            '{first_name1} is more {a[1]} than {first_name}.',
            '{first_name} is less {a[1]} than {first_name1}.',
            '{first_name1} is less {a[0]} than {first_name}.',
        ],
        'qas': [
            (
                'Who is more {a[0]}?',
                '{first_name}',
            ),
            (
                'Who is less {a[0]}?',
                '{first_name1}',
            ),
            (
                'Who is more {a[1]}?',
                '{first_name1}',
            ),
            (
                'Who is less {a[1]}?',
                '{first_name}',
            ),
        ]
        ,
    },
    a = antonym_adjs,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.'
test = MFT(**t, name=name, description='', capability='Taxonomy')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 1600 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Sue is less active than Leslie.
# Q: Who is more passive?
# A: Sue
# P: Leslie
#
# C: Sue is less active than Leslie.
# Q: Who is less active?
# A: Sue
# P: Leslie
#
# C: Leslie is less passive than Sue.
# Q: Who is less active?
# A: Sue
# P: Leslie
#
#
# ----
# C: Laura is less humble than Alfred.
# Q: Who is less humble?
# A: Laura
# P: Alfred
#
# C: Alfred is less proud than Laura.
# Q: Who is more humble?
# A: Alfred
# P: Laura
#
# C: Alfred is less proud than Laura.
# Q: Who is less humble?
# A: Laura
# P: Alfred
#
#
# ----
# C: Henry is less proud than Janet.
# Q: Who is less proud?
# A: Henry
# P: Janet
#
# C: Henry is less proud than Janet.
# Q: Who is more humble?
# A: Henry
# P: Janet
#
# C: Janet is less humble than Henry.
# Q: Who is less proud?
# A: Henry
# P: Janet
#
#
# ----
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-46-0380497bfdfe> in <cell line: 39>()
#      37 test.run(predconfs, n=100)
#      38 test.summary(n=3, format_example_fn=format_squad_with_context)
# ---> 39 suite.add(test)
#
# /usr/local/lib/python3.10/dist-packages/checklist/test_suite.py in add(self, test, name, capability, description, format_example_fn, print_fn, overwrite)
#      67             description = test.description
#      68         if name in self.tests and not overwrite:
# ---> 69             raise(Exception('There is already a test named %s suite. Run with overwrite=True to overwrite' % name))
#      70         if name in self.info:
#      71             del self.info[name]
#
# Exception: There is already a test named A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A. suite. Run with overwrite=True to overwrite

# %% [markdown]
# # Robustness

# %%
import pickle
# # IF YOU ALREADY RAN THIS CELL, JUMP TO NEXT
# # source: https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/QQP.ipynb
nlp = spacy.load('en_core_web_sm')
all_questions = set() # a set of all questions and context
dataset = datasets.load_dataset('squad')
pairs = [(x['context'], x['question']) for x in dataset['train']]
for x in dataset['train']:
    all_questions.add(x['question'])
    all_questions.add(x['context'])


all_questions = list(all_questions)
parsed_questions = list(nlp.pipe(all_questions)) # this takes a while to run
spacy_map = dict([(x, y) for x, y in zip(all_questions, parsed_questions)])


pickle.dump(spacy_map, open('processed_squad.pkl', 'wb'))

# %%
import pickle
dataset = datasets.load_dataset('squad')
pairs = [(x['context'], x['question']) for x in dataset['train']]
spacy_map =  pickle.load(open('/content/final/processed_squad.pkl', 'rb'))
processed_pairs = [(spacy_map[x[0]], spacy_map[x[1]]) for x in pairs]
# check
print("text:",pairs[0][0])
print("entities:",spacy_map[pairs[0][0]].ents)

def question_typo(x):
    """
    x[0]: context
    x[1]: question
    Perturb.add_typos(x[1]): add a typo to question
    """
    return (x[0], Perturb.add_typos(x[1]))
t = Perturb.perturb(pairs, question_typo, nsamples=500)
test = INV(**t, name='Question typo', capability='Robustness', description='')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad)
suite.add(test, overwrite=True)
# Out:
# text: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# entities: (Catholic, the Main Building's, the Virgin Mary., the Main Building, Venite Ad Me Omnes, the Main Building, the Sacred Heart, Grotto, Marian, Lourdes, France, the Virgin Mary, Saint Bernadette Soubirous, 1858, 3, the Gold Dome, Mary)
# Predicting 200 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    21 (21.0%)
#
# Example fails:
# Q: What is another magazine that is published in Oklahoma City?
# P: Slice
#
# Q: What is another magazine that si published in Oklahoma City?
# P: The Edmond Outlook
#
#
# ----
# Q: What was the cause of the severe erosion?
# P: glaciation
#
# Q: What was the cuase of the severe erosion?
# P: the mountains
#
#
# ----
# Q: Where did the West Indies merchants in London create a police force?
# P: at the docks
#
# Q: Whree did the West Indies merchants in London create a police force?
# P: to prevent rampant theft
#
#
# ----

# %%
def contractions(x):
    conts = Perturb.contractions(x[1])
    return [(x[0], a) for a in conts]
t = Perturb.perturb(pairs, contractions, nsamples=500)
test = INV(**t, name='Question contractions', capability='Robustness', description='')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad)
suite.add(test)
# Out:
# Predicting 200 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    12 (12.0%)
#
# Example fails:
# Q: When is the latest a Somali might eat dinner during Ramadan?
# P: as late as 9 pm
#
# Q: When's the latest a Somali might eat dinner during Ramadan?
# P: 9 pm
#
#
# ----
# Q: What is the general opinion of the difficulty level of Whitehead's work in philosophy?
# P: among the most difficult to understand in all of the western canon
#
# Q: What's the general opinion of the difficulty level of Whitehead's work in philosophy?
# P: among the most difficult to understand
#
#
# ----
# Q: What is an example of financial innovation pertinent to the financial crisis?
# P: the adjustable-rate mortgage
#
# Q: What's an example of financial innovation pertinent to the financial crisis?
# P: adjustable-rate mortgage
#
#
# ----

# %%
#Add random sentence

random_sentences = set()
for x, _ in processed_pairs:
    for y in x.sents:
        random_sentences.add(y.text)
random_sentences = list(random_sentences)
# check
for y in processed_pairs[0][0].sents:
    print(y.text)

def add_random_sentence(x, **kwargs):
    random_s = np.random.choice(random_sentences)
    while random_s in x[0]:
        random_s = np.random.choice(random_sentences)
    random_s = random_s.strip('.') + '. '
    meta = ['add to end: %s' % random_s, 'add to beg: %s' % random_s]
    return [(x[0] + random_s, x[1]), (random_s + x[0], x[1])], meta

def format_add(x, pred, conf, label=None, meta=None):
    ret = format_squad(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s\n' % meta
    return ret

t = Perturb.perturb(pairs, add_random_sentence, nsamples=500, meta=True)
test = INV(**t, name='Add random sentence to context', capability='Robustness', description='')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_add)
suite.add(test)
# Out:
# Architecturally, the school has a Catholic character.
# Atop the Main Building's gold dome is a golden statue of the Virgin Mary.
# Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes".
# Next to the Main Building is the Basilica of the Sacred Heart.
# Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection.
# It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858.
# At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# Predicting 300 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    18 (18.0%)
#
# Example fails:
# Q: What is a safety feature to prevent entrapment?
# P: it is running low on power
#
# Q: What is a safety feature to prevent entrapment?
# P: open the doors and shut down
# Perturb: add to beg: In the past, "paper money" was occasionally issued in denominations less than a dollar (fractional currency) and gold coins were issued for circulation up to the value of $20 (known as the "double eagle", discontinued in the 1930s).
#
#
# ----
# Q: What did KInsey state as his reasoning for the scale?
# P: antitheses in the sexual world
#
# Q: What did KInsey state as his reasoning for the scale?
# P: to combat the assumption at the time that people are either heterosexual or homosexual
# Perturb: add to end: In October 1951, Princess Elizabeth and the Duke of Edinburgh went on a month-long tour of Canada; the trip had been delayed for a week due to the King's illness.
#
# Q: What did KInsey state as his reasoning for the scale?
# P: to combat the assumption at the time that people are either heterosexual or homosexual
# Perturb: add to beg: In October 1951, Princess Elizabeth and the Duke of Edinburgh went on a month-long tour of Canada; the trip had been delayed for a week due to the King's illness.
#
#
# ----
# Q: True aspirated consonants have been found in Kelabit Taa and what else?
# P: Kx'a languages
#
# Q: True aspirated consonants have been found in Kelabit Taa and what else?
# P: the Kx'a languages
# Perturb: add to beg: Most cotton in the United States, Europe and Australia is harvested mechanically, either by a cotton picker, a machine that removes the cotton from the boll without damaging the cotton plant, or by a cotton stripper, which strips the entire boll off the plant.
#
#
# ----

# %% [markdown]
# # NER

# %%
import re
def change_thing(change_fn):
    def change_both(cq, **kwargs):
        context, question = cq
        a = change_fn(context, meta=True)
        if not a:
            return None
        changed, meta = a
        ret = []
        for c, m in zip(changed, meta):
            new_q = re.sub(r'\b%s\b' % re.escape(m[0]), m[1], question.text)
            ret.append((c, new_q))
        return ret, meta
    return change_both

def expect_same(orig_pred, pred, orig_conf, conf, labels=None, meta=None):
    if not meta:
        return pred == orig_pred
    return pred == re.sub(r'\b%s\b' % re.escape(meta[0]), meta[1], orig_pred)

def format_replace(x, pred, conf, label=None, meta=None):
    ret = format_squad(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s -> %s\n' % meta
    return ret

def format_replace_context(x, pred, conf, label=None, meta=None):
    ret = format_squad_with_context(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s -> %s\n' % meta
    return ret

# %%
t = Perturb.perturb(processed_pairs, change_thing(Perturb.change_names), nsamples=500, meta=True)

test = INV(**t, name='Change name everywhere', capability='NER',
          description='', expect=Expect.pairwise(expect_same))
test.run(predconfs, n=100)
test.summary(3, format_example_fn=format_replace)
suite.add(test, overwrite=True)
# Out:
# Predicting 1100 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    10 (10.0%)
#
# Example fails:
# Q: Who financed a large chunk of the architecture from 1917 to 1931
# P: Edward S. Harkness
#
# Q: Who financed a large chunk of the architecture from 1917 to 1931
# P: Matthew Ortiz sculpture
# Perturb: Edward S. Harkness Stone -> Matthew Ortiz
#
# Q: Who financed a large chunk of the architecture from 1917 to 1931
# P: William Green sculpture
# Perturb: Edward S. Harkness Stone -> William Green
#
#
# ----
# Q: The Cubs had a Class A minor league affiliation on two occasions with who?
# P: Peoria Chiefs
#
# Q: The Cubs had a Class A minor league affiliation on two occasions with who?
# P: the Peoria Chiefs
# Perturb: Ryne Sandberg -> Christopher Ross
#
# Q: The Cubs had a Class A minor league affiliation on two occasions with who?
# P: the Peoria Chiefs
# Perturb: Ryne Sandberg -> Matthew Morgan
#
#
# ----
# Q: In 1986, what did Apple introduce to allow developers to create software for Macintosh on Macintosh?
# P: Macintosh Programmer's Workshop, or MPW
#
# Q: In 1986, what did Apple introduce to allow developers to create software for Macintosh on Macintosh?
# P: the Macintosh Programmer's Workshop, or MPW
# Perturb: Lisa -> Michelle
#
# Q: In 1986, what did Apple introduce to allow developers to create software for Macintosh on Macintosh?
# P: the Macintosh Programmer's Workshop, or MPW
# Perturb: Lisa -> Jamie
#
#
# ----

# %%
t = Perturb.perturb(processed_pairs, change_thing(Perturb.change_location), nsamples=500, meta=True)

test = INV(**t, name='Change location everywhere', capability='NER',
          description='', expect=Expect.pairwise(expect_same))
test.run(predconfs, n=100)
test.summary(3, format_example_fn=format_replace)
suite.add(test, overwrite=True)
# Out:
# Predicting 1100 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    14 (14.0%)
#
# Example fails:
# Q: What group awarded Schwarzenegger the title of one of the 11 "worst governors" in a 2010 report?
# P: Citizens for Responsibility and Ethics in Washington
#
# Q: What group awarded Schwarzenegger the title of one of the 11 "worst governors" in a 2010 report?
# P: Citizens for Responsibility and Ethics
# Perturb: Washington -> Boise City
#
# Q: What group awarded Schwarzenegger the title of one of the 11 "worst governors" in a 2010 report?
# P: Citizens for Responsibility and Ethics
# Perturb: Washington -> Miami
#
#
# ----
# Q: How does Tucson rank among US metro areas?
# P: 52nd largest
#
# Q: How does Memphis rank among US metro areas?
# P: 32nd largest city and 52nd largest
# Perturb: Tucson -> Memphis
#
#
# ----
# Q: How tall was Queen Victoria?
# P: five feet
#
# Q: How tall was Queen Oakland?
# P: no more than five feet
# Perturb: Victoria -> Oakland
#
# Q: How tall was Queen Austin?
# P: no more than five feet
# Perturb: Victoria -> Austin
#
#
# ----

# %% [markdown]
# # Fairness

# %%
import collections
fewer_profs = ['doctor', 'nurse', 'secretary', 'CEO']
t = editor.template(
    [
        ('{male} is not {a:prof}, {female} is.', 'Who is {a:prof}?', '{female}', 'woman', '{prof}'),
        ('{female} is not {a:prof}, {male} is.', 'Who is {a:prof}?', '{male}', 'man', '{prof}'),
    ],
#     prof=professions + ['doctor'],
    prof=fewer_profs,
    remove_duplicates=True,
    nsamples=1000,
    unroll=True,
    save=True,
    )
data = [(d[0], d[1]) for d in t.data]
labels = [d[2] for d in t.data]
meta = [(d[3], d[4]) for d in t.data]

test = MFT(data, expect=expect_squad, labels=labels, meta=meta, templates=t.templates,
          name='M/F failure rates should be similar for different professions', capability='Fairness',
          description='Using negation in context.')
test.run(predconfs, n=100)

def print_fair(test):
    c = collections.Counter(test.meta)
    fail = collections.Counter([tuple(x) for x in np.array(test.meta)[test.fail_idxs()]])
    profs = set()
    for sex, prof in fail:
        profs.add(prof)
    prof_fail = {}
    get_fail = lambda f:fail[f] / c[f]
    for prof in profs:
        fail_m = get_fail(('man', prof))
        fail_f = get_fail(('woman', prof))
        prof_fail[prof] = (fail_m, fail_f)
    print('%-13s fail_men fail_women (count)' % 'profession')
    for prof, vs in sorted(prof_fail.items(), key=lambda x:max(x[1][0], x[1][1]), reverse=True):
        fail_m, fail_f = vs
        print('%-13s   %.1f      %.1f     (%d)' % (prof, 100 * fail_m, 100 * fail_f, c[('man', prof)]))
print_fair(test)
suite.add(test)
# Out:
# Predicting 100 examples
# profession    fail_men fail_women (count)

# %%
test.summary(format_example_fn=format_squad_with_context)
# Out:
# Test cases:      2000
# Test cases run:  100
# Fails (rate):    0 (0.0%)

# %% [markdown]
# # Negation

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is not {a:prof}. {first_name2} is.',
            '{first_name2} is {a:prof}. {first_name} is not.',
        ],
        'qas': [
            (
                'Who is {a:prof}?',
                '{first_name2}'
            ),
            (
                'Who is not {a:prof}?',
                '{first_name}'
            ),
        ]

    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Negation in context, may or may not be in question'
test = MFT(**t, expect=expect_squad, capability='Negation', name=name, description='' )
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      496
# Test cases run:  100
# Fails (rate):    0 (0.0%)

# %%
format_fn = lambda x: {'passage': x[0], 'question': x[1]}
suite.to_raw_file('/tmp/squad.json', format_fn=format_fn, file_format='squad')

# %%
path = 'squad_suite2.pkl'
suite.save(path)

# %%
suite.summary(n=3, format_example_fn=format_squad_with_context)
# Out:
# Vocabulary
#
# Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Test cases:      498
# Fails (rate):    1 (0.2%)
#
# Example fails:
# C: Steve is particular about the project. Bobby is very particular about the project.
# Q: Who is most particular about the project?
# A: Bobby
# P: Bobby
#
#
# ----
#
#
#
#
# Taxonomy
#
# A is richer than B. Who is more rich?
# Test cases:      498
# Fails (rate):    0 (0.0%)
#
#
# A is COMP than B. Who is less COMP?
# Test cases:      495
# Fails (rate):    9 (1.8%)
#
# Example fails:
#
#
# A is COMP than B. Who is antonym(COMP)? B
# Test cases:      497
# Fails (rate):    12 (2.4%)
#
# Example fails:
# C: Nick is shorter than Bruce.
# Q: Who is taller?
# A: Bruce
# P: Bruce
#
#
# ----
# C: Don is smaller than Martha.
# Q: Who is bigger?
# A: Martha
# P: Martha
#
#
# ----
#
#
# size, shape, age, color
# Test cases:      500
# Fails (rate):    0 (0.0%)
#
#
# Profession vs nationality
# Test cases:      500
# Fails (rate):    0 (0.0%)
#
#
# Synonyms
# Test cases:      460
# Fails (rate):    0 (0.0%)
#
#
# Animal vs Vehicle
# Test cases:      500
# Fails (rate):    0 (0.0%)
#
#
# A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Test cases:      499
# Fails (rate):    100 (20.0%)
#
# Example fails:
#
#
#
#
# Robustness
#
# Question typo
# Test cases:      500
# Fails (rate):    21 (4.2%)
#
# Example fails:
#
#
# Question contractions
# Test cases:      500
# Fails (rate):    12 (2.4%)
#
# Example fails:
#
#
# Add random sentence to context
# Test cases:      500
# Fails (rate):    18 (3.6%)
#
# Example fails:
#
#
#
#
# NER
#
# Change name everywhere
# Test cases:      500
# Fails (rate):    10 (2.0%)
#
# Example fails:
# C: In 2015 Beyoncé signed an open letter which the ONE Campaign had been collecting signatures for; the letter was addressed to Angela Merkel and Nkosazana Dlamini-Zuma, urging them to focus on women as they serve as the head of the G7 in Germany and the AU in South Africa respectively, which will start to set the priorities in development funding before a main UN summit in September 2015 that will establish new development goals for the generation.
# Q: An important UN summit took place when?
# P: September 2015
#
# C: In 2015 Beyoncé signed an open letter which the ONE Campaign had been collecting signatures for; the letter was addressed to Jennifer Bell and Nkosazana Dlamini-Zuma, urging them to focus on women as they serve as the head of the G7 in Germany and the AU in South Africa respectively, which will start to set the priorities in development funding before a main UN summit in September 2015 that will establish new development goals for the generation.
# Q: An important UN summit took place when?
# P: September 2015
#
# C: In 2015 Beyoncé signed an open letter which the ONE Campaign had been collecting signatures for; the letter was addressed to Ashley Jenkins and Nkosazana Dlamini-Zuma, urging them to focus on women as they serve as the head of the G7 in Germany and the AU in South Africa respectively, which will start to set the priorities in development funding before a main UN summit in September 2015 that will establish new development goals for the generation.
# Q: An important UN summit took place when?
# P: September 2015
#
#
# ----
#
#
# Change location everywhere
# Test cases:      500
# Fails (rate):    14 (2.8%)
#
# Example fails:
#
#
#
#
# Fairness
#
# M/F failure rates should be similar for different professions
# Test cases:      2000
# Fails (rate):    0 (0.0%)
#
#
#
#
# Negation
#
# Negation in context, may or may not be in question
# Test cases:      496
# Fails (rate):    0 (0.0%)

# %% [markdown]
# # Other

# %%
#1117

def checklist_to_squad(name, new_data, current_data=None, num_samples=None):

  ids = []
  titles = []
  contexts = []
  questions = []
  answers = []

  for example_group_idx in range(len(new_data.data)):
    for example_idx in range(len(new_data.data[example_group_idx])):
      #print("our indices: ", example_group_idx, example_idx, "in ", len(new_data.data), len(example))
      example_data = new_data.data[example_group_idx][example_idx]
      context, question = example_data
      example_label = new_data.labels[example_group_idx][example_idx]
      ids.append("a"+str(example_group_idx)+str(example_idx))
      titles.append("name")
      contexts.append(context)
      questions.append(question)

      answers.append({'text':[example_label], "answer_start":[context.find(example_label)]})

  my_data = {
      "id": ids,
      "title": titles,
      "context": contexts,
      "question": questions,
      "answers": answers

  }
  checklist_data = Dataset.from_dict(my_data, features=squad["train"].features)
  if num_samples != None:
    selection = random.sample(range(checklist_data.num_rows), num_samples)
    checklist_data = checklist_data.select(selection)
  if current_data == None:
    return checklist_data
  else:
    return datasets.concatenate_datasets([current_data, checklist_data])

checklist_data = checklist_to_squad("more_less_comp", t)
checklist_data_full = checklist_to_squad("more_less_comp", t)

# %%
#1117 version
def crossproduct(t):
    # takes the output of editor.template and does the cross product of contexts and qas
    ret = []
    ret_labels = []
    for x in t.data:
        cs = x['contexts']
        qas = x['qas']
        d = list(itertools.product(cs, qas))
        ret.append([(x[0], x[1][0]) for x in d])
        ret_labels.append([x[1][1] for x in d])
    t.data = ret
    t.labels = ret_labels
    return t

def clean(string):
    return string.lstrip('[a,the,an,in,at] ').rstrip('.')

def expect_squad(x, pred, conf, label=None, meta=None):
    return clean(pred) == clean(label)
expect_squad = Expect.single(expect_squad)

state = editor.suggest('John is very {mask} about the project.')[:20]
print(', '.join(editor.suggest('John is {mask} {state} about the project.', state=state)[:30]))
very = ['very', 'extremely', 'really', 'quite', 'incredibly', 'particularly', 'highly', 'super']
somewhat = ['a little', 'somewhat', 'slightly', 'mildly']
# Out:
# very, pretty, extremely, also, still, quite, more, really, not, clearly, fairly, incredibly, particularly, now, understandably, rather, cautiously, surprisingly, certainly, feeling, so, especially, definitely, generally, most, highly, super, reportedly, being, obviously

# %%
#1117 version


professions = editor.suggest('{first_name} works as {a:mask}.')[:30]
professions += editor.suggest('{first_name} {last_name} works as {a:mask}.')[:30]
professions = list(set(professions))


if 'translator' in professions:
    professions.remove('translator')

t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {a:nat} {prof}.',
            '{first_name} is {a:prof}. {first_name} is {nat}.',
            '{first_name} is {nat}. {first_name} is {a:prof}.',
            '{first_name} is {nat} and {a:prof}.',
            '{first_name} is {a:prof} and {nat}.',
        ],
        'qas': [
            (
                'What is {first_name}\'s job?',
                '{prof}'
            ),
            (
                'What is {first_name}\'s nationality?',
                '{nat}'
            ),

        ]

    },
    nat = editor.lexicons['nationality'][:10],
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    save=True,
    ))
name = 'Profession vs nationality'
test = MFT(**t, name=name, expect=expect_squad, description='',  capability='Taxonomy')
test.run(predict_and_score)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test, overwrite=True)
checklist_data = checklist_to_squad("profession_vs_nationality", t, checklist_data, 100)
checklist_data_full = checklist_to_squad("profession_vs_nationality", t, checklist_data_full)
# Out:
# Predicting 5000 examples
# Test cases:      500
# Fails (rate):    500 (100.0%)
#
# Example fails:
# C: Robin is a Bangladeshi reporter.
# Q: What is Robin's job?
# A: reporter
# P: bangladeshi reporter
#
# C: Robin is a Bangladeshi reporter.
# Q: What is Robin's nationality?
# A: Bangladeshi
# P: bangladeshi
#
# C: Robin is a reporter. Robin is Bangladeshi.
# Q: What is Robin's nationality?
# A: Bangladeshi
# P: bangladeshi
#
#
# ----
# C: Don is an American DJ.
# Q: What is Don's job?
# A: DJ
# P: dj
#
# C: Don is an American DJ.
# Q: What is Don's nationality?
# A: American
# P: american dj
#
# C: Don is a DJ. Don is American.
# Q: What is Don's job?
# A: DJ
# P: dj
#
#
# ----
# C: Martin is a Chinese model.
# Q: What is Martin's job?
# A: model
# P: chinese model
#
# C: Martin is a Chinese model.
# Q: What is Martin's nationality?
# A: Chinese
# P: chinese
#
# C: Martin is a model. Martin is Chinese.
# Q: What is Martin's nationality?
# A: Chinese
# P: chinese
#
#
# ----

# %%
#1117 version
from transformers import Trainer


squad_adv_addSent_limited

checklist_data

combined_df = datasets.concatenate_datasets([squad_limited, checklist_data])

# %%
#將檔案copy回去
# !cp -r /content/final/trained_model_qa_64.zip /content/MyDrive/MyDrive/UT_NLP/final/trained_model_qa_64.zip

# %%
#將檔案copy回去
#!cp -r /content/final/trained_model.zip /content/MyDrive/MyDrive/UT_NLP/final/trained_model.zip
# !cp -r /content/final/run.py /content/MyDrive/MyDrive/UT_NLP/final/run.py
# !cp -r /content/final/squad_suite2.pkl /content/MyDrive/MyDrive/UT_NLP/final/squad_suite2.pkl
# !cp -r /content/final/squad_suite3.pkl /content/MyDrive/MyDrive/UT_NLP/final/squad_suite3.pkl
#!cp -r /content/a4-distrib/factchecking_main.py /content/MyDrive/MyDrive/UT_NLP/a4-distrib/factchecking_main.py
#!cp -r /content/a4-distrib/transformer.py /content/MyDrive/MyDrive/UT_NLP/a4-distrib/transformer.py

# %%
# !cp -r /content/final /content/MyDrive/MyDrive/UT_NLP

# %% [markdown]
# # 新增區段

# %%
#copy zip file
# !cp -r /content/a4-distrib/wc22987.zip /content/MyDrive/MyDrive/UT_NLP/a4-distrib/
