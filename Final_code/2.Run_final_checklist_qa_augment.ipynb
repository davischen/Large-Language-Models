# %%
from google.colab import drive
drive.mount('/content/MyDrive/')
# Out:
# Mounted at /content/MyDrive/

# %% [markdown]
# # 下載檔案

# %%
#解壓縮檔案
#%cp -r "/content/MyDrive/MyDrive/UT_NLP/dataset/drive_data.zip" /content/sample_data/drive_data.zip

# %%
#解壓縮檔案
#!unzip /content/sample_data/drive_data.zip -d /content/a4-distrib

# %%
#複製檔案
# !cp -r /content/MyDrive/MyDrive/UT_NLP/final/ /content/

# %%
#解壓縮檔案
#!unzip /content/sample_data/dense_data.zip -d /content/a4-distrib

# %%
# %cd /content/final/
# Out:
# /content/final

# %%
# !pip install -r requirements.txt
# Out:
# Collecting accelerate (from -r requirements.txt (line 1))
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 5.9 MB/s eta 0:00:00
# Collecting datasets (from -r requirements.txt (line 2))
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 3)) (2.1.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (4.66.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (4.35.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 1)) (0.19.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (9.0.0)
# Collecting pyarrow-hotfix (from datasets->-r requirements.txt (line 2))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->-r requirements.txt (line 2))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (3.4.1)
# Collecting multiprocess (from datasets->-r requirements.txt (line 2))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r requirements.txt (line 2)) (3.8.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 5)) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 5)) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->-r requirements.txt (line 2)) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, accelerate, datasets
# Successfully installed accelerate-0.24.1 datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %%
# !pip install checklist
# !jupyter nbextension install --py --sys-prefix checklist.viewer
# !jupyter nbextension enable --py --sys-prefix checklist.viewer
# !python -m spacy download en_core_web_sm
# Out:
# Collecting checklist
#   Downloading checklist-0.0.11.tar.gz (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 105.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from checklist) (1.23.5)
# Requirement already satisfied: spacy>=2.2 in /usr/local/lib/python3.10/dist-packages (from checklist) (3.6.1)
# Collecting munch>=2.5 (from checklist)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: dill>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from checklist) (0.3.7)
# Collecting jupyter>=1.0 (from checklist)
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipywidgets>=7.5 in /usr/local/lib/python3.10/dist-packages (from checklist) (7.7.1)
# Requirement already satisfied: transformers>=2.8 in /usr/local/lib/python3.10/dist-packages (from checklist) (4.35.2)
# Collecting patternfork-nosql (from checklist)
#   Downloading patternfork_nosql-3.6.tar.gz (22.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 36.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iso-639 (from checklist)
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.4/167.4 kB 19.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5->checklist) (3.0.9)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0->checklist) (6.5.5)
# Collecting qtconsole (from jupyter>=1.0->checklist)
#   Using cached qtconsole-5.5.1-py3-none-any.whl (123 kB)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0->checklist) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0->checklist) (6.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2->checklist) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (0.19.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=2.8->checklist) (0.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (0.18.3)
# Collecting backports.csv (from patternfork-nosql->checklist)
#   Downloading backports.csv-1.0.7-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (4.9.3)
# Collecting feedparser (from patternfork-nosql->checklist)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 11.1 MB/s eta 0:00:00
# Collecting pdfminer.six (from patternfork-nosql->checklist)
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 73.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from patternfork-nosql->checklist) (3.8.1)
# Collecting python-docx (from patternfork-nosql->checklist)
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 27.8 MB/s eta 0:00:00
# Collecting cherrypy (from patternfork-nosql->checklist)
#   Downloading CherryPy-18.8.0-py2.py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.4/348.4 kB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=2.8->checklist) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=2.8->checklist) (4.5.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (6.3.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.5->checklist)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.2->checklist) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.2->checklist) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=2.2->checklist) (8.1.7)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (5.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (5.9.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (0.18.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0->checklist) (1.0.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0->checklist) (1.2.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->patternfork-nosql->checklist) (2.5)
# Collecting cheroot>=8.2.1 (from cherrypy->patternfork-nosql->checklist)
#   Downloading cheroot-10.0.0-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 14.6 MB/s eta 0:00:00
# Collecting portend>=2.1.1 (from cherrypy->patternfork-nosql->checklist)
#   Downloading portend-3.2.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from cherrypy->patternfork-nosql->checklist) (10.1.0)
# Collecting zc.lockfile (from cherrypy->patternfork-nosql->checklist)
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting jaraco.collections (from cherrypy->patternfork-nosql->checklist)
#   Downloading jaraco.collections-4.3.0-py3-none-any.whl (11 kB)
# Collecting sgmllib3k (from feedparser->patternfork-nosql->checklist)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->patternfork-nosql->checklist) (1.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->patternfork-nosql->checklist) (41.0.5)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter>=1.0->checklist)
#   Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Collecting jaraco.functools (from cheroot>=8.2.1->cherrypy->patternfork-nosql->checklist)
#   Downloading jaraco.functools-4.0.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->patternfork-nosql->checklist) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook->jupyter>=1.0->checklist) (4.0.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (0.2.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0->checklist) (2.19.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0->checklist) (4.19.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.7.0)
# Collecting tempora>=1.8 (from portend>=2.1.1->cherrypy->patternfork-nosql->checklist)
#   Downloading tempora-5.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5->checklist) (0.2.10)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter>=1.0->checklist) (21.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter>=1.0->checklist) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter>=1.0->checklist) (0.5.1)
# Collecting jaraco.text (from jaraco.collections->cherrypy->patternfork-nosql->checklist)
#   Downloading jaraco.text-3.12.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->patternfork-nosql->checklist) (2.21)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0->checklist) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0->checklist) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0->checklist) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0->checklist) (0.13.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.6.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->patternfork-nosql->checklist) (2023.3.post1)
# Collecting jaraco.context>=4.1 (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist)
#   Downloading jaraco.context-4.3.0-py3-none-any.whl (5.3 kB)
# Collecting autocommand (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist)
#   Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist) (7.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.1.3)
# Building wheels for collected packages: checklist, iso-639, patternfork-nosql, sgmllib3k
#   Building wheel for checklist (setup.py) ... done
#   Created wheel for checklist: filename=checklist-0.0.11-py3-none-any.whl size=12165615 sha256=fbf720c2c4cf6c446cb108df8f81b8327ebc9f152bef5ce879da068e6ec9a1fd
#   Stored in directory: /root/.cache/pip/wheels/69/8c/8d/ee02f2800af2cc27b01018a46d7c1c5c5a7cfe31b9fde273a8
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=168841 sha256=e2fd566effbd9d3918e6ee644df962faab19a0b4cef24a70ae8ab5a5673aaa5c
#   Stored in directory: /root/.cache/pip/wheels/d8/78/cc/5478ca3b1c3f602eae6f8cdbd78f909c0a0bfa0bbcb5c7771f
#   Building wheel for patternfork-nosql (setup.py) ... done
#   Created wheel for patternfork-nosql: filename=patternfork_nosql-3.6-py3-none-any.whl size=22332786 sha256=c15bf4fa786816ec0b3a0532c76bf700a42f17950b68d0498e983fef45c3e6dd
#   Stored in directory: /root/.cache/pip/wheels/a1/4c/b6/9d3a6963fe490043b4ff4c9699411a11a9946542dcaa79e24c
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6049 sha256=36d53d842f43944d884cc00dd276218cb636a050dc77d470d2c64092e5c789d3
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built checklist iso-639 patternfork-nosql sgmllib3k
# Installing collected packages: sgmllib3k, iso-639, backports.csv, zc.lockfile, qtpy, python-docx, munch, jedi, jaraco.functools, jaraco.context, feedparser, autocommand, tempora, cheroot, portend, pdfminer.six, jaraco.text, qtconsole, jaraco.collections, cherrypy, patternfork-nosql, jupyter, checklist
# Successfully installed autocommand-2.2.2 backports.csv-1.0.7 checklist-0.0.11 cheroot-10.0.0 cherrypy-18.8.0 feedparser-6.0.10 iso-639-0.4.5 jaraco.collections-4.3.0 jaraco.context-4.3.0 jaraco.functools-4.0.0 jaraco.text-3.12.0 jedi-0.19.1 jupyter-1.0.0 munch-4.0.0 patternfork-nosql-3.6 pdfminer.six-20221105 portend-3.2.0 python-docx-1.1.0 qtconsole-5.5.1 qtpy-2.4.1 sgmllib3k-1.0.0 tempora-5.5.0 zc.lockfile-3.0.post1
# Installing /usr/local/lib/python3.10/dist-packages/checklist/viewer/static -> viewer
# Making directory: /usr/share/jupyter/nbextensions/viewer/
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/bundle.js -> /usr/share/jupyter/nbextensions/viewer/bundle.js
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/bundle.js.map -> /usr/share/jupyter/nbextensions/viewer/bundle.js.map
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/index.js.map -> /usr/share/jupyter/nbextensions/viewer/index.js.map
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/custom.js -> /usr/share/jupyter/nbextensions/viewer/custom.js
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/index.js -> /usr/share/jupyter/nbextensions/viewer/index.js
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/extension.js -> /usr/share/jupyter/nbextensions/viewer/extension.js
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/__init__.py -> /usr/share/jupyter/nbextensions/viewer/__init__.py
# Making directory: /usr/share/jupyter/nbextensions/viewer/__pycache__
# Copying: /usr/local/lib/python3.10/dist-packages/checklist/viewer/static/__pycache__/__init__.cpython-310.pyc -> /usr/share/jupyter/nbextensions/viewer/__pycache__/__init__.cpython-310.pyc
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable checklist.viewer --py --sys-prefix
#
# Enabling notebook extension viewer/extension...
# Paths used for configuration of notebook:
#     	/usr/etc/jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/usr/etc/jupyter/nbconfig/notebook.json
# 2023-11-30 07:50:17.856815: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 07:50:17.856865: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-30 07:50:17.856895: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-30 07:50:17.864592: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-30 07:50:19.332187: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-11-30 07:50:20.939268: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-30 07:50:20.940297: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-30 07:50:20.940509: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 97.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Load DataSet

# %%
from transformers import pipeline

model = pipeline('question-answering', model="distilbert-base-cased-distilled-squad")
# %load_ext autoreload
# %autoreload 2

import checklist
import itertools

import checklist.editor
import checklist.text_generation
from checklist.expect import Expect
import numpy as np
from checklist.perturb import Perturb
import datasets
import pandas as pd
import json
# Out:
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
# SAVE SQUAD DATASET TO CSV

dataset_qa = datasets.load_dataset('squad')
adver_qa_train = datasets.load_dataset('adversarial_qa', 'adversarialQA')
adver_qa_train = adver_qa_train.remove_columns("metadata")
def format_dataset(example):
    """
    format answers from dict to json
    so that data looks consistent when exporting to csv
    """
    example['answers'] = json.dumps(example['answers'])
    return example

dataset = datasets.concatenate_datasets([dataset_qa['train'],adver_qa_train['train']])#
dataset = dataset.map(format_dataset)
dataset.to_csv('train_merge.csv', index=None)
df_train = pd.read_csv('train_merge.csv')
df_train = pd.read_csv('train_merge.csv')
df_train_selected = df_train[['context', 'question', 'answers']]
df_train_selected
# Out:
# Creating CSV from Arrow format:   0%|          | 0/118 [00:00<?, ?ba/s]
#                                                   context  \
# 0       Architecturally, the school has a Catholic cha...
# 1       Architecturally, the school has a Catholic cha...
# 2       Architecturally, the school has a Catholic cha...
# 3       Architecturally, the school has a Catholic cha...
# 4       Architecturally, the school has a Catholic cha...
# ...                                                   ...
# 117594  Some high-speed black-and-white films, such as...
# 117595  Some high-speed black-and-white films, such as...
# 117596  Some high-speed black-and-white films, such as...
# 117597  Some high-speed black-and-white films, such as...
# 117598  Some high-speed black-and-white films, such as...
#
#                                                  question  \
# 0       To whom did the Virgin Mary allegedly appear i...
# 1       What is in front of the Notre Dame Main Building?
# 2       The Basilica of the Sacred heart at Notre Dame...
# 3                       What is the Grotto at Notre Dame?
# 4       What sits on top of the Main Building at Notre...
# ...                                                   ...
# 117594                  What is the lowest ISO mentioned?
# 117595                 What is the highest ISO mentioned?
# 117596              What is Kodak'sbrand name of E6 film?
# 117597                         How do these films differ?
# 117598  What letter designates what Ektachrome is desi...
#
#                                                   answers
# 0       {"text": ["Saint Bernadette Soubirous"], "answ...
# 1       {"text": ["a copper statue of Christ"], "answe...
# 2       {"text": ["the Main Building"], "answer_start"...
# 3       {"text": ["a Marian place of prayer and reflec...
# 4       {"text": ["a golden statue of the Virgin Mary"...
# ...                                                   ...
# 117594           {"text": ["400"], "answer_start": [543]}
# 117595           {"text": ["3200"], "answer_start": [60]}
# 117596    {"text": ["Ektachrome"], "answer_start": [470]}
# 117597  {"text": ["high-speed black-and-white films"],...
# 117598             {"text": ["P"], "answer_start": [450]}
#
# [117599 rows x 3 columns]

# %%
import pandas as pd
def dataset_fmt(t, file_name):
    """
    format t to acceptable dataframe format
    """
    df = pd.DataFrame([
        {'context':i[k][0], 'question':i[k][1], 'answers_text': j[k]}
        for i, j in zip(t.data, t.labels)
        for k in range(len(i))
    ])
    df['answer_start'] = df.apply(lambda row: row['context'].index(row['answers_text']), axis=1)
    df['answers'] = df.apply(lambda row: {'text': [row['answers_text']], 'answer_start': [row['answer_start']]}, axis=1)
    df = df.drop(columns=['answers_text', 'answer_start'])
    df['answers'] = df['answers'].apply(json.dumps)
    df = df.drop_duplicates().reset_index(drop=True)
    df.to_csv(f'new_data/{file_name}.csv', index=False)
    return df


def inv_dataset_fmt(t, file_name, df_train=df_train):
    """
    use original answers for invariance cases
    note that in many cases start position changes, that's why we find the correct index
    """
    df = pd.DataFrame([{'context':i[0][0], 'question':i[0][1], 'context_modified':i[1][0], 'question_modified':i[1][1]} for i in t.data])
    df = (
        df
        .merge(df_train, on=['context','question'], how='inner')
        .drop(columns=['context', 'question', 'id', 'title'])
        .rename(columns={'context_modified': 'context', 'question_modified':'question'})
        .drop_duplicates(subset=['context','question'])
        .reset_index(drop=True)
    )
    # df = find_matching_index(df)
    df['answers'] = df['answers'].apply(json.dumps)
    df.to_csv(f'new_data/{file_name}.csv', index=False)
    return df

# %%
import re
def find_all_matching(string, sentence):
    matching_lst = []
    for m in re.finditer(re.escape(string), sentence): #re.escape deals with weird character issues
        matching_lst.append(m.start())
    return matching_lst

def find_matching_index(df):
    for index, row in df.iterrows():
        row['answers'] = json.loads(row['answers'])
        for i in range(len(row['answers']['text'])):
            original_index = row['answers']['answer_start'][i]
            all_matched_indexes = find_all_matching(row['answers']['text'][i], row['context'])
            if len(all_matched_indexes) ==0:
                pass
            elif original_index in all_matched_indexes:
                # if the original index is in the matched indexes, do nothing
                pass
            else:
                print(index)
                print(row)
                print('changed')
                # if not, choose the index that's the closest to the original index
                row['answers']['answer_start'][i] = min(all_matched_indexes, key=lambda x: abs(x - original_index))
                print(original_index)
                print(row['answers']['answer_start'][i])
    return df
editor = checklist.editor.Editor()
editor.tg

# %%
#1117 version
import datasets
from transformers import AutoTokenizer, AutoModelForSequenceClassification, \
    AutoModelForQuestionAnswering, Trainer, TrainingArguments, HfArgumentParser
from transformers import pipeline

model_checkpoint = "trained_model_qa_64/trained_model_qa_64/checkpoint-4000"
baseline_model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
baseline_model_pipeline = pipeline('question-answering', model=baseline_model, tokenizer=tokenizer)

#model = pipeline('question-answering', model="distilbert-base-cased-distilled-squad")
baseline_model_pipeline({
    'context': 'A new strain of flu that has the potential to become a pandemic has been identified by scientists.',
    'question': 'What has been discovered by scientists?'
})
# Out:
# {'score': 0.5901924967765808,
#  'start': 0,
#  'end': 19,
#  'answer': 'A new strain of flu'}

# %% [markdown]
# # Checklist test

# %%
#1117 version

from checklist.test_suite import TestSuite
def predconfs(context_question_pairs):
    """
    output: predictions, confidence
    source: https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/tutorials/5.%20Testing%20transformer%20pipelines.ipynb
    https://github.com/filipegl/checklist_SQuAD_exp/blob/main/1.%20SQuAD-create-test-suite.ipynb
    https://github.com/marcotcr/checklist/blob/4e6e5e33a26f30c20ed602b2050f6c73e123cc23/notebooks/Sentiment.ipynb
    https://github.com/marcotcr/checklist/tree/4e6e5e33a26f30c20ed602b2050f6c73e123cc23
    """
    preds = []
    confs = []
    for c, q in context_question_pairs:
        try:
            p = baseline_model_pipeline(question=q, context=c, truncation=True, )
        except:
            print('Failed', q)
            preds.append(' ')
            confs.append(1)
        preds.append(p['answer'])
        confs.append(p['score'])
    return preds, np.array(confs)

def format_squad_with_context(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'C: %s\nQ: %s\n' % (c, q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret

def format_squad(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'Q: %s\n' % (q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret
editor = checklist.editor.Editor()
suite = TestSuite()

# %%
#1117 Vocabulary
suggestions1 = editor.suggest('{first_name} is {mask} than {first_name2}.')[:60]
print(suggestions1)
suggestions1 = [x for x in suggestions1 if x.endswith("er")][:20]
# Out:
# ['smarter', 'older', 'better', 'younger', 'taller', 'worse', 'stronger', 'different', 'shorter', 'cooler', 'nicer', 'tougher', 'bigger', 'hotter', 'happier', 'smaller', 'wiser', 'more', 'faster', 'richer', 'darker', 'thinner', 'weaker', 'less', 'larger', 'quieter', 'cleaner', 'heavier', 'healthier', 'closer', 'colder', 'slower', 'wealthier', 'quicker', 'longer', 'harder', 'safer', 'lighter', 'warmer', 'brighter', 'cheaper', 'sharper', 'higher', 'louder', 'thicker', 'greater', 'lower', 'easier', 'deeper', 'poorer', 'softer', 'smoother', 'simpler', 'stranger', 'newer', 'other', 'superior', 'clearer', 'stricter', 'tighter']

# %% [markdown]
# # Vocabulary

# %%
adj = ['old', 'smart', 'tall', 'young', 'strong', 'short', 'tough', 'cool', 'fast', 'nice', 'small', 'dark', 'wise', 'rich', 'great', 'weak', 'high', 'slow', 'strange', 'clean']
adj = [(x.rstrip('e'), x) for x in adj]
t = editor.template(
    [(
    '{first_name} is {adj[0]}er than {first_name1}.',
    'Who is {adj[0]}er?'
    )
    ],
    labels = ['{first_name}'],
    adj=adj,
    remove_duplicates=True,
    nsamples=500,
    save=True
    )
name = 'A is COMP than B. Who is more COMP?'
# description = ''
# test = MFT(**t, name=name, description=description, capability='Vocabulary')
# suite.add(test)
dataset_fmt(t, "compare_more")
# Out:
#                                context          question  \
# 0            Jim is darker than Annie.    Who is darker?
# 1         Anthony is taller than Jean.    Who is taller?
# 2          Donald is older than Laura.     Who is older?
# 3       Francis is greater than James.   Who is greater?
# 4        Eleanor is darker than Linda.    Who is darker?
# ..                                 ...               ...
# 492   Arthur is shorter than Margaret.   Who is shorter?
# 493       Joseph is nicer than Albert.     Who is nicer?
# 494      Dick is stronger than Leslie.  Who is stronger?
# 495  Caroline is faster than Patricia.    Who is faster?
# 496         Anna is higher than Sarah.    Who is higher?
#
#                                          answers
# 0         {"text": ["Jim"], "answer_start": [0]}
# 1     {"text": ["Anthony"], "answer_start": [0]}
# 2      {"text": ["Donald"], "answer_start": [0]}
# 3     {"text": ["Francis"], "answer_start": [0]}
# 4     {"text": ["Eleanor"], "answer_start": [0]}
# ..                                           ...
# 492    {"text": ["Arthur"], "answer_start": [0]}
# 493    {"text": ["Joseph"], "answer_start": [0]}
# 494      {"text": ["Dick"], "answer_start": [0]}
# 495  {"text": ["Caroline"], "answer_start": [0]}
# 496      {"text": ["Anna"], "answer_start": [0]}
#
# [497 rows x 3 columns]

# %%
#1117 Vocabulary
#1117 version more than
editor = checklist.editor.Editor()
suite = TestSuite()
t = editor.template(
    [(
    '{first_name} is {adj} than {first_name1}.',
    'Who is {adj}?'
    )
    ],
    labels = ['{first_name}'],
    adj=suggestions1,
    remove_duplicates=True,
    nsamples=500,
    save=True
    )
name = 'A is richer than B. Who is more rich?'
description = ''
#test = MFT(**t, name=name, description=description, capability='Taxonomy')
#suite.add(test)
dataset_fmt(t, "compare_less")
# Out:
#                                   context          question  \
# 0             Eric is better than Leslie.    Who is better?
# 1              Lisa is nicer than Harold.     Who is nicer?
# 2                Tom is nicer than Laura.     Who is nicer?
# 3           Harold is faster than Joseph.    Who is faster?
# 4        Tony is stronger than Elizabeth.  Who is stronger?
# ..                                    ...               ...
# 491              Ben is taller than Sara.    Who is taller?
# 492           Fred is shorter than Harry.   Who is shorter?
# 493         Sue is shorter than Patricia.   Who is shorter?
# 494            Ray is better than Steven.    Who is better?
# 495  Michael is happier than Christopher.   Who is happier?
#
#                                         answers
# 0       {"text": ["Eric"], "answer_start": [0]}
# 1       {"text": ["Lisa"], "answer_start": [0]}
# 2        {"text": ["Tom"], "answer_start": [0]}
# 3     {"text": ["Harold"], "answer_start": [0]}
# 4       {"text": ["Tony"], "answer_start": [0]}
# ..                                          ...
# 491      {"text": ["Ben"], "answer_start": [0]}
# 492     {"text": ["Fred"], "answer_start": [0]}
# 493      {"text": ["Sue"], "answer_start": [0]}
# 494      {"text": ["Ray"], "answer_start": [0]}
# 495  {"text": ["Michael"], "answer_start": [0]}
#
# [496 rows x 3 columns]

# %%
#1117 Intensifiers
#1117 version
def crossproduct(t):
    # takes the output of editor.template and does the cross product of contexts and qas
    ret = []
    ret_labels = []
    for x in t.data:
        cs = x['contexts']
        qas = x['qas']
        d = list(itertools.product(cs, qas))
        ret.append([(x[0], x[1][0]) for x in d])
        ret_labels.append([x[1][1] for x in d])
    t.data = ret
    t.labels = ret_labels
    return t
state = editor.suggest('John is very {mask} about the project.')[:20]
print(', '.join(editor.suggest('John is {mask} {state} about the project.', state=state)[:30]))
very = ['very', 'extremely', 'really', 'quite', 'incredibly', 'particularly', 'highly', 'super']
somewhat = ['a little', 'somewhat', 'slightly', 'mildly']

t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {very} {s} about the project. {first_name1} is {s} about the project.',
            '{first_name1} is {s} about the project. {first_name} is {very} {s} about the project.',
            '{first_name} is {s} about the project. {first_name1} is {somewhat} {s} about the project.',
            '{first_name1} is {somewhat} {s} about the project. {first_name} is {s} about the project.',
            '{first_name} is {very} {s} about the project. {first_name1} is {somewhat} {s} about the project.',
            '{first_name1} is {somewhat} {s} about the project. {first_name} is {very} {s} about the project.',
        ],
        'qas': [
            (
                'Who is most {s} about the project?',
                '{first_name}'
            ),
            (
                'Who is least {s} about the project?',
                '{first_name1}'
            ),

        ]

    },
    s = state,
    very=very,
    somewhat=somewhat,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?'
desc = ''
# test = MFT(**t, name=name, description=desc, capability='Vocabulary')
# suite.add(test)
dataset_fmt(t, "intensifiers_reducers")
# Out:
# very, pretty, extremely, also, still, quite, more, really, not, clearly, fairly, incredibly, particularly, now, understandably, rather, cautiously, surprisingly, certainly, feeling, so, especially, definitely, generally, most, highly, super, reportedly, being, obviously
#                                                 context  \
# 0     Claire is very skeptical about the project. Di...
# 1     Claire is very skeptical about the project. Di...
# 2     Diana is skeptical about the project. Claire i...
# 3     Diana is skeptical about the project. Claire i...
# 4     Claire is skeptical about the project. Diana i...
# ...                                                 ...
# 5971  Pamela is slightly confident about the project...
# 5972  Emily is quite confident about the project. Pa...
# 5973  Emily is quite confident about the project. Pa...
# 5974  Pamela is slightly confident about the project...
# 5975  Pamela is slightly confident about the project...
#
#                                        question  \
# 0      Who is most skeptical about the project?
# 1     Who is least skeptical about the project?
# 2      Who is most skeptical about the project?
# 3     Who is least skeptical about the project?
# 4      Who is most skeptical about the project?
# ...                                         ...
# 5971  Who is least confident about the project?
# 5972   Who is most confident about the project?
# 5973  Who is least confident about the project?
# 5974   Who is most confident about the project?
# 5975  Who is least confident about the project?
#
#                                          answers
# 0      {"text": ["Claire"], "answer_start": [0]}
# 1      {"text": ["Diana"], "answer_start": [44]}
# 2     {"text": ["Claire"], "answer_start": [38]}
# 3       {"text": ["Diana"], "answer_start": [0]}
# 4      {"text": ["Claire"], "answer_start": [0]}
# ...                                          ...
# 5971   {"text": ["Pamela"], "answer_start": [0]}
# 5972    {"text": ["Emily"], "answer_start": [0]}
# 5973  {"text": ["Pamela"], "answer_start": [44]}
# 5974   {"text": ["Emily"], "answer_start": [48]}
# 5975   {"text": ["Pamela"], "answer_start": [0]}
#
# [5976 rows x 3 columns]

# %% [markdown]
# # Taxonomy

# %%
#1117 Taxonomy
#1117 version
import munch
order = ['size', 'shape', 'age', 'color']
props = []
properties = {
    'color' : ['red', 'blue','yellow', 'green', 'pink', 'white', 'black', 'orange', 'grey', 'purple', 'brown'],
    'size' : ['big', 'small', 'tiny', 'enormous'],
    'age' : ['old', 'new'],
    'shape' : ['round', 'oval', 'square', 'triangular'],
    'material' : ['iron', 'wooden', 'ceramic', 'glass', 'stone']
}
for i in range(len(order)):
    for j in range(i + 1, len(order)):
        p1, p2 = order[i], order[j]
        for v1, v2 in itertools.product(properties[p1], properties[p2]):
            props.append(munch.Munch({
                'p1': p1,
                'p2': p2,
                'v1': v1,
                'v2': v2,
            }))
print(', '.join(editor.suggest('There is {a:p.v1} {p.v2} {mask} in the room.', p=props, verbose=False)[:30]))
objects = ['box', 'clock', 'table', 'object', 'toy', 'painting', 'sculpture', 'thing', 'figure']

t = crossproduct(editor.template(
    {
        'contexts': [
            'There is {a:p.v1} {p.v2} {obj} in the room.',
            'There is {a:obj} in the room. The {obj} is {p.v1} and {p.v2}.',
        ],
        'qas': [
            (
                'What {p.p1} is the {obj}?',
                '{p.v1}'
            ),
            (
                'What {p.p2} is the {obj}?',
                '{p.v2}'
            ),

        ]
    },
    obj=objects,
    p=props,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'size, shape, age, color'
desc = ''
# test = MFT(**t, name=name, description=desc, capability='Taxonomy')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "size_shape_age_color")
# Out:
# sofa, couch, wall, carpet, chair, table, light, lamp, door, clock, mirror, desk, bed, TV, bar, television, window, box, tree, painting, curtain, fan, fridge, screen, wallpaper, piano, rug, shelf, camera, candle
#                                                 context  \
# 0                  There is a tiny old box in the room.
# 1                  There is a tiny old box in the room.
# 2     There is a box in the room. The box is tiny an...
# 3     There is a box in the room. The box is tiny an...
# 4              There is a square green box in the room.
# ...                                                 ...
# 1663  There is a clock in the room. The clock is big...
# 1664           There is an old white thing in the room.
# 1665           There is an old white thing in the room.
# 1666  There is a thing in the room. The thing is old...
# 1667  There is a thing in the room. The thing is old...
#
#                       question                                     answers
# 0        What size is the box?    {"text": ["tiny"], "answer_start": [11]}
# 1         What age is the box?     {"text": ["old"], "answer_start": [16]}
# 2        What size is the box?    {"text": ["tiny"], "answer_start": [39]}
# 3         What age is the box?     {"text": ["old"], "answer_start": [48]}
# 4       What shape is the box?  {"text": ["square"], "answer_start": [11]}
# ...                        ...                                         ...
# 1663  What color is the clock?     {"text": ["red"], "answer_start": [51]}
# 1664    What age is the thing?     {"text": ["old"], "answer_start": [12]}
# 1665  What color is the thing?   {"text": ["white"], "answer_start": [16]}
# 1666    What age is the thing?     {"text": ["old"], "answer_start": [43]}
# 1667  What color is the thing?   {"text": ["white"], "answer_start": [51]}
#
# [1668 rows x 3 columns]

# %%
#1117 professions
#1117 version
professions = editor.suggest('{first_name} works as {a:mask}.')[:30]
professions += editor.suggest('{first_name} {last_name} works as {a:mask}.')[:30]
professions = list(set(professions))
if 'translator' in professions:
    professions.remove('translator')
print(professions)

def clean(string):
    return string.lstrip('[a,the,an,in,at] ').rstrip('.')
def expect_squad(x, pred, conf, label=None, meta=None):
    return clean(pred) == clean(label)
expect_squad = Expect.single(expect_squad)
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {a:nat} {prof}.',
            '{first_name} is {a:prof}. {first_name} is {nat}.',
            '{first_name} is {nat}. {first_name} is {a:prof}.',
            '{first_name} is {nat} and {a:prof}.',
            '{first_name} is {a:prof} and {nat}.',
        ],
        'qas': [
            (
                'What is {first_name}\'s job?',
                '{prof}'
            ),
            (
                'What is {first_name}\'s nationality?',
                '{nat}'
            ),

        ]

    },
    nat = editor.lexicons['nationality'][:10],
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    save=True,
    ))
name = 'Profession vs nationality'
# test = MFT(**t, name=name, expect=expect_squad, description='',  capability='Taxonomy')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "profession_nationality")
# Out:
# ['investigator', 'reporter', 'waitress', 'educator', 'executive', 'attorney', 'interpreter', 'economist', 'agent', 'nurse', 'administrator', 'escort', 'model', 'actor', 'DJ', 'historian', 'secretary', 'activist', 'organizer', 'analyst', 'photographer', 'editor', 'assistant', 'entrepreneur', 'investor', 'journalist', 'engineer', 'architect', 'accountant', 'author', 'intern', 'artist', 'producer', 'actress']
#                                  context                     question  \
# 0              Anne is an Indonesian DJ.          What is Anne's job?
# 1              Anne is an Indonesian DJ.  What is Anne's nationality?
# 2      Anne is a DJ. Anne is Indonesian.          What is Anne's job?
# 3      Anne is a DJ. Anne is Indonesian.  What is Anne's nationality?
# 4      Anne is Indonesian. Anne is a DJ.          What is Anne's job?
# ...                                  ...                          ...
# 4985  Tim is Chinese. Tim is a waitress.   What is Tim's nationality?
# 4986      Tim is Chinese and a waitress.           What is Tim's job?
# 4987      Tim is Chinese and a waitress.   What is Tim's nationality?
# 4988      Tim is a waitress and Chinese.           What is Tim's job?
# 4989      Tim is a waitress and Chinese.   What is Tim's nationality?
#
#                                              answers
# 0             {"text": ["DJ"], "answer_start": [22]}
# 1     {"text": ["Indonesian"], "answer_start": [11]}
# 2             {"text": ["DJ"], "answer_start": [10]}
# 3     {"text": ["Indonesian"], "answer_start": [22]}
# 4             {"text": ["DJ"], "answer_start": [30]}
# ...                                              ...
# 4985      {"text": ["Chinese"], "answer_start": [7]}
# 4986    {"text": ["waitress"], "answer_start": [21]}
# 4987      {"text": ["Chinese"], "answer_start": [7]}
# 4988     {"text": ["waitress"], "answer_start": [9]}
# 4989     {"text": ["Chinese"], "answer_start": [22]}
#
# [4990 rows x 3 columns]

# %%
animals = ['dog', 'cat', 'bull', 'cow', 'fish', 'serpent', 'snake', 'lizard', 'hamster', 'rabbit', 'guinea pig', 'iguana', 'duck']
vehicles = ['car', 'truck', 'train', 'motorcycle', 'bike', 'firetruck', 'tractor', 'van', 'SUV', 'minivan']
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} has {a:animal} and {a:vehicle}.',
            '{first_name} has {a:vehicle} and {a:animal}.',
        ],
        'qas': [
            (
                'What animal does {first_name} have?',
                '{animal}'
            ),
            (
                'What vehicle does {first_name} have?',
                '{vehicle}'
            ),

        ]

    },
    animal=animals,
    vehicle=vehicles,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Animal vs Vehicle'
# test = MFT(**t, name=name, description='', capability='Taxonomy', expect=expect_squad)
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test, overwrite=True)
dataset_fmt(t, "animal_vehicle")
# Out:
#                                  context                          question  \
# 0            Martha has a dog and a SUV.     What animal does Martha have?
# 1            Martha has a dog and a SUV.    What vehicle does Martha have?
# 2            Martha has a SUV and a dog.     What animal does Martha have?
# 3            Martha has a SUV and a dog.    What vehicle does Martha have?
# 4     Stephanie has a snake and a train.  What animal does Stephanie have?
# ...                                  ...                               ...
# 1963   Emily has a firetruck and a fish.     What vehicle does Emily have?
# 1964         Tim has a duck and a train.        What animal does Tim have?
# 1965         Tim has a duck and a train.       What vehicle does Tim have?
# 1966         Tim has a train and a duck.        What animal does Tim have?
# 1967         Tim has a train and a duck.       What vehicle does Tim have?
#
#                                             answers
# 0           {"text": ["dog"], "answer_start": [13]}
# 1           {"text": ["SUV"], "answer_start": [23]}
# 2           {"text": ["dog"], "answer_start": [23]}
# 3           {"text": ["SUV"], "answer_start": [13]}
# 4         {"text": ["snake"], "answer_start": [16]}
# ...                                             ...
# 1963  {"text": ["firetruck"], "answer_start": [12]}
# 1964       {"text": ["duck"], "answer_start": [10]}
# 1965      {"text": ["train"], "answer_start": [21]}
# 1966       {"text": ["duck"], "answer_start": [22]}
# 1967      {"text": ["train"], "answer_start": [10]}
#
# [1968 rows x 3 columns]

# %%
animals = ['dog', 'cat', 'bull', 'cow', 'fish', 'serpent', 'snake', 'lizard', 'hamster', 'rabbit', 'guinea pig', 'iguana', 'duck']
vehicles = ['car', 'truck', 'train', 'motorcycle', 'bike', 'firetruck', 'tractor', 'van', 'SUV', 'minivan']
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} bought {a:animal}. {first_name2} bought {a:vehicle}.',
            '{first_name2} bought {a:vehicle}. {first_name} bought {a:animal}.',
        ],
        'qas': [
            (
                'Who bought an animal?',
                '{first_name}'
            ),
            (
                'Who bought a vehicle?',
                '{first_name2}'
            ),

        ]

    },
    animal=animals,
    vehicle=vehicles,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Animal vs Vehicle v2'
# test = MFT(**t, name=name, description='', capability='Taxonomy', expect=expect_squad)
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test, overwrite=True)
dataset_fmt(t, "animal_vehicle2")
# Out:
#                                                context               question  \
# 0        Martha bought a lizard. Jason bought a truck.  Who bought an animal?
# 1        Martha bought a lizard. Jason bought a truck.  Who bought a vehicle?
# 2        Jason bought a truck. Martha bought a lizard.  Who bought an animal?
# 3        Jason bought a truck. Martha bought a lizard.  Who bought a vehicle?
# 4     Thomas bought a cat. Andrea bought a motorcycle.  Who bought an animal?
# ...                                                ...                    ...
# 1979   Tim bought a minivan. Eleanor bought an iguana.  Who bought a vehicle?
# 1980  Rebecca bought a dog. Ashley bought a firetruck.  Who bought an animal?
# 1981  Rebecca bought a dog. Ashley bought a firetruck.  Who bought a vehicle?
# 1982  Ashley bought a firetruck. Rebecca bought a dog.  Who bought an animal?
# 1983  Ashley bought a firetruck. Rebecca bought a dog.  Who bought a vehicle?
#
#                                           answers
# 0       {"text": ["Martha"], "answer_start": [0]}
# 1       {"text": ["Jason"], "answer_start": [24]}
# 2      {"text": ["Martha"], "answer_start": [22]}
# 3        {"text": ["Jason"], "answer_start": [0]}
# 4       {"text": ["Thomas"], "answer_start": [0]}
# ...                                           ...
# 1979       {"text": ["Tim"], "answer_start": [0]}
# 1980   {"text": ["Rebecca"], "answer_start": [0]}
# 1981   {"text": ["Ashley"], "answer_start": [22]}
# 1982  {"text": ["Rebecca"], "answer_start": [27]}
# 1983    {"text": ["Ashley"], "answer_start": [0]}
#
# [1984 rows x 3 columns]

# %%
synonyms = [ ('spiritual', 'religious'), ('angry', 'furious'), ('organized', 'organised'),
            ('vocal', 'outspoken'), ('grateful', 'thankful'), ('intelligent', 'smart'),
            ('humble', 'modest'), ('courageous', 'brave'), ('happy', 'joyful'), ('scared', 'frightened'),
           ]

t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is very {s1[0]}. {first_name2} is very {s2[0]}.',
            '{first_name2} is very {s2[0]}. {first_name} is very {s1[0]}.',
        ],
        'qas': [
            (
                'Who is {s1[1]}?',
                '{first_name}'
            ),
            (
                'Who is {s2[1]}?',
                '{first_name2}'
            ),

        ]

    },
    s=synonyms,
    remove_duplicates=True,
    nsamples=250,
    save=True
   ))
t += crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is very {s1[1]}. {first_name2} is very {s2[1]}.',
            '{first_name2} is very {s2[1]}. {first_name} is very {s1[1]}.',
        ],
        'qas': [
            (
                'Who is {s1[0]}?',
                '{first_name}'
            ),
            (
                'Who is {s2[0]}?',
                '{first_name2}'
            ),

        ]

    },
    s=synonyms,
    remove_duplicates=True,
    nsamples=250,
    save=True
    ))
name = 'Synonyms'
# test = MFT(**t, name=name, description='', capability='Taxonomy', expect=expect_squad)
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "synonyms")
# Out:
#                                                 context           question  \
# 0        Anne is very spiritual. Ryan is very grateful.  Who is religious?
# 1        Anne is very spiritual. Ryan is very grateful.   Who is thankful?
# 2        Ryan is very grateful. Anne is very spiritual.  Who is religious?
# 3        Ryan is very grateful. Anne is very spiritual.   Who is thankful?
# 4         Eleanor is very vocal. Sue is very organized.  Who is outspoken?
# ...                                                 ...                ...
# 1831  Jonathan is very outspoken. Christine is very ...      Who is vocal?
# 1832  Colin is very outspoken. Dorothy is very organ...      Who is vocal?
# 1833  Colin is very outspoken. Dorothy is very organ...  Who is organized?
# 1834  Dorothy is very organised. Colin is very outsp...      Who is vocal?
# 1835  Dorothy is very organised. Colin is very outsp...  Who is organized?
#
#                                           answers
# 0         {"text": ["Anne"], "answer_start": [0]}
# 1        {"text": ["Ryan"], "answer_start": [24]}
# 2        {"text": ["Anne"], "answer_start": [23]}
# 3         {"text": ["Ryan"], "answer_start": [0]}
# 4      {"text": ["Eleanor"], "answer_start": [0]}
# ...                                           ...
# 1831  {"text": ["Jonathan"], "answer_start": [0]}
# 1832     {"text": ["Colin"], "answer_start": [0]}
# 1833  {"text": ["Dorothy"], "answer_start": [25]}
# 1834    {"text": ["Colin"], "answer_start": [27]}
# 1835   {"text": ["Dorothy"], "answer_start": [0]}
#
# [1836 rows x 3 columns]

# %%
comp_pairs = [('better', 'worse'), ('older', 'younger'), ('smarter', 'dumber'), ('taller', 'shorter'), ('bigger', 'smaller'), ('stronger', 'weaker'), ('faster', 'slower'), ('darker', 'lighter'), ('richer', 'poorer'), ('happier', 'sadder'), ('louder', 'quieter'), ('warmer', 'colder')]
comp_pairs = list(set(comp_pairs))#list(set(comp_pairs + [(x[1], x[0]) for x in comp_pairs]))
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {comp[0]} than {first_name1}.',
            '{first_name1} is {comp[1]} than {first_name}.',
        ],
        'qas': [
            (
                'Who is {comp[1]}?',
                '{first_name1}',
            ),
            (
                'Who is {comp[0]}?',
                '{first_name}',
            )

        ]
        ,
    },
    comp=comp_pairs,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'A is COMP than B. Who is antonym(COMP)? B'
# test = MFT(**t, name=name, description='', capability='Taxonomy')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "compare_antonym")
# Out:
#                               context         question  \
# 0      Alexandra is bigger than Judy.  Who is smaller?
# 1      Alexandra is bigger than Judy.   Who is bigger?
# 2     Judy is smaller than Alexandra.  Who is smaller?
# 3     Judy is smaller than Alexandra.   Who is bigger?
# 4         Simon is better than Peter.    Who is worse?
# ...                               ...              ...
# 1979      Kelly is poorer than Bobby.   Who is richer?
# 1980     Betty is taller than Elaine.  Who is shorter?
# 1981     Betty is taller than Elaine.   Who is taller?
# 1982    Elaine is shorter than Betty.  Who is shorter?
# 1983    Elaine is shorter than Betty.   Who is taller?
#
#                                             answers
# 0          {"text": ["Judy"], "answer_start": [25]}
# 1      {"text": ["Alexandra"], "answer_start": [0]}
# 2           {"text": ["Judy"], "answer_start": [0]}
# 3     {"text": ["Alexandra"], "answer_start": [21]}
# 4         {"text": ["Peter"], "answer_start": [21]}
# ...                                             ...
# 1979      {"text": ["Bobby"], "answer_start": [21]}
# 1980     {"text": ["Elaine"], "answer_start": [21]}
# 1981       {"text": ["Betty"], "answer_start": [0]}
# 1982      {"text": ["Elaine"], "answer_start": [0]}
# 1983      {"text": ["Betty"], "answer_start": [23]}
#
# [1984 rows x 3 columns]

# %%
antonym_adjs = [('progressive', 'conservative'),('religious', 'secular'),('positive', 'negative'),('defensive', 'offensive'),('rude',  'polite'),('optimistic', 'pessimistic'),('stupid', 'smart'),('negative', 'positive'),('unhappy', 'happy'),('active', 'passive'),('impatient', 'patient'),('powerless', 'powerful'),('visible', 'invisible'),('fat', 'thin'),('bad', 'good'),('cautious', 'brave'), ('hopeful', 'hopeless'),('insecure', 'secure'),('humble', 'proud'),('passive', 'active'),('dependent', 'independent'),('pessimistic', 'optimistic'),('irresponsible', 'responsible'),('courageous', 'fearful')]
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is more {a[0]} than {first_name1}.',
            '{first_name1} is more {a[1]} than {first_name}.',
            '{first_name} is less {a[1]} than {first_name1}.',
            '{first_name1} is less {a[0]} than {first_name}.',
        ],
        'qas': [
            (
                'Who is more {a[0]}?',
                '{first_name}',
            ),
            (
                'Who is less {a[0]}?',
                '{first_name1}',
            ),
            (
                'Who is more {a[1]}?',
                '{first_name1}',
            ),
            (
                'Who is less {a[1]}?',
                '{first_name}',
            ),
        ]
        ,
    },
    a = antonym_adjs,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.'
# test = MFT(**t, name=name, description='', capability='Taxonomy')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "compare_moreless_antonym")
# Out:
#                                      context                    question  \
# 0           George is more fat than Melissa.            Who is more fat?
# 1           George is more fat than Melissa.            Who is less fat?
# 2           George is more fat than Melissa.           Who is more thin?
# 3           George is more fat than Melissa.           Who is less thin?
# 4          Melissa is more thin than George.            Who is more fat?
# ...                                      ...                         ...
# 7947    Ralph is less responsible than Adam.    Who is less responsible?
# 7948  Adam is less irresponsible than Ralph.  Who is more irresponsible?
# 7949  Adam is less irresponsible than Ralph.  Who is less irresponsible?
# 7950  Adam is less irresponsible than Ralph.    Who is more responsible?
# 7951  Adam is less irresponsible than Ralph.    Who is less responsible?
#
#                                           answers
# 0       {"text": ["George"], "answer_start": [0]}
# 1     {"text": ["Melissa"], "answer_start": [24]}
# 2     {"text": ["Melissa"], "answer_start": [24]}
# 3       {"text": ["George"], "answer_start": [0]}
# 4      {"text": ["George"], "answer_start": [26]}
# ...                                           ...
# 7947     {"text": ["Ralph"], "answer_start": [0]}
# 7948    {"text": ["Ralph"], "answer_start": [32]}
# 7949      {"text": ["Adam"], "answer_start": [0]}
# 7950      {"text": ["Adam"], "answer_start": [0]}
# 7951    {"text": ["Ralph"], "answer_start": [32]}
#
# [7952 rows x 3 columns]

# %% [markdown]
# # Robustness

# %%
# import pickle
# # IF YOU ALREADY RAN THIS CELL, JUMP TO NEXT
# # source: https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/QQP.ipynb
import spacy
nlp = spacy.load('en_core_web_sm')
all_questions = set() # a set of all questions and context
for x in dataset['train']:
    all_questions.add(x['question'])
    all_questions.add(x['context'])


all_questions = list(all_questions)
parsed_questions = list(nlp.pipe(all_questions)) # this takes a while to run
spacy_map = dict([(x, y) for x, y in zip(all_questions, parsed_questions)])


pickle.dump(spacy_map, open('processed_squad.pkl', 'wb'))

# %%
import pickle
dataset = datasets.load_dataset('squad')
pairs = [(x['context'], x['question']) for x in dataset['train']]
spacy_map =  pickle.load(open('/content/final/processed_squad.pkl', 'rb'))
processed_pairs = [(spacy_map[x[0]], spacy_map[x[1]]) for x in pairs]
# check
print("text:",pairs[0][0])
print("entities:",spacy_map[pairs[0][0]].ents)

def question_typo(x):
    """
    x[0]: context
    x[1]: question
    Perturb.add_typos(x[1]): add a typo to question
    """
    return (x[0], Perturb.add_typos(x[1]))
t = Perturb.perturb(pairs, question_typo, nsamples=500)
# test = INV(**t, name='Question typo', capability='Robustness', description='')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad)
# suite.add(test, overwrite=True)
inv_dataset_fmt(t, 'typo')
# Out:
# text: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# entities: (Catholic, the Main Building's, the Virgin Mary., the Main Building, Venite Ad Me Omnes, the Main Building, the Sacred Heart, Grotto, Marian, Lourdes, France, the Virgin Mary, Saint Bernadette Soubirous, 1858, 3, the Gold Dome, Mary)
#                                                context  \
# 0    A strong and prominent a cappella tradition wa...
# 1    Catalan has an inflectional grammar, with two ...
# 2     Hong Kong: The event was held in Hong Kong on...
# 3    The tourist industry is heavily based on the p...
# 4    A referee may stop the match when they or offi...
# ..                                                 ...
# 495  The Late Jurassic spans from 163 million to 14...
# 496  A group of seven companies began the developme...
# 497  After back-to-back pennants in 1880 and 1881, ...
# 498  Eritrea can be split into three ecoregions. To...
# 499  The disadvantage of the ski-jump is the penalt...
#
#                                               question  \
# 0    When did a cappell abegin to take hold in the ...
# 1    What is used in Catalan a sword endings that i...
# 2    How many torchbearers participated in the rela...
# 3    What kind of fisihng tourism occurs on the isl...
# 4         Why couldn't Shawn Michaels defend hismelf?
# ..                                                 ...
# 495  What caused the destruction of fern prairies a...
# 496                       hWat was the goal for USB's?
# 497  Who assumed ownership of the Cubs fater Hulber...
# 498                       Where si Emba Soira located?
# 499  What do hevaily laden aircraft sometimes requi...
#
#                                                answers
# 0     "{\"text\": [\"1911\"], \"answer_start\": [98]}"
# 1    "{\"text\": [\"consonants\"], \"answer_start\"...
# 2     "{\"text\": [\"120\"], \"answer_start\": [568]}"
# 3    "{\"text\": [\"sportfishing\"], \"answer_start...
# 4    "{\"text\": [\"due to excessive blood loss and...
# ..                                                 ...
# 495  "{\"text\": [\"Sea levels rose\"], \"answer_st...
# 496  "{\"text\": [\"to make it fundamentally easier...
# 497  "{\"text\": [\"Spalding\"], \"answer_start\": ...
# 498  "{\"text\": [\"in the center of Eritrea\"], \"...
# 499  "{\"text\": [\"a catapult or JATO rocket\"], \...
#
# [500 rows x 3 columns]

# %%
def contractions(x):
    conts = Perturb.contractions(x[1])
    return [(x[0], a) for a in conts]
t = Perturb.perturb(pairs, contractions, nsamples=500)
# test = INV(**t, name='Question contractions', capability='Robustness', description='')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad)
# suite.add(test)
inv_dataset_fmt(t, 'contractions')
# Out:
#                                                context  \
# 0    Population testing is still being done. Some N...
# 1    The government of the City of Miami (proper) u...
# 2    In 2010, there were concerns among Tajik offic...
# 3    Researchers include biologists, geologists, oc...
# 4    Nonverbal communication describes the process ...
# ..                                                 ...
# 495  The Bamar form an estimated 68% of the populat...
# 496  The new SuperSpeed bus provides a fourth trans...
# 497  Israel has two official languages, Hebrew and ...
# 498  Einstein partially advocates Mach's principle ...
# 499  Burma is bordered in the northwest by the Chit...
#
#                                               question  \
# 0    Who says genetic tests cannot tell the differe...
# 1        What's the street address of Miami City Hall?
# 2    When did Russia say they'll be sending more tr...
# 3    Who's interested in the effects of harsh envir...
# 4       What's one example of nonverbal communication?
# ..                                                 ...
# 495  What's the largest percentage of  the Burmese ...
# 496    What's full-duplex in SuperSpeed transfer mode?
# 497      What're the two official languages of Israel?
# 498  What's considered contrary to idealist beliefs...
# 499  What countries surround the border that's oppo...
#
#                                                answers
# 0    "{\"text\": [\"Geneticists\"], \"answer_start\...
# 1    "{\"text\": [\"3500 Pan American Drive\"], \"a...
# 2    "{\"text\": [\"2015\"], \"answer_start\": [644]}"
# 3    "{\"text\": [\"Biologists\"], \"answer_start\"...
# 4    "{\"text\": [\"body language\"], \"answer_star...
# ..                                                 ...
# 495  "{\"text\": [\"Bamar form an estimated 68% of ...
# 496  "{\"text\": [\"Communication\"], \"answer_star...
# 497  "{\"text\": [\"Hebrew and Arabic\"], \"answer_...
# 498  "{\"text\": [\"objects exist independently of ...
# 499  "{\"text\": [\"Burma is bordered in the northw...
#
# [500 rows x 3 columns]

# %%
#Add random sentence

random_sentences = set()
for x, _ in processed_pairs:
    for y in x.sents:
        random_sentences.add(y.text)
random_sentences = list(random_sentences)
# check
for y in processed_pairs[0][0].sents:
    print(y.text)

def add_random_sentence(x, **kwargs):
    random_s = np.random.choice(random_sentences)
    while random_s in x[0]:
        random_s = np.random.choice(random_sentences)
    random_s = random_s.strip('.') + '. '
    meta = ['add to end: %s' % random_s, 'add to beg: %s' % random_s]
    return [(x[0] + random_s, x[1]), (random_s + x[0], x[1])], meta

def format_add(x, pred, conf, label=None, meta=None):
    ret = format_squad(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s\n' % meta
    return ret

t = Perturb.perturb(pairs, add_random_sentence, nsamples=500, meta=True)
# test = INV(**t, name='Add random sentence to context', capability='Robustness', description='')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_add)
# suite.add(test)
inv_dataset_fmt(t, 'random_sentence')
# Out:
# Architecturally, the school has a Catholic character.
# Atop the Main Building's gold dome is a golden statue of the Virgin Mary.
# Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes".
# Next to the Main Building is the Basilica of the Sacred Heart.
# Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection.
# It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858.
# At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
#                                                context  \
# 0    As for Mac OS, System 7 was a 32-bit rewrite f...
# 1    During the Hellenistic period, Judea became a ...
# 2    Historically, the cuisine of Estonia has been ...
# 3    Ptolemy's Geography divided Asia on a similar ...
# 4    Energy transformations in the universe over ti...
# ..                                                 ...
# 495  The method of execution of federal prisoners f...
# 496  Rapid environmental changes typically cause ma...
# 497  Religious beliefs in the Eastern Empire and Pe...
# 498  The annual Southampton Boat Show is held in Se...
# 499  Dog behavior is the internally coordinated res...
#
#                                               question  \
# 0       How did the Mac System 7 improve multitasking?
# 1    What religion rose in Judea durring the Hellen...
# 2    What food gathering behaviors are now seen as ...
# 3    "India on this side of the Ganges" is located ...
# 4    What is a process ultimately using the gravita...
# ..                                                 ...
# 495  According to what law are federal prisoners ex...
# 496          How many species currently live on earth?
# 497                      In what yer did Muhammad die?
# 498  What Southampton festival culminates in the Bo...
# 499  Dog minds have been shaped by thousands of yea...
#
#                                                answers
# 0    "{\"text\": [\"co-operative multitasking\"], \...
# 1    "{\"text\": [\"Judaism\"], \"answer_start\": [...
# 2    "{\"text\": [\"Hunting and fishing\"], \"answe...
# 3    "{\"text\": [\"To the south\"], \"answer_start...
# 4    "{\"text\": [\"nucleosynthesis\"], \"answer_st...
# ..                                                 ...
# 495  "{\"text\": [\"Violent Crime Control and Law E...
# 496  "{\"text\": [\"Earth's current species range f...
# 497   "{\"text\": [\"632\"], \"answer_start\": [468]}"
# 498  "{\"text\": [\"Sea City\"], \"answer_start\": ...
# 499  "{\"text\": [\"humans.\"], \"answer_start\": [...
#
# [500 rows x 3 columns]

# %% [markdown]
# # NER

# %%
import re
def change_thing(change_fn):
    def change_both(cq, **kwargs):
        context, question = cq
        a = change_fn(context, meta=True)
        if not a:
            return None
        changed, meta = a
        ret = []
        for c, m in zip(changed, meta):
            new_q = re.sub(r'\b%s\b' % re.escape(m[0]), m[1], question.text)
            ret.append((c, new_q))
        return ret, meta
    return change_both

def expect_same(orig_pred, pred, orig_conf, conf, labels=None, meta=None):
    if not meta:
        return pred == orig_pred
    return pred == re.sub(r'\b%s\b' % re.escape(meta[0]), meta[1], orig_pred)

def format_replace(x, pred, conf, label=None, meta=None):
    ret = format_squad(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s -> %s\n' % meta
    return ret

def format_replace_context(x, pred, conf, label=None, meta=None):
    ret = format_squad_with_context(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s -> %s\n' % meta
    return ret

# %%
t = Perturb.perturb(processed_pairs, change_thing(Perturb.change_names), nsamples=500, meta=True)

# test = INV(**t, name='Change name everywhere', capability='NER',
#           description='', expect=Expect.pairwise(expect_same))
# test.run(predconfs, n=100)
# test.summary(3, format_example_fn=format_replace)
# suite.add(test, overwrite=True)
inv_dataset_fmt(t, 'name_change')
# Out:
#                                                context  \
# 0    After just 100 hours of ground combat, and wit...
# 1    Mithridates the Great was the ruler of Pontus,...
# 2    On 6 September 2007, Belgian-based Internation...
# 3    On September 13, 2009, during the 2009 MTV Vid...
# 4    Eisenhower returned to the U.S. in December 19...
# ..                                                 ...
# 495  An alternative view offered by Michael Sanders...
# 496  Beyoncé's vocal range spans four octaves. Jody...
# 497  In 1867, the university opened the first priva...
# 498  The team worked on a Wii control scheme, adapt...
# 499  Following the Ulm Campaign, French forces mana...
#
#                                               question  \
# 0    Why did Coalition nations fear the removal of ...
# 1    How many Romans lived in Mithridate the Great'...
# 2    How much did the Princess Elizabeth station cost?
# 3    What artist's award reception did Kanye interr...
# 4    What event contributed to Eisenhower receiving...
# ..                                                 ...
# 495  To what part of the prey does Michael Sanders ...
# 496  New York Times' Jon Pareles calls Beyoncé's vo...
# 497  When did Washington University establish its m...
# 498  What kind of movement interfaced with the swor...
# 499   How many muskets did the French capture in th...
#
#                                                answers
# 0    "{\"text\": [\"it would create a power vacuum ...
# 1    "{\"text\": [\"80,000\"], \"answer_start\": [3...
# 2    "{\"text\": [\"$16.3 million\"], \"answer_star...
# 3    "{\"text\": [\"Taylor Swift\"], \"answer_start...
# 4    "{\"text\": [\"Louisiana Maneuvers\"], \"answe...
# ..                                                 ...
# 495  "{\"text\": [\"the body\"], \"answer_start\": ...
# 496  "{\"text\": [\"tart\"], \"answer_start\": [630]}"
# 497  "{\"text\": [\"1891\"], \"answer_start\": [290]}"
# 498  "{\"text\": [\"swinging gesture\"], \"answer_s...
# 499  "{\"text\": [\"100,000\"], \"answer_start\": [...
#
# [500 rows x 3 columns]

# %%
t = Perturb.perturb(processed_pairs, change_thing(Perturb.change_location), nsamples=500, meta=True)

# test = INV(**t, name='Change location everywhere', capability='NER',
#           description='', expect=Expect.pairwise(expect_same))
# test.run(predconfs, n=100)
# test.summary(3, format_example_fn=format_replace)
# suite.add(test, overwrite=True)
inv_dataset_fmt(t, 'location_change')
# Out:
#                                                context  \
# 0    Argentine activists told a news conference tha...
# 1    By 1976, Queen were back in the studio recordi...
# 2    In the 1874 general election, Disraeli was ret...
# 3    Imperial College Union, the students' union at...
# 4    In 2010, 24.9 percent of households reported h...
# ..                                                 ...
# 495  Coyotes and big cats have also been known to a...
# 496  Spectre opened in Germany with $22.45 million ...
# 497  Portland is known for being a trailblazer in v...
# 498  The first boardwalk was built in 1870 along a ...
# 499  St. Louis's primary electrical power source is...
#
#                                               question  \
# 0    What is the name of the activist who promised ...
# 1               What Queen album was released in 1976?
# 2    What removed Catholic Rituals from Anglican se...
# 3    How long is the tenure for an officer to run t...
# 4                          Percentage of unwed births?
# ..                                                 ...
# 495       What big cats in Indonesia also attack dogs?
# 496  How much more did Spectre earn compared with S...
# 497  How many $10+ donations must Portland city cou...
# 498  Why was the first boardwalk built in New Orleans?
# 499  What does St. Louis's main power plant use for...
#
#                                                answers
# 0    "{\"text\": [\"Jorge Carcavallo\"], \"answer_s...
# 1    "{\"text\": [\"A Day at the Races\"], \"answer...
# 2    "{\"text\": [\"Public Worship Regulation Act 1...
# 3    "{\"text\": [\"one year\"], \"answer_start\": ...
# 4      "{\"text\": [\"56\"], \"answer_start\": [635]}"
# ..                                                 ...
# 495  "{\"text\": [\"Tigers\"], \"answer_start\": [2...
# 496    "{\"text\": [\"4%\"], \"answer_start\": [849]}"
# 497   "{\"text\": [\"200\"], \"answer_start\": [257]}"
# 498  "{\"text\": [\"to help hotel owners keep sand ...
# 499  "{\"text\": [\"coal and natural gas\"], \"answ...
#
# [500 rows x 3 columns]

# %% [markdown]
# # Temporal

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            'Both {first_name} and {first_name2} were {prof1}s, but there was a change in {first_name}, who is now {a:prof2}.',
            'Both {first_name2} and {first_name} were {prof1}s, but there was a change in {first_name}, who is now {a:prof2}.',
        ],
        'qas': [
            (
                'Who is {a:prof2}?',
                '{first_name}'
            ),
        ]

    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'There was a change in profession'
# test = MFT(**t, expect=expect_squad, capability='Temporal', name=name, description='' )
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "temproal")
# Out:
#                                                context  \
# 0    Both Suzanne and Victoria were administrators,...
# 1    Both Victoria and Suzanne were administrators,...
# 2    Both Edith and James were educators, but there...
# 3    Both James and Edith were educators, but there...
# 4    Both David and Katie were models, but there wa...
# ..                                                 ...
# 965  Both Margaret and Howard were assistants, but ...
# 966  Both Lawrence and Leslie were investors, but t...
# 967  Both Leslie and Lawrence were investors, but t...
# 968  Both Lawrence and Jean were photographers, but...
# 969  Both Jean and Lawrence were photographers, but...
#
#                      question                                       answers
# 0        Who is an assistant?    {"text": ["Suzanne"], "answer_start": [5]}
# 1        Who is an assistant?   {"text": ["Suzanne"], "answer_start": [18]}
# 2            Who is an agent?      {"text": ["Edith"], "answer_start": [5]}
# 3            Who is an agent?     {"text": ["Edith"], "answer_start": [15]}
# 4     Who is an investigator?      {"text": ["David"], "answer_start": [5]}
# ..                        ...                                           ...
# 965      Who is a journalist?    {"text": ["Howard"], "answer_start": [18]}
# 966         Who is an editor?   {"text": ["Lawrence"], "answer_start": [5]}
# 967         Who is an editor?  {"text": ["Lawrence"], "answer_start": [16]}
# 968  Who is an administrator?   {"text": ["Lawrence"], "answer_start": [5]}
# 969  Who is an administrator?  {"text": ["Lawrence"], "answer_start": [14]}
#
# [970 rows x 3 columns]

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} became a {prof} before {first_name2} did.',
            '{first_name2} became a {prof} after {first_name} did.',
        ],
        'qas': [
            (
                'Who became a {prof} first?',
                '{first_name}'
            ),
            (
                'Who became a {prof} last?',
                '{first_name2}'
            ),
        ]

    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Understanding before / after -> first / last.'
# test = MFT(**t, expect=expect_squad, capability='Temporal', name=name, description='' )
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "before_after")
# Out:
#                                              context  \
# 0     Nicole became a interpreter before Andrew did.
# 1     Nicole became a interpreter before Andrew did.
# 2      Andrew became a interpreter after Nicole did.
# 3      Andrew became a interpreter after Nicole did.
# 4     Jerry became a photographer before Albert did.
# ...                                              ...
# 1991       Patrick became a attorney after Mark did.
# 1992       Robert became a investor before Alex did.
# 1993       Robert became a investor before Alex did.
# 1994        Alex became a investor after Robert did.
# 1995        Alex became a investor after Robert did.
#
#                               question  \
# 0      Who became a interpreter first?
# 1       Who became a interpreter last?
# 2      Who became a interpreter first?
# 3       Who became a interpreter last?
# 4     Who became a photographer first?
# ...                                ...
# 1991       Who became a attorney last?
# 1992      Who became a investor first?
# 1993       Who became a investor last?
# 1994      Who became a investor first?
# 1995       Who became a investor last?
#
#                                          answers
# 0      {"text": ["Nicole"], "answer_start": [0]}
# 1     {"text": ["Andrew"], "answer_start": [35]}
# 2     {"text": ["Nicole"], "answer_start": [34]}
# 3      {"text": ["Andrew"], "answer_start": [0]}
# 4       {"text": ["Jerry"], "answer_start": [0]}
# ...                                          ...
# 1991  {"text": ["Patrick"], "answer_start": [0]}
# 1992   {"text": ["Robert"], "answer_start": [0]}
# 1993    {"text": ["Alex"], "answer_start": [32]}
# 1994  {"text": ["Robert"], "answer_start": [29]}
# 1995     {"text": ["Alex"], "answer_start": [0]}
#
# [1996 rows x 3 columns]

# %% [markdown]
# # Negation

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is not {a:prof}. {first_name2} is.',
            '{first_name2} is {a:prof}. {first_name} is not.',
        ],
        'qas': [
            (
                'Who is {a:prof}?',
                '{first_name2}'
            ),
            (
                'Who is not {a:prof}?',
                '{first_name}'
            ),
        ]

    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Negation in context, may or may not be in question'
# test = MFT(**t, expect=expect_squad, capability='Negation', name=name, description='' )
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "negation")
# Out:
#                                         context                    question  \
# 0             Tim is not an educator. Roger is.         Who is an educator?
# 1             Tim is not an educator. Roger is.     Who is not an educator?
# 2             Roger is an educator. Tim is not.         Who is an educator?
# 3             Roger is an educator. Tim is not.     Who is not an educator?
# 4        Heather is not a secretary. George is.         Who is a secretary?
# ...                                         ...                         ...
# 1975      Charles is an educator. Brian is not.     Who is not an educator?
# 1976  Dorothy is not an interpreter. Amanda is.      Who is an interpreter?
# 1977  Dorothy is not an interpreter. Amanda is.  Who is not an interpreter?
# 1978  Amanda is an interpreter. Dorothy is not.      Who is an interpreter?
# 1979  Amanda is an interpreter. Dorothy is not.  Who is not an interpreter?
#
#                                           answers
# 0       {"text": ["Roger"], "answer_start": [24]}
# 1          {"text": ["Tim"], "answer_start": [0]}
# 2        {"text": ["Roger"], "answer_start": [0]}
# 3         {"text": ["Tim"], "answer_start": [22]}
# 4      {"text": ["George"], "answer_start": [28]}
# ...                                           ...
# 1975    {"text": ["Brian"], "answer_start": [24]}
# 1976   {"text": ["Amanda"], "answer_start": [31]}
# 1977   {"text": ["Dorothy"], "answer_start": [0]}
# 1978    {"text": ["Amanda"], "answer_start": [0]}
# 1979  {"text": ["Dorothy"], "answer_start": [26]}
#
# [1980 rows x 3 columns]

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {a:prof}. {first_name2} is {a:prof2}.',
            '{first_name2} is {a:prof2}. {first_name} is {a:prof}.',
        ],
        'qas': [
            (
                'Who is {a:prof}?',
                '{first_name}'
            ),
            (
                'Who is not {a:prof}?',
                '{first_name2}'
            ),
            (
                'Who is {a:prof2}?',
                '{first_name2}'
            ),
            (
                'Who is not {a:prof2}?',
                '{first_name}'
            ),
        ]

    },
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Negation in question only.'
# test = MFT(**t, expect=expect_squad, capability='Negation', name=name, description='' )
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "negation_question")
# Out:
#                                            context                 question  \
# 0     Michael is an educator. John is an activist.      Who is an educator?
# 1     Michael is an educator. John is an activist.  Who is not an educator?
# 2     Michael is an educator. John is an activist.      Who is an activist?
# 3     Michael is an educator. John is an activist.  Who is not an activist?
# 4     John is an activist. Michael is an educator.      Who is an educator?
# ...                                            ...                      ...
# 3835     Lisa is a reporter. Stephen is an author.    Who is not an author?
# 3836     Stephen is an author. Lisa is a reporter.       Who is a reporter?
# 3837     Stephen is an author. Lisa is a reporter.   Who is not a reporter?
# 3838     Stephen is an author. Lisa is a reporter.        Who is an author?
# 3839     Stephen is an author. Lisa is a reporter.    Who is not an author?
#
#                                           answers
# 0      {"text": ["Michael"], "answer_start": [0]}
# 1        {"text": ["John"], "answer_start": [24]}
# 2        {"text": ["John"], "answer_start": [24]}
# 3      {"text": ["Michael"], "answer_start": [0]}
# 4     {"text": ["Michael"], "answer_start": [21]}
# ...                                           ...
# 3835      {"text": ["Lisa"], "answer_start": [0]}
# 3836     {"text": ["Lisa"], "answer_start": [22]}
# 3837   {"text": ["Stephen"], "answer_start": [0]}
# 3838   {"text": ["Stephen"], "answer_start": [0]}
# 3839     {"text": ["Lisa"], "answer_start": [22]}
#
# [3840 rows x 3 columns]

# %% [markdown]
# # Fairness

# %%
import collections
fewer_profs = ['doctor', 'nurse', 'secretary', 'CEO']
t = editor.template(
    [
        ('{male} is not {a:prof}, {female} is.', 'Who is {a:prof}?', '{female}', 'woman', '{prof}'),
        ('{female} is not {a:prof}, {male} is.', 'Who is {a:prof}?', '{male}', 'man', '{prof}'),
    ],
#     prof=professions + ['doctor'],
    prof=fewer_profs,
    remove_duplicates=True,
    nsamples=1000,
    unroll=True,
    save=True,
    )
data = [(d[0], d[1]) for d in t.data]
labels = [d[2] for d in t.data]
meta = [(d[3], d[4]) for d in t.data]

# test = MFT(data, expect=expect_squad, labels=labels, meta=meta, templates=t.templates,
#           name='M/F failure rates should be similar for different professions', capability='Fairness',
#           description='Using negation in context.')
# test.run(predconfs, n=100)

# suite.add(test)
t.data = [[i] for i in data]
t.labels = [[i] for i in labels]
dataset_fmt(t, "fair")
# Out:
#                                    context          question  \
# 0          Greg is not a doctor, Helen is.  Who is a doctor?
# 1          Helen is not a doctor, Greg is.  Who is a doctor?
# 2      Donald is not a doctor, Barbara is.  Who is a doctor?
# 3      Barbara is not a doctor, Donald is.  Who is a doctor?
# 4     Joseph is not a nurse, Elizabeth is.   Who is a nurse?
# ...                                    ...               ...
# 1975           Amy is not a CEO, Scott is.     Who is a CEO?
# 1976      Kevin is not a nurse, Sharon is.   Who is a nurse?
# 1977      Sharon is not a nurse, Kevin is.   Who is a nurse?
# 1978      Louis is not a nurse, Evelyn is.   Who is a nurse?
# 1979      Evelyn is not a nurse, Louis is.   Who is a nurse?
#
#                                             answers
# 0         {"text": ["Helen"], "answer_start": [22]}
# 1          {"text": ["Greg"], "answer_start": [23]}
# 2       {"text": ["Barbara"], "answer_start": [24]}
# 3        {"text": ["Donald"], "answer_start": [25]}
# 4     {"text": ["Elizabeth"], "answer_start": [23]}
# ...                                             ...
# 1975      {"text": ["Scott"], "answer_start": [18]}
# 1976     {"text": ["Sharon"], "answer_start": [22]}
# 1977      {"text": ["Kevin"], "answer_start": [23]}
# 1978     {"text": ["Evelyn"], "answer_start": [22]}
# 1979      {"text": ["Louis"], "answer_start": [23]}
#
# [1980 rows x 3 columns]

# %% [markdown]
# # Coref

# %%
if 'actress' in professions:
    professions.remove('actress')
t = crossproduct(editor.template(
    {
        'contexts': [
            '{male} and {female} are friends. He is {a:prof1}, and she is {a:prof2}.',
            '{female} and {male} are friends. He is {a:prof1}, and she is {a:prof2}.',
            '{male} and {female} are friends. She is {a:prof2}, and he is {a:prof1}.',
            '{female} and {male} are friends. She is {a:prof2}, and he is {a:prof1}.',
        ],
        'qas': [
            (
                'Who is {a:prof1}?',
                '{male}'
            ),
            (
                'Who is {a:prof2}?',
                '{female}'
            ),
        ]

    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Basic coref, he / she'
# test = MFT(**t, expect=expect_squad, name=name, description='', capability='Coref')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "basic_coref")
# Out:
#                                                 context  \
# 0     Bobby and Louise are friends. He is an author,...
# 1     Bobby and Louise are friends. He is an author,...
# 2     Louise and Bobby are friends. He is an author,...
# 3     Louise and Bobby are friends. He is an author,...
# 4     Bobby and Louise are friends. She is an admini...
# ...                                                 ...
# 3891  Eleanor and Roger are friends. He is a nurse, ...
# 3892  Roger and Eleanor are friends. She is an econo...
# 3893  Roger and Eleanor are friends. She is an econo...
# 3894  Eleanor and Roger are friends. She is an econo...
# 3895  Eleanor and Roger are friends. She is an econo...
#
#                       question                                      answers
# 0            Who is an author?     {"text": ["Bobby"], "answer_start": [0]}
# 1     Who is an administrator?   {"text": ["Louise"], "answer_start": [10]}
# 2            Who is an author?    {"text": ["Bobby"], "answer_start": [11]}
# 3     Who is an administrator?    {"text": ["Louise"], "answer_start": [0]}
# 4            Who is an author?     {"text": ["Bobby"], "answer_start": [0]}
# ...                        ...                                          ...
# 3891      Who is an economist?   {"text": ["Eleanor"], "answer_start": [0]}
# 3892           Who is a nurse?     {"text": ["Roger"], "answer_start": [0]}
# 3893      Who is an economist?  {"text": ["Eleanor"], "answer_start": [10]}
# 3894           Who is a nurse?    {"text": ["Roger"], "answer_start": [12]}
# 3895      Who is an economist?   {"text": ["Eleanor"], "answer_start": [0]}
#
# [3896 rows x 3 columns]

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{male} and {female} are friends. His mom is {a:prof}.',
            '{female} and {male} are friends. His mom is {a:prof}.',
        ],
        'qas': [
            (
                'Whose mom is {a:prof}?',
                '{male}'
            ),
        ]

    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=250,
    ))
t += crossproduct(editor.template(
    {
        'contexts': [
            '{male} and {female} are friends. Her mom is {a:prof}.',
            '{female} and {male} are friends. Her mom is {a:prof}.',
        ],
        'qas': [
            (
                'Whose mom is {a:prof}?',
                '{female}'
            ),
        ]

    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=250,
    ))

name = 'Basic coref, his / her'
# test = MFT(**t, expect=expect_squad, name=name, description='', capability='Coref')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "basic_coref2")
# Out:
#                                                context  \
# 0    Jay and Eleanor are friends. His mom is an act...
# 1    Eleanor and Jay are friends. His mom is an act...
# 2    Hugh and Katie are friends. His mom is an arch...
# 3    Katie and Hugh are friends. His mom is an arch...
# 4    Tom and Rachel are friends. His mom is a journ...
# ..                                                 ...
# 995  Sally and Kevin are friends. Her mom is an arc...
# 996  Howard and Marilyn are friends. Her mom is a p...
# 997  Marilyn and Howard are friends. Her mom is a p...
# 998  Matt and Lynn are friends. Her mom is an inves...
# 999  Lynn and Matt are friends. Her mom is an inves...
#
#                        question                                      answers
# 0     Whose mom is an activist?       {"text": ["Jay"], "answer_start": [0]}
# 1     Whose mom is an activist?      {"text": ["Jay"], "answer_start": [12]}
# 2    Whose mom is an architect?      {"text": ["Hugh"], "answer_start": [0]}
# 3    Whose mom is an architect?     {"text": ["Hugh"], "answer_start": [10]}
# 4    Whose mom is a journalist?       {"text": ["Tom"], "answer_start": [0]}
# ..                          ...                                          ...
# 995  Whose mom is an architect?     {"text": ["Sally"], "answer_start": [0]}
# 996    Whose mom is a producer?  {"text": ["Marilyn"], "answer_start": [11]}
# 997    Whose mom is a producer?   {"text": ["Marilyn"], "answer_start": [0]}
# 998   Whose mom is an investor?      {"text": ["Lynn"], "answer_start": [9]}
# 999   Whose mom is an investor?      {"text": ["Lynn"], "answer_start": [0]}
#
# [1000 rows x 3 columns]

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} and {first_name2} are friends. The former is {a:prof1}.',
            '{first_name2} and {first_name} are friends. The latter is {a:prof1}.',
            '{first_name} and {first_name2} are friends. The former is {a:prof1} and the latter is {a:prof2}.',
            '{first_name2} and {first_name} are friends. The former is {a:prof2} and the latter is {a:prof1}.',
        ],
        'qas': [
            (
                'Who is {a:prof1}?',
                '{first_name}'
            ),
        ]

    },
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Former / Latter'
# test = MFT(**t, expect=expect_squad, name=name, description='', capability='Coref')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "former")
# Out:
#                                                 context  \
# 0     Julia and Rose are friends. The former is an e...
# 1     Rose and Julia are friends. The latter is an e...
# 2     Julia and Rose are friends. The former is an e...
# 3     Rose and Julia are friends. The former is a jo...
# 4     Johnny and Susan are friends. The former is an...
# ...                                                 ...
# 1951  Donald and Judy are friends. The former is a w...
# 1952  Patricia and Jason are friends. The former is ...
# 1953  Jason and Patricia are friends. The latter is ...
# 1954  Patricia and Jason are friends. The former is ...
# 1955  Jason and Patricia are friends. The former is ...
#
#                      question                                       answers
# 0     Who is an entrepreneur?      {"text": ["Julia"], "answer_start": [0]}
# 1     Who is an entrepreneur?      {"text": ["Julia"], "answer_start": [9]}
# 2     Who is an entrepreneur?      {"text": ["Julia"], "answer_start": [0]}
# 3     Who is an entrepreneur?      {"text": ["Julia"], "answer_start": [9]}
# 4         Who is an engineer?     {"text": ["Johnny"], "answer_start": [0]}
# ...                       ...                                           ...
# 1951      Who is an educator?      {"text": ["Judy"], "answer_start": [11]}
# 1952     Who is an assistant?   {"text": ["Patricia"], "answer_start": [0]}
# 1953     Who is an assistant?  {"text": ["Patricia"], "answer_start": [10]}
# 1954     Who is an assistant?   {"text": ["Patricia"], "answer_start": [0]}
# 1955     Who is an assistant?  {"text": ["Patricia"], "answer_start": [10]}
#
# [1956 rows x 3 columns]

# %% [markdown]
# # SRL

# %%
import pattern
import pattern.en
pverb = ['love', 'hate', 'like', 'remember', 'recognize', 'trust', 'deserve', 'understand', 'blame', 'dislike', 'prefer', 'follow', 'notice', 'hurt', 'bother', 'support', 'believe', 'accept', 'attack']
#a = pattern.en.tenses('loves')[0]
#b = pattern.en.tenses('stolen')[0]
#pverb = [(pattern.en.conjugate(v, *a), pattern.en.conjugate(v, *b)) for v in pverb]

t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} {v[0]} {first_name2}.',
            '{first_name2} is {v[1]} by {first_name}.',
        ],
        'qas': [
            (
                'Who {v[0]}?',
                '{first_name}'
            ),
            (
                'Who is {v[1]}?',
                '{first_name2}'
            ),
        ]

    },
    v=pverb,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Agent / object distinction'
# test = MFT(**t, expect=expect_squad, name=name, description='', capability='SRL')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "agent")
# Out:
#                        context   question  \
# 0              Kathleen h Don.     Who h?
# 1              Kathleen h Don.  Who is a?
# 2        Don is a by Kathleen.     Who h?
# 3        Don is a by Kathleen.  Who is a?
# 4            Virginia a Nancy.     Who a?
# ...                        ...        ...
# 1977     Carl is o by William.  Who is o?
# 1978        Andrew b Patricia.     Who b?
# 1979        Andrew b Patricia.  Who is l?
# 1980  Patricia is l by Andrew.     Who b?
# 1981  Patricia is l by Andrew.  Who is l?
#
#                                            answers
# 0      {"text": ["Kathleen"], "answer_start": [0]}
# 1          {"text": ["Don"], "answer_start": [11]}
# 2     {"text": ["Kathleen"], "answer_start": [12]}
# 3           {"text": ["Don"], "answer_start": [0]}
# 4      {"text": ["Virginia"], "answer_start": [0]}
# ...                                            ...
# 1977       {"text": ["Carl"], "answer_start": [0]}
# 1978     {"text": ["Andrew"], "answer_start": [0]}
# 1979   {"text": ["Patricia"], "answer_start": [9]}
# 1980    {"text": ["Andrew"], "answer_start": [17]}
# 1981   {"text": ["Patricia"], "answer_start": [0]}
#
# [1982 rows x 3 columns]

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} {v[0]} {first_name2}. {first_name2} {v[0]} {first_name3}.',
            '{first_name} {v[0]} {first_name2}. {first_name3} is {v[1]} by {first_name2}.',
            '{first_name2} is {v[1]} by {first_name}. {first_name2} {v[0]} {first_name3}.',
            '{first_name2} is {v[1]} by {first_name}. {first_name3} is {v[1]} by {first_name2}.',
        ],
        'qas': [
            (
                'Who {v[0]} {first_name2}?',
                '{first_name}'
            ),
            (
                'Who {v[0]} {first_name3}?',
                '{first_name2}'
            ),
            (
                'Who is {v[1]} by {first_name}?',
                '{first_name2}'
            ),
            (
                'Who is {v[1]} by {first_name2}?',
                '{first_name3}'
            ),
        ]

    },
    save=True,
    v=pverb,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Agent / object distinction with 3 agents'
# test = MFT(**t, expect=expect_squad, name=name, description='', capability='SRL')
# test.run(predconfs, n=100)
# test.summary(n=3, format_example_fn=format_squad_with_context)
# suite.add(test)
dataset_fmt(t, "agent2")
# Out:
#                                              context                question  \
# 0                 Alexandra r Jane. Jane r Lawrence.             Who r Jane?
# 1                 Alexandra r Jane. Jane r Lawrence.         Who r Lawrence?
# 2                 Alexandra r Jane. Jane r Lawrence.  Who is e by Alexandra?
# 3                 Alexandra r Jane. Jane r Lawrence.       Who is e by Jane?
# 4           Alexandra r Jane. Lawrence is e by Jane.             Who r Jane?
# ...                                              ...                     ...
# 7867        Andrea is e by Florence. Andrea r Billy.     Who is e by Andrea?
# 7868  Andrea is e by Florence. Billy is e by Andrea.           Who r Andrea?
# 7869  Andrea is e by Florence. Billy is e by Andrea.            Who r Billy?
# 7870  Andrea is e by Florence. Billy is e by Andrea.   Who is e by Florence?
# 7871  Andrea is e by Florence. Billy is e by Andrea.     Who is e by Andrea?
#
#                                            answers
# 0     {"text": ["Alexandra"], "answer_start": [0]}
# 1         {"text": ["Jane"], "answer_start": [12]}
# 2         {"text": ["Jane"], "answer_start": [12]}
# 3     {"text": ["Lawrence"], "answer_start": [25]}
# 4     {"text": ["Alexandra"], "answer_start": [0]}
# ...                                            ...
# 7867     {"text": ["Billy"], "answer_start": [34]}
# 7868  {"text": ["Florence"], "answer_start": [15]}
# 7869     {"text": ["Andrea"], "answer_start": [0]}
# 7870     {"text": ["Andrea"], "answer_start": [0]}
# 7871     {"text": ["Billy"], "answer_start": [25]}
#
# [7872 rows x 3 columns]

# %% [markdown]
# # Combine all

# %%
import pandas as pd
import glob

path = 'new_data'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
del li
frame
# Out:
#                                   context                          question  \
# 0             Martha has a dog and a SUV.     What animal does Martha have?
# 1             Martha has a dog and a SUV.    What vehicle does Martha have?
# 2             Martha has a SUV and a dog.     What animal does Martha have?
# 3             Martha has a SUV and a dog.    What vehicle does Martha have?
# 4      Stephanie has a snake and a train.  What animal does Stephanie have?
# ...                                   ...                               ...
# 59318         Amy is not a CEO, Scott is.                     Who is a CEO?
# 59319    Kevin is not a nurse, Sharon is.                   Who is a nurse?
# 59320    Sharon is not a nurse, Kevin is.                   Who is a nurse?
# 59321    Louis is not a nurse, Evelyn is.                   Who is a nurse?
# 59322    Evelyn is not a nurse, Louis is.                   Who is a nurse?
#
#                                           answers
# 0         {"text": ["dog"], "answer_start": [13]}
# 1         {"text": ["SUV"], "answer_start": [23]}
# 2         {"text": ["dog"], "answer_start": [23]}
# 3         {"text": ["SUV"], "answer_start": [13]}
# 4       {"text": ["snake"], "answer_start": [16]}
# ...                                           ...
# 59318   {"text": ["Scott"], "answer_start": [18]}
# 59319  {"text": ["Sharon"], "answer_start": [22]}
# 59320   {"text": ["Kevin"], "answer_start": [23]}
# 59321  {"text": ["Evelyn"], "answer_start": [22]}
# 59322   {"text": ["Louis"], "answer_start": [23]}
#
# [59323 rows x 3 columns]

# %%
frame.iloc[0].answers
# Out:
# '{"text": ["dog"], "answer_start": [13]}'

# %%
json.loads(frame.iloc[57410].answers)
# Out:
# {'text': ['Bill'], 'answer_start': [26]}

# %%
{'text': ['primary (P), secondary (S), and tertiary (T)'],
 'answer_start': [115]}
frame.to_csv('checklist_train_1130.csv', index=None)
combined = pd.concat([
    df_train[['context','question','answers']],
    frame]
)
## shuffle
combined.iloc[np.random.permutation(len(combined))].reset_index(drop=True)
# Out:
#                                                   context  \
# 0       The inflection of determinatives is complex, s...
# 1                             Harry is warmer than Jerry.
# 2       The mandolin's popularity in the United States...
# 3       The Clerk of the Parliaments, an official of t...
# 4                   Deborah is less polite than Kathleen.
# ...                                                   ...
# 176917  City transportation in Strasbourg includes the...
# 176918  The Arctic tern holds the long-distance migrat...
# 176919  The foundations of the British Empire were lai...
# 176920  Uniquely among major American cities, New York...
# 176921               Alexandra b Brian. Brian b Florence.
#
#                                                  question  \
# 0       What language does Catalan have more contracti...
# 1                                          Who is warmer?
# 2                       What group in the US was popular?
# 3       What phrase is used to announce a withheld ass...
# 4                                       Who is less rude?
# ...                                                   ...
# 176917  What is the length of the Strasbourg tramway i...
# 176918                 Where do Manx shearwaters migrate?
# 176919         When was John Cabot's voyage commissioned?
# 176920  What square is home to the US Court of Interna...
# 176921                                    Who b Florence?
#
#                                                   answers
# 0            {"text": ["Spanish"], "answer_start": [200]}
# 1                {"text": ["Harry"], "answer_start": [0]}
# 2       {"text": ["Estudiantina Figaro"], "answer_star...
# 3       {"text": ["\"La Reyne s'avisera\""], "answer_s...
# 4            {"text": ["Kathleen"], "answer_start": [28]}
# ...                                                   ...
# 176917       {"text": ["55.8 km"], "answer_start": [243]}
# 176918  {"text": ["between their northern breeding gro...
# 176919          {"text": ["1496"], "answer_start": [101]}
# 176920  {"text": ["Foley Square"], "answer_start": [224]}
# 176921          {"text": ["Brian"], "answer_start": [12]}
#
# [176922 rows x 3 columns]

# %%
merged_df = pd.concat([combined, df_train_selected], axis=0)

# Reset the index if necessary
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df.to_csv('combined_train_1130.csv', index=None)

# %% [markdown]
# # Other

# %%
#將檔案copy回去
# !cp -r /content/final/checklist_train_1130.csv /content/MyDrive/MyDrive/UT_NLP/final/checklist_train_1130.csv

# !cp -r /content/final/combined_train_1130.csv /content/MyDrive/MyDrive/UT_NLP/final/combined_train_1130.csv


# !cp -r /content/final/train_merge.csv /content/MyDrive/MyDrive/UT_NLP/final/train_merge.csv

# !cp -r /content/final/new_data_1130 /content/MyDrive/MyDrive/UT_NLP/final/

# %%
#將檔案copy回去
#!cp -r /content/final/trained_model.zip /content/MyDrive/MyDrive/UT_NLP/final/trained_model.zip
# !cp -r /content/final/run.py /content/MyDrive/MyDrive/UT_NLP/final/run.py

#!cp -r /content/a4-distrib/factchecking_main.py /content/MyDrive/MyDrive/UT_NLP/a4-distrib/factchecking_main.py
#!cp -r /content/a4-distrib/transformer.py /content/MyDrive/MyDrive/UT_NLP/a4-distrib/transformer.py

# %%
# !cp -r /content/final /content/MyDrive/MyDrive/UT_NLP

# %% [markdown]
# # 新增區段

# %%
#copy zip file
# !cp -r /content/a4-distrib/wc22987.zip /content/MyDrive/MyDrive/UT_NLP/a4-distrib/
