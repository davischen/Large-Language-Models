# %%
# !rm -rf /content/a2-distrib
# !rm -rf /content/dataset
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
from google.colab import drive
drive.mount('/content/MyDrive/')
# Out:
# Mounted at /content/MyDrive/

# %%
#解壓縮檔案
#%cp -r "/content/MyDrive/MyDrive/UT_NLP/dataset/drive_data.zip" /content/sample_data/drive_data.zip

# %%
#解壓縮檔案
#!unzip /content/sample_data/drive_data.zip -d /content/a2-distrib

# %%
#複製檔案
# !cp -r /content/MyDrive/MyDrive/UT_NLP/a2-distrib/ /content/

# %%
#解壓縮檔案
#!unzip /content/sample_data/dense_data.zip -d /content/a2-distrib

# %%
# %cd /content/a2-distrib/
# Out:
# /content/a2-distrib

# %%
# !python optimization.py --lr 1
# Out:
# Point after epoch 0: array([ 2., 16.])
# Point after epoch 1: array([   0., -224.])
# Point after epoch 2: array([2.000e+00, 3.376e+03])
# Point after epoch 3: array([     0., -50624.])
# Point after epoch 4: array([2.00000e+00, 7.59376e+05])
# Point after epoch 5: array([        0., -11390624.])
# Point after epoch 6: array([2.00000000e+00, 1.70859376e+08])
# Point after epoch 7: array([ 0.00000000e+00, -2.56289062e+09])
# Point after epoch 8: array([2.00000000e+00, 3.84433594e+10])
# Point after epoch 9: array([ 0.00000000e+00, -5.76650391e+11])
# Point after epoch 10: array([2.00000000e+00, 8.64975586e+12])
# Point after epoch 11: array([ 0.00000000e+00, -1.29746338e+14])
# Point after epoch 12: array([2.00000000e+00, 1.94619507e+15])
# Point after epoch 13: array([ 0.0000000e+00, -2.9192926e+16])
# Point after epoch 14: array([2.0000000e+00, 4.3789389e+17])
# Point after epoch 15: array([ 0.00000000e+00, -6.56840836e+18])
# ...

# %%
# !python neural_sentiment_classifier.py --model TRIVIAL --no_run_on_test
# Out:
# Namespace(model='TRIVIAL', train_path='data/train.txt', dev_path='data/dev.txt', use_typo_setting=False, blind_test_path='data/test-blind.txt', test_output_path='test-blind.output.txt', run_on_test=False, word_vecs_path='data/glove.6B.300d-relativized.txt', lr=0.001, num_epochs=10, hidden_size=100, batch_size=1)
# 6920 / 872 / 1821 train/dev/test examples
# Read in 14923 vectors of size 300
# =====Train Accuracy=====
# Accuracy: 3610 / 6920 = 0.521676;
# Precision (fraction of predicted positives that are correct): 3610 / 6920 = 0.521676;
# Recall (fraction of true positives predicted correctly): 3610 / 3610 = 1.000000;
# F1 (harmonic mean of precision and recall): 0.685660;
#
# =====Dev Accuracy=====
# Accuracy: 444 / 872 = 0.509174;
# Precision (fraction of predicted positives that are correct): 444 / 872 = 0.509174;
# Recall (fraction of true positives predicted correctly): 444 / 444 = 1.000000;
# F1 (harmonic mean of precision and recall): 0.674772;
#
# ...

# %%
# !python neural_sentiment_classifier.py
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# ['most', 'thrillers', 'send', 'audiences', 'out', 'talking', 'about', 'specific', 'scary', 'scenes', 'or', 'startling', 'moments', ';', '``', 'frailty', "''", 'leaves', 'us', 'with', 'the', 'terrifying', 'message', 'that', 'the', 'real', 'horror', 'may', 'be', 'waiting', 'for', 'us', 'at', 'home', '.']
# 1
# 110
# ['it', "'s", 'all', 'stitched', 'together', 'with', 'energy', ',', 'intelligence', 'and', 'verve', ',', 'enhanced', 'by', 'a', 'surplus', 'of', 'vintage', 'archive', 'footage', '.']
# 1
# 111
# ['an', 'amused', 'indictment', 'of', 'jaglom', "'s", 'own', 'profession', '.']
# 1
# 112
# ['too', 'bad', 'writer-director', 'adam', 'rifkin', 'situates', 'it', 'all', 'in', 'a', 'plot', 'as', 'musty', 'as', 'one', 'of', 'the', 'golden', 'eagle', "'s", 'carpets', '.']
# 0
# 113
# ...

# %%
# !python neural_sentiment_classifier.py --use_typo_setting
# Out:
# Namespace(model='DAN', train_path='data/train.txt', dev_path='data/dev.txt', use_typo_setting=True, blind_test_path='data/test-blind.txt', test_output_path='test-blind.output.txt', run_on_test=True, word_vecs_path='data/glove.6B.300d-relativized.txt', lr=0.001, num_epochs=10, hidden_size=100, batch_size=1)
# 6920 / 872 / 1821 train/dev/test examples
# Read in 14923 vectors of size 300
# Total loss on epoch 0: 0.005091
# Total loss on epoch 1: 0.003856
# Total loss on epoch 2: 0.002702
# Total loss on epoch 3: 0.001923
# Total loss on epoch 4: 0.001449
# Total loss on epoch 5: 0.001062
# Total loss on epoch 6: 0.000778
# Total loss on epoch 7: 0.000577
# Total loss on epoch 8: 0.000454
# Total loss on epoch 9: 0.000371
# =====Train Accuracy=====
# Accuracy: 6870 / 6920 = 0.992775;
# Precision (fraction of predicted positives that are correct): 3580 / 3600 = 0.994444;
# Recall (fraction of true positives predicted correctly): 3580 / 3610 = 0.991690;
# ...

# %%
#下載檔案
from google.colab import files;
files.download("wc22987.zip");

# %%
#將檔案copy回去

# !cp -r /content/a2-distrib/optimization.py /content/MyDrive/MyDrive/UT_NLP/a2-distrib/optimization.py
# !cp -r /content/a2-distrib/models_1.py /content/MyDrive/MyDrive/UT_NLP/a2-distrib/models_1.py
# !cp -r /content/a2-distrib/models.py /content/MyDrive/MyDrive/UT_NLP/a2-distrib/models.py

# %%
#copy zip file
# !cp -r /content/a2-distrib/wc22987.zip /content/MyDrive/MyDrive/UT_NLP/a2-distrib/
