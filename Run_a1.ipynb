# %%
# !rm -rf /content/a1-distrib
# !rm -rf /content/dataset
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
from google.colab import drive
drive.mount('/content/MyDrive/')
# Out:
# Mounted at /content/MyDrive/

# %%
#解壓縮檔案
#%cp -r "/content/MyDrive/MyDrive/UT_NLP/dataset/drive_data.zip" /content/sample_data/drive_data.zip

# %%
#解壓縮檔案
#!unzip /content/sample_data/drive_data.zip -d /content/a1-distrib

# %%
#複製檔案
# !cp -r /content/MyDrive/MyDrive/UT_NLP/a1-distrib/ /content/

# %%
#解壓縮檔案
#!unzip /content/sample_data/dense_data.zip -d /content/a1-distrib

# %%
# %cd /content/a1-distrib/
# Out:
# /content/a1-distrib

# %%
# !python sentiment_classifier.py --model TRIVIAL --no_run_on_test
# Out:
# Namespace(model='TRIVIAL', feats='UNIGRAM', train_path='data/train.txt', dev_path='data/dev.txt', blind_test_path='data/test-blind.txt', test_output_path='test-blind.output.txt', run_on_test=False)
# 6920 / 872 / 1821 train/dev/test examples
# =====Train Accuracy=====
# Accuracy: 3610 / 6920 = 0.521676
# Precision (fraction of predicted positives that are correct): 3610 / 6920 = 0.521676; Recall (fraction of true positives predicted correctly): 3610 / 3610 = 1.000000; F1 (harmonic mean of precision and recall): 0.685660
# =====Dev Accuracy=====
# Accuracy: 444 / 872 = 0.509174
# Precision (fraction of predicted positives that are correct): 444 / 872 = 0.509174; Recall (fraction of true positives predicted correctly): 444 / 444 = 1.000000; F1 (harmonic mean of precision and recall): 0.674772
# Time for training and evaluation: 0.01 seconds

# %%
# !python sentiment_classifier.py --model PERCEPTRON --feats UNIGRAM
# Out:
# Namespace(model='PERCEPTRON', feats='UNIGRAM', train_path='data/train.txt', dev_path='data/dev.txt', blind_test_path='data/test-blind.txt', test_output_path='test-blind.output.txt', run_on_test=True)
# 6920 / 872 / 1821 train/dev/test examples
# 100% 20/20 [00:01<00:00, 12.33it/s]
# =====Train Accuracy=====
# Accuracy: 6919 / 6920 = 0.999855
# Precision (fraction of predicted positives that are correct): 3609 / 3609 = 1.000000; Recall (fraction of true positives predicted correctly): 3609 / 3610 = 0.999723; F1 (harmonic mean of precision and recall): 0.999861
# =====Dev Accuracy=====
# Accuracy: 671 / 872 = 0.769495
# Precision (fraction of predicted positives that are correct): 348 / 453 = 0.768212; Recall (fraction of true positives predicted correctly): 348 / 444 = 0.783784; F1 (harmonic mean of precision and recall): 0.775920
# Time for training and evaluation: 1.79 seconds

# %%
# !python sentiment_classifier.py --model LR --feats UNIGRAM
# Out:
# Namespace(model='LR', feats='UNIGRAM', train_path='data/train.txt', dev_path='data/dev.txt', blind_test_path='data/test-blind.txt', test_output_path='test-blind.output.txt', run_on_test=True)
# 6920 / 872 / 1821 train/dev/test examples
# 100% 30/30 [00:06<00:00,  4.95it/s]
# =====Train Accuracy=====
# Accuracy: 6916 / 6920 = 0.999422
# Precision (fraction of predicted positives that are correct): 3606 / 3606 = 1.000000; Recall (fraction of true positives predicted correctly): 3606 / 3610 = 0.998892; F1 (harmonic mean of precision and recall): 0.999446
# =====Dev Accuracy=====
# Accuracy: 674 / 872 = 0.772936
# Precision (fraction of predicted positives that are correct): 355 / 464 = 0.765086; Recall (fraction of true positives predicted correctly): 355 / 444 = 0.799550; F1 (harmonic mean of precision and recall): 0.781938
# Time for training and evaluation: 6.27 seconds

# %%
# !python sentiment_classifier.py --model LR --feats BIGRAM
# Out:
# Namespace(model='LR', feats='BIGRAM', train_path='data/train.txt', dev_path='data/dev.txt', blind_test_path='data/test-blind.txt', test_output_path='test-blind.output.txt', run_on_test=True)
# 6920 / 872 / 1821 train/dev/test examples
# 100% 30/30 [00:07<00:00,  4.01it/s]
# =====Train Accuracy=====
# Accuracy: 6920 / 6920 = 1.000000
# Precision (fraction of predicted positives that are correct): 3610 / 3610 = 1.000000; Recall (fraction of true positives predicted correctly): 3610 / 3610 = 1.000000; F1 (harmonic mean of precision and recall): 1.000000
# =====Dev Accuracy=====
# Accuracy: 633 / 872 = 0.725917
# Precision (fraction of predicted positives that are correct): 345 / 485 = 0.711340; Recall (fraction of true positives predicted correctly): 345 / 444 = 0.777027; F1 (harmonic mean of precision and recall): 0.742734
# Time for training and evaluation: 8.12 seconds

# %%
# !python sentiment_classifier.py --model LR --feats BETTER
# Out:
# Namespace(model='LR', feats='BETTER', train_path='data/train.txt', dev_path='data/dev.txt', blind_test_path='data/test-blind.txt', test_output_path='test-blind.output.txt', run_on_test=True)
# 6920 / 872 / 1821 train/dev/test examples
# 100% 30/30 [00:02<00:00, 11.55it/s]
# =====Train Accuracy=====
# Accuracy: 6632 / 6920 = 0.958382
# Precision (fraction of predicted positives that are correct): 3323 / 3324 = 0.999699; Recall (fraction of true positives predicted correctly): 3323 / 3610 = 0.920499; F1 (harmonic mean of precision and recall): 0.958466
# =====Dev Accuracy=====
# Accuracy: 656 / 872 = 0.752294
# Precision (fraction of predicted positives that are correct): 289 / 350 = 0.825714; Recall (fraction of true positives predicted correctly): 289 / 444 = 0.650901; F1 (harmonic mean of precision and recall): 0.727960
# Time for training and evaluation: 2.82 seconds

# %%
#下載檔案
from google.colab import files;
files.download("wc22987.zip");

# %%
#將檔案copy回去

# !cp -r /content/a1-distrib/models.py /content/MyDrive/MyDrive/UT_NLP/a1-distrib/models.py
#!cp -r /content/a1-distrib/homework /content/MyDrive/MyDrive/UT_NLP/a1-distrib/homework_0704/
#!cp -r /content/a1-distrib/wc22987.zip /content/MyDrive/MyDrive/UT_NLP/a1-distrib/

# %%
#copy zip file
# !cp -r /content/a1-distrib/wc22987.zip /content/MyDrive/MyDrive/UT_NLP/a1-distrib/
